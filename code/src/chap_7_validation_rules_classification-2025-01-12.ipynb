# %% [markdown]
# <a href="https://colab.research.google.com/github/asantos2000/master-degree-santos-anderson/blob/main/code/src/chap_7_validation_rules_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Validation
#
# Validation of algorithms and transformation results.
#
# Chap 7. Validação
# - Section 7.3 Resultados
#     - Section 7.3.2 Semantic Annotation
#         - Classificação de regras operativas, fatos, termos e nomes
#     - Section 7.3.3 nlp2sbvr
#
#
# > To run again, restore checkpoint directory with file *-1 to *-10 from `checkpoints_classification` directory.

# %% [markdown]
# ## Google colab

# %%
# %load_ext autoreload
# %autoreload 2

import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  # !rm -rf cfr2sbvr configuration checkpoint
  # !git clone https://github.com/asantos2000/master-degree-santos-anderson.git cfr2sbvr
  # %pip install -r cfr2sbvr/code/requirements.txt
  # !cp -r cfr2sbvr/code/src/configuration .
  # !cp -r cfr2sbvr/code/src/checkpoint .
  # !cp -r cfr2sbvr/code/config.colab.yaml config.yaml
  DEFAULT_CONFIG_FILE="config.yaml"
else:
  DEFAULT_CONFIG_FILE="../config.yaml"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Imports

# %%
# Standard library imports
from collections import defaultdict
from datetime import datetime
import json
import time
from typing import List
import os
import re
from collections import Counter

# Third-party imports
import jellyfish
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from openai import OpenAI
from scipy.spatial.distance import cosine
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)
import seaborn as sns
import xlsxwriter
from openpyxl import load_workbook
import openpyxl
from pydantic import BaseModel, Field

# Local application/library-specific imports
import checkpoint.main as checkpoint
from checkpoint.main import (
    normalize_str,
    restore_checkpoint,
    get_all_checkpoints,
    get_elements_from_checkpoints,
    get_elements_from_true_tables,
    Document,
)
import configuration.main as configuration
import logging_setup.main as logging_setup
import token_estimator.main as token_estimator
from token_estimator.main import estimate_tokens
import llm_query.main as llm_query
from llm_query.main import query_instruct_llm
import rules_taxonomy_provider.main as rules_taxonomy_provider
from rules_taxonomy_provider.main import RulesTemplateProvider

DEV_MODE = True

if DEV_MODE:
    # Development mode
    import importlib

    importlib.reload(configuration)
    importlib.reload(logging_setup)
    importlib.reload(checkpoint)
    importlib.reload(token_estimator)
    importlib.reload(llm_query)
    importlib.reload(rules_taxonomy_provider)

# Ensure plots are displayed inline if using a Jupyter notebook
# %matplotlib inline

from IPython.display import display

# %% [markdown]
# ## Settings

# %% [markdown]
# ### Configuration

# %%
# Load configuration
config = configuration.load_config(DEFAULT_CONFIG_FILE)

# %% [markdown]
# ### Logging

# %%
logger = logging_setup.setting_logging(config["DEFAULT_LOG_DIR"], config["LOG_LEVEL"])
# Out:
# 2025-01-12 01:49:42 - INFO - Logging is set up with daily rotation.

# %% [markdown]
# ## Checkpoints

# %% [markdown]
# ### Restore the checkpoint

# %%
# Restore the checkpoint

# To run after extraction
last_checkpoint = configuration.get_last_filename(
    config["DEFAULT_CHECKPOINT_DIR"], "documents", "json"
)

logger.info(f"{last_checkpoint=}")

config["DEFAULT_CHECKPOINT_FILE"] = last_checkpoint

manager = restore_checkpoint(filename=config["DEFAULT_CHECKPOINT_FILE"])
# Out:
# 2025-01-12 01:49:43 - INFO - last_checkpoint='../data/checkpoints/documents-2025-01-11-10.json'
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-10.json
# 2025-01-12 01:49:43 - INFO - Checkpoint restored from ../data/checkpoints/documents-2025-01-11-10.json.

# %% [markdown]
# ## General functions

# %%
def generate_metrics_with_report(pred_docs, true_docs, key_to_compare, element_name):
    """
    Matches predicted and true documents to extract a specified key's values, then generates
    a confusion matrix and classification report. Plots the confusion matrix and prints the report.
    Returns the confusion matrix and classification report as DataFrames.

    Args:
        pred_docs (list): List of predicted document dictionaries.
        true_docs (list): List of true document dictionaries.
        key_to_compare (str): The key to compare between predicted and true documents.

    Returns:
        tuple: A tuple containing:
            - cm_df (DataFrame): The confusion matrix as a DataFrame.
            - report_df (DataFrame): The classification report as a DataFrame.
            - not_match (list): List of predicted documents with no matching true document.
            - mismatched_docs (list): List of tuples containing the true document and predicted document where y_true differs from y_pred.
    """

    # Normalize sources to avoid mismatches due to ordering or case sensitivity
    def normalize_sources(sources):
        return tuple(sorted([source.strip().lower() for source in sources]))

    # Create a dictionary for true_docs lookup by (doc_id, sources, statement_id)
    true_dict = {
        (
            d["doc_id"],
            normalize_sources(d["sources"]),
            str(d.get("statement_id", "")),
        ): d
        for d in true_docs
    }

    # Initialize true and predicted values
    y_true = []
    y_pred = []
    not_match = []
    mismatched_docs = []

    # Match predicted documents and extract values
    for pred_doc in pred_docs:
        # Generate the key to find the true document
        key = (
            pred_doc["doc_id"],
            normalize_sources(pred_doc["sources"]),
            str(pred_doc.get("statement_id", "")),
        )
        true_doc = true_dict.get(key)
        logger.debug(f"{pred_doc=}")
        # Append the appropriate values for y_true and y_pred
        if true_doc:
            y_true_value = true_doc.get(
                key_to_compare, "No Key"
            )  # Default if key is missing
            y_pred_value = pred_doc.get(
                key_to_compare, "No Key"
            )  # Default if key is missing

            # Add to y_true and y_pred
            y_true.append(y_true_value)
            y_pred.append(y_pred_value)

            # Check for mismatched values between y_true and y_pred
            if y_true_value != y_pred_value:
                mismatched_docs.append((true_doc, pred_doc))

        else:
            # Attempt fallback matching based on doc_id and sources if exact match not found
            fallback_matches = [
                true
                for (doc_id, sources, _), true in true_dict.items()
                if doc_id == pred_doc["doc_id"]
                and sources == normalize_sources(pred_doc["sources"])
            ]
            if fallback_matches:
                true_doc = fallback_matches[0]
                y_true_value = true_doc.get(key_to_compare, "No Key")
                y_pred_value = pred_doc.get(key_to_compare, "No Key")

                # Add to y_true and y_pred
                y_true.append(y_true_value)
                y_pred.append(y_pred_value)

                # Check for mismatched values between y_true and y_pred
                if y_true_value != y_pred_value:
                    mismatched_docs.append((true_doc, pred_doc))

            else:
                # If no match at all, add to not_match
                not_match.append(pred_doc)
            # not_match.append(pred_doc)

    # Ensure all labels are strings to avoid comparison issues
    y_true = [str(label) for label in y_true]
    y_pred = [str(label) for label in y_pred]

    # Generate confusion matrix
    labels = sorted(set(y_true + y_pred))  # Unique classes, sorted for consistency
    # labels = sorted(set(y_true))  # Classes that actually appear in the ground truth
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_df = pd.DataFrame(cm, index=labels, columns=labels)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(
        cm_df, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels
    )
    plt.xlabel(f"Predicted {key_to_compare.capitalize()}")
    plt.ylabel(f"True {key_to_compare.capitalize()}")
    plt.title(
        f"Confusion Matrix for {element_name.capitalize()}: {key_to_compare.capitalize()}"
    )
    plt.show()

    # Print classification report
    report = classification_report(
        y_true, y_pred, labels=labels, output_dict=True, zero_division=0
    )
    print("\nClassification Report:")
    print(
        classification_report(
            y_true, y_pred, labels=labels, output_dict=False, zero_division=0
        )
    )

    # Convert classification report to DataFrame
    report_df = pd.DataFrame(report).transpose()

    return cm_df, report_df, not_match, mismatched_docs

# %%
def remove_section_symbol(input_string: str) -> str:
    """
    Removes the '§' symbol from the input string and trims whitespace.

    Args:
        input_string (str): The string from which to remove the '§' symbol.

    Returns:
        str: The cleaned string without the '§' symbol and leading/trailing whitespace.

    Raises:
        TypeError: If 'input_string' is not a string.
    """
    if not isinstance(input_string, str):
        raise TypeError("input_string must be a string")
    return input_string.replace("§", "").strip()

# %%
def save_metrics_to_excel(dataframes_list, output_excel_path):
    """
    Saves multiple DataFrames to an Excel file, each as a separate sheet.

    Args:
        dataframes_list (list): List of tuples, where each tuple contains:
            - sheet_name (str): The name of the sheet.
            - dataframe (DataFrame): The DataFrame to save.
        output_excel_path (str): Path to save the Excel file.

    Returns:
        None
    """
    # Clean up sheet names to contain only letters, spaces, and numbers
    sanitized_dataframes = [
        (re.sub(r"[^A-Za-z0-9 ]+", "", sheet_name).strip(), df)
        for sheet_name, df in dataframes_list
    ]

    # Check if the file exists
    file_exists = os.path.exists(output_excel_path)

    if file_exists:
        # Load existing workbook
        book = load_workbook(output_excel_path)
        # Append to the existing file
        with pd.ExcelWriter(output_excel_path, engine="openpyxl", mode="a", if_sheet_exists="overlay") as writer:
            for sheet_name, df in sanitized_dataframes:
                # Remove the sheet if it exists in the workbook
                if sheet_name in book.sheetnames:
                    del book[sheet_name]
                # Write to Excel
                df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        # Create a new workbook
        with pd.ExcelWriter(output_excel_path, engine="openpyxl", mode="w") as writer:
            for sheet_name, df in sanitized_dataframes:
                df.to_excel(writer, sheet_name=sheet_name, index=False)

# %%
# Add similarity_classification based on similarity_score
def classify_similarity(score):
    if score == 1.0:
        return "identical"
    elif score >= 0.9:
        return "close-match"
    else:
        return "not-sure"


# Modify the highlight_similarity function to use three colors
def highlight_similarity(val):
    if val == "identical":
        color = "green"
    elif val == "close-match":
        color = "yellow"
    else:
        color = "red"
    return f"background-color: {color}"

# %%
def create_df_elements_results(similarity_elements_results):
    # Build the dataframe
    df_results = pd.DataFrame(similarity_elements_results)

    df_results["similarity_classification"] = df_results["similarity_score"].apply(
        classify_similarity
    )

    df_results["classification_match"] = (
        df_results["classification_pred"] == df_results["classification_true"]
    )
    df_results["classification_match_label"] = df_results["classification_match"].map(
        {True: "match", False: "mismatch"}
    )

    df_results["source_match"] = df_results["source_pred"] == df_results["source_true"]
    df_results["source_match_label"] = df_results["source_match"].map(
        {True: "match", False: "mismatch"}
    )

    df_results["id_match"] = df_results["id_pred"] == df_results["id_true"]
    df_results["id_match_label"] = df_results["id_match"].map(
        {True: "match", False: "mismatch"}
    )

    return df_results

# %% [markdown]
# ## Datasets
#
# From section 7.2.4 Datasets
#
# The dataset of the previous algorithm was adjusted with the gold standard dataset. The goal is to reduce the accumulation of errors from one step to the next.
#
# The data adjusted:
#
# - § 275.0-2_P1, § 275.0-2_P2
# - § 275.0-5_P1, § 275.0-5_P2
# - § 275.0-7_P1, § 275.0-7_P2

# %% [markdown]
# ### True tables

# %% [markdown]
# Get true values from true tables for classification.

# %%
(
    true_operative_rules_p1_classify,
    true_facts_classify,
    true_names_classify,
    true_terms_classify,
    true_operative_rules_p2_classify,
) = get_elements_from_true_tables(config["DEFAULT_DATA_DIR"])
# Out:
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/documents_true_table.json
# 2025-01-12 01:49:43 - INFO - Checkpoint restored from ../data/documents_true_table.json.
# 2025-01-12 01:49:43 - INFO - P1: Operative Rules to evaluate: 6
# 2025-01-12 01:49:43 - INFO - P2: Facts to evaluate: 16
# 2025-01-12 01:49:43 - INFO - P2: Names to evaluate: 5
# 2025-01-12 01:49:43 - INFO - P2: Terms to evaluate: 28
# 2025-01-12 01:49:43 - INFO - P2: Operative Rules to evaluate: 6

# %% [markdown]
# Get predicted values from all runs for classification.

# %% [markdown]
# ### Predicted values
#
# Get predicted elements from all runs

# %%
(
    pred_operative_rules_classify,
    pred_facts_classify,
    pred_terms_classify,
    pred_names_classify,
    pred_files_classify,
) = get_elements_from_checkpoints(
    config["DEFAULT_CHECKPOINT_DIR"], merge=True, filter="non_null"
)
# Out:
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-1.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-10.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-2.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-3.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-4.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-5.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-6.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-7.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-8.json
# 2025-01-12 01:49:43 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-9.json
# 2025-01-12 01:49:43 - WARNING - Document 'classify_P2_Definitional_names' not found or has empty content.
# 2025-01-12 01:49:43 - WARNING - Document 'transform_Names' of type 'llm_response_transform' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Document 'classify_P2_Definitional_names' not found or has empty content.
# 2025-01-12 01:49:43 - WARNING - Document 'transform_Names' of type 'llm_response_transform' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Document 'classify_P2_Definitional_names' not found or has empty content.
# 2025-01-12 01:49:43 - WARNING - Document 'transform_Names' of type 'llm_response_transform' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Document 'classify_P2_Definitional_names' not found or has empty content.
# 2025-01-12 01:49:43 - WARNING - Document 'transform_Names' of type 'llm_response_transform' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Operative_Rules' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Fact_Types' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Terms' not found or empty.
# 2025-01-12 01:49:43 - WARNING - Validation document 'validation_judge_Names' not found or empty.
# 2025-01-12 01:49:43 - INFO - Rules to evaluate: 42
# 2025-01-12 01:49:43 - INFO - Facts to evaluate: 175
# 2025-01-12 01:49:43 - INFO - Terms to evaluate: 237
# 2025-01-12 01:49:43 - INFO - Names to evaluate: 23

# %% [markdown]
# ## Algorithms
#
# Validation of algorithm from section 6.2 Implementation of main components
#
# Source for section 7.3 Results

# %% [markdown]
# ### semantic annotation

# %% [markdown]
# #### Classify elements
#
# Validating results from chap_6_semantic_annotation_elements_classification.ipynb
#
# - Classify operative rules by top-level taxonomy: Activity, Data, Party
# - Classify elements by taxonomy and get templates
#     - operative rules
#     - facts
#     - terms
#     - names

# %% [markdown]
# ##### Operative rules
#
# Validate taxonomy top-level classification. (P1)

# %%
# Save all metrics to a single Excel file
dataframes_list = []

# %% [markdown]
# Compare predict and true values for attribute "type"

# %%
len(pred_operative_rules_classify), len(true_operative_rules_p1_classify)
# Out:
# (42, 6)

# %%
pred_operative_rules_classify
# Out:
# [{'doc_id': '§ 275.0-5',
#   'statement_id': 4,
#   'statement_title': 'Conditions for ordering a hearing',
#   'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion.',
#   'sources': ['(c)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity, the regulatory body overseeing the process.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly mentioned as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a general legal concept referring to a formal meeting for discussion.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is a key part of the decision process.'},
#    {'term': 'Matter',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term is a general concept referring to the subject of the proceeding.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used to describe the subject of the hearing.'},
#    {'term': 'Public interest',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': 'The term is a general concept referring to the welfare of the general public.',
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is used to describe a condition for ordering a hearing.'},
#    {'term': 'Protection of investors',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': "The term is a general concept referring to safeguarding investors' interests.",
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is used to describe a condition for ordering a hearing.'},
#    {'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a general concept referring to any person with a stake in the proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as a participant in the process.'}],
#   'verb_symbols': ['will order', 'appears', 'is necessary', 'is appropriate'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission may order a hearing on the matter only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion.',
#   'type': 'Activity rules',
#   'type_confidence': 0.8,
#   'type_explanation': 'The statement specifies conditions under which the Commission will order a hearing, which is an activity. It outlines the circumstances that trigger this activity, such as necessity in the public interest or upon request, making it an activity obligation rule.',
#   'subtype': 'Activity pre-condition rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': "The statement describes a condition under which the Commission will order a hearing. It specifies that a hearing will be ordered if it appears necessary or appropriate in the public interest or for the protection of investors, or upon request. This aligns with the definition of an activity pre-condition rule, which prohibits an activity unless certain conditions are met. The template T50 is used as it involves a conditional clause ('if it appears that a hearing is necessary or appropriate'). The confidence is set at 0.8 due to the clear conditional nature of the rule, though it does not strictly prohibit the activity without the condition.",
#   'templates_ids': ['T50']},
#  {'doc_id': '§ 275.0-2',
#   'statement_id': 3,
#   'statement_title': 'Forwarding documents by the Secretary',
#   'statement': "If process, pleadings, or other papers are served on the Commission as described in this section, the Secretary of the Commission (Secretary) will promptly forward a copy to each named party by registered or certified mail at that party's last address filed with the Commission.",
#   'sources': ['(a)(2)'],
#   'terms': [{'term': 'Process',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being served.'},
#    {'term': 'Pleadings',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being served.'},
#    {'term': 'Papers',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being served.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific governmental body.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the recipient.'},
#    {'term': 'Secretary of the Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific official within the Commission.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the actor.'},
#    {'term': 'Named party',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the parties involved in the legal process.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the recipient of the documents.'},
#    {'term': 'Registered mail',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a method of mailing documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as the method.'},
#    {'term': 'Certified mail',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a method of mailing documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as the method.'},
#    {'term': 'Last address filed with the Commission',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the address on record for the named party.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the destination of the documents.'}],
#   'verb_symbols': ['served', 'will forward', 'by'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Secretary of the Commission must forward a copy to each named party by registered or certified mail if process, pleadings, or other papers are served on the Commission as described in this section.',
#   'type': 'Party rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement specifies the role of the Secretary in forwarding documents to named parties, indicating a responsibility and action linked to a specific role, which is characteristic of a party rule.',
#   'subtype': 'Responsibility rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': "This statement assigns a responsibility to the Secretary of the Commission to forward documents to each named party. The rule specifies the process (forwarding documents) and the responsible party (Secretary), aligning with the responsibility rule template. The confidence is not full because the statement does not explicitly use the template's verb phrase structure, but the intent is clear.",
#   'templates_ids': ['T56']},
#  {'doc_id': '§ 275.0-2',
#   'statement_id': 4,
#   'statement_title': 'Certification of service by the Secretary',
#   'statement': 'If the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section, this certification constitutes evidence of service upon that party.',
#   'sources': ['(a)(3)'],
#   'terms': [{'term': 'Secretary',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific official within the Commission.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the actor.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific governmental body.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the recipient.'},
#    {'term': 'Process',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being served.'},
#    {'term': 'Pleadings',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being served.'},
#    {'term': 'Papers',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being served.'},
#    {'term': 'Named party',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the parties involved in the legal process.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the recipient of the documents.'},
#    {'term': 'Certification',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the act of certifying the service of documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as the evidence.'},
#    {'term': 'Evidence of service',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the proof of service upon the named party.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the result of the certification.'}],
#   'verb_symbols': ['certifies', 'was served', 'forwarded', 'constitutes'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The certification of service by the Secretary must constitute evidence of service upon a party if the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section.',
#   'type': 'Party rules',
#   'type_confidence': 0.8,
#   'type_explanation': "The statement involves the Secretary's role in certifying service, linking a specific action to a role, which is a characteristic of party rules.",
#   'subtype': 'Responsibility rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': "This statement involves the Secretary's responsibility to certify the service of documents, which constitutes evidence of service. It aligns with the responsibility rule as it defines a duty (certification) and the responsible party (Secretary). The confidence is lower due to the indirect nature of the responsibility and the lack of explicit verb phrase matching the template.",
#   'templates_ids': ['T56']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 4,
#   'statement_title': 'Commission orders a hearing',
#   'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.',
#   'sources': ['(c)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a legal proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."},
#    {'term': 'Public interest',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term describes a condition for ordering a hearing.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'},
#    {'term': 'Protection of investors',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': 'The term describes a condition for ordering a hearing.',
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'}],
#   'verb_symbols': ['will order', 'appears'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission must order a hearing on the matter if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement describes a condition under which an activity (ordering a hearing) must occur, which is characteristic of activity restriction rules.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'The statement describes a decision-making process where the Commission must decide to order a hearing based on specific conditions (public interest or protection of investors). This aligns with the process decision rules, which determine actions in specific situations.',
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 5,
#   'statement_title': 'Request for hearing by interested person',
#   'statement': 'The Commission will order a hearing on the matter upon the request of any interested person.',
#   'sources': ['(c)(1)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a legal proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."},
#    {'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general category of individuals involved in the process.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."}],
#   'verb_symbols': ['will order', 'upon the request'],
#   'element_name': 'Operative Rule',
#   'transformed': 'Each interested person must request a hearing on the matter if the Commission will order it.',
#   'type': 'Activity rules',
#   'type_confidence': 0.8,
#   'type_explanation': 'The statement specifies an activity (ordering a hearing) that must occur upon a triggering event (request by an interested person), aligning with activity obligation rules.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.9,
#   'subtype_explanation': 'The statement specifies a condition under which the Commission must order a hearing, namely, upon request by an interested person. This fits the process decision rules, as it dictates an action based on a specific condition.',
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 6,
#   'statement_title': 'Commission orders a hearing on its own motion',
#   'statement': 'The Commission will order a hearing on the matter upon its own motion.',
#   'sources': ['(c)(2)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a legal proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."},
#    {'term': 'Own motion',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': "The term describes the Commission's initiative.",
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'}],
#   'verb_symbols': ['will order', 'upon'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission must order a hearing on the matter upon its own motion.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'The statement describes an activity (ordering a hearing) that the Commission can initiate on its own, which aligns with activity obligation rules.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': "The statement indicates that the Commission can decide to order a hearing on its own initiative. This is a decision-making process, aligning with process decision rules, as it involves taking action based on the Commission's discretion.",
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-7',
#   'statement_id': 2,
#   'statement_title': 'Asset Threshold for Small Business',
#   'statement': 'An investment adviser did not have total assets of $5 million or more on the last day of the most recent fiscal year.',
#   'sources': ['(a)(2)'],
#   'terms': [{'term': 'Investment adviser',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a specific entity type within the financial industry.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned in the context of the definition.'},
#    {'term': 'Total assets',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a financial metric used to define the size of an investment adviser.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as a criterion.'},
#    {'term': 'Fiscal year',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a specific accounting period.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is mentioned as a time reference for the asset measurement.'}],
#   'verb_symbols': ['did not have'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The total assets specified in each investment adviser must be less than $5 million unless the last day of the most recent fiscal year.',
#   'type': 'Data rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement imposes a constraint on the data (total assets) of an investment adviser, which is characteristic of data content rules.',
#   'subtype': 'Range rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'The statement specifies a condition where the total assets must be less than $5 million, which aligns with a range rule that requires a value to be within a particular range. The statement does not explicitly mention a range but implies an upper limit, fitting the template for range rules.',
#   'templates_ids': ['T29']},
#  {'doc_id': '§ 275.0-7',
#   'statement_id': 3,
#   'statement_title': 'Control Relationship Restriction',
#   'statement': 'An investment adviser does not control, is not controlled by, and is not under common control with another investment adviser that has assets under management of $25 million or more.',
#   'sources': ['(a)(3)'],
#   'terms': [{'term': 'Investment adviser',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a specific entity type within the financial industry.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned in the context of the definition.'},
#    {'term': 'Control',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to the power to direct management or policies.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly defined in the document.'},
#    {'term': 'Assets under management',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a financial metric used to define the size of an investment adviser.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as a criterion.'}],
#   'verb_symbols': ['does not control', 'is not controlled by', 'is not under'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The investment adviser must not be one of the investment advisers that has assets under management of $25 million or more.',
#   'type': 'Party rules',
#   'type_confidence': 0.8,
#   'type_explanation': 'This statement establishes constraints on the relationships between parties (investment advisers), which is characteristic of party rules.',
#   'subtype': 'Role separation rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'The statement specifies that an investment adviser must not have control relationships with another adviser managing $25 million or more. This aligns with the role separation rule, which prohibits the same party from performing two activities, in this case, controlling or being controlled by another adviser. The template T54 fits as it involves prohibiting a relationship between two parties.',
#   'templates_ids': ['T54']},
#  {'doc_id': '§ 275.0-2',
#   'statement_id': 3,
#   'statement_title': 'Forwarding documents by the Secretary',
#   'statement': "If process, pleadings, or other papers are served on the Commission as described in this section, the Secretary of the Commission (Secretary) will promptly forward a copy to each named party by registered or certified mail at that party's last address filed with the Commission.",
#   'sources': ['(a)(2)'],
#   'terms': [{'term': 'Process',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being forwarded.'},
#    {'term': 'Pleadings',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being forwarded.'},
#    {'term': 'Papers',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being forwarded.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific governmental body.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the recipient.'},
#    {'term': 'Secretary of the Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific official within the Commission.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the actor.'},
#    {'term': 'Named party',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the entities involved in the legal process.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the entities receiving the forwarded documents.'},
#    {'term': 'Registered mail',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a method of mailing documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as the method of forwarding.'},
#    {'term': 'Certified mail',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a method of mailing documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as the method of forwarding.'},
#    {'term': 'Last address filed',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the address on record for the named party.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the destination for the documents.'}],
#   'verb_symbols': ['served', 'forward', 'by', 'at'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Secretary of the Commission must forward a copy to each named party by registered or certified mail if process, pleadings, or other papers are served on the Commission as described in this section.',
#   'type': 'Party rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement specifies the role of the Secretary in forwarding documents to named parties, indicating a responsibility and action linked to a specific role, which is characteristic of a party rule.',
#   'subtype': 'Responsibility rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'This statement assigns a responsibility to the Secretary of the Commission to forward documents to each named party. The rule specifies the process (forwarding documents) and the responsible party (the Secretary). The template aligns with the responsibility rule as it defines who is responsible for performing a particular process.',
#   'templates_ids': ['T56']},
#  {'doc_id': '§ 275.0-2',
#   'statement_id': 4,
#   'statement_title': 'Certification of service by the Secretary',
#   'statement': 'If the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section, this certification constitutes evidence of service upon that party.',
#   'sources': ['(a)(3)'],
#   'terms': [{'term': 'Secretary',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific official within the Commission.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the actor.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific governmental body.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the recipient.'},
#    {'term': 'Process',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being certified.'},
#    {'term': 'Pleadings',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being certified.'},
#    {'term': 'Papers',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents involved in the service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the objects being certified.'},
#    {'term': 'Named party',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the entities involved in the legal process.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the entities receiving the documents.'},
#    {'term': 'Certification',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the act of certifying the service of documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as the evidence.'},
#    {'term': 'Evidence of service',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the proof of service upon the named party.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is implied as the result of certification.'}],
#   'verb_symbols': ['certifies', 'was served', 'forwarded', 'constitutes'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The certification of service by the Secretary must constitute evidence of service upon the party if the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section.',
#   'type': 'Party rules',
#   'type_confidence': 0.8,
#   'type_explanation': "The statement involves the Secretary's role in certifying service, which is a responsibility linked to a specific role, indicating a party rule.",
#   'subtype': 'Responsibility rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': "This statement involves the Secretary's responsibility to certify the service of documents. It specifies a process (certification of service) and the responsible party (the Secretary). The rule aligns with the responsibility rule as it defines who is responsible for performing a particular process, although it is more about the evidence of service rather than the act itself.",
#   'templates_ids': ['T56']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 4,
#   'statement_title': 'Commission orders a hearing',
#   'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.',
#   'sources': ['(c)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a legal proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."},
#    {'term': 'Public interest',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term describes a condition for ordering a hearing.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is mentioned as a reason for a hearing.'},
#    {'term': 'Protection of investors',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': 'The term describes a condition for ordering a hearing.',
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is mentioned as a reason for a hearing.'}],
#   'verb_symbols': ['will order', 'appears'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission may order a hearing on the matter only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement describes a condition under which an activity (ordering a hearing) must occur, which is characteristic of an activity rule.',
#   'subtype': 'Activity pre-condition rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'The statement specifies that the Commission will order a hearing only if certain conditions are met, namely if it is necessary or appropriate in the public interest or for the protection of investors. This aligns with the template for activity pre-condition rules, which prohibit an activity unless a prerequisite condition exists.',
#   'templates_ids': ['T50']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 5,
#   'statement_title': 'Request for hearing by interested person',
#   'statement': 'The Commission will order a hearing on the matter, upon the request of any interested person.',
#   'sources': ['(c)(1)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a legal proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."},
#    {'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general category of individuals involved in the process.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."}],
#   'verb_symbols': ['will order', 'upon the request'],
#   'element_name': 'Operative Rule',
#   'transformed': 'A hearing on the matter may be ordered by the Commission only if any interested person requests it.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement specifies an activity (ordering a hearing) that must occur upon a triggering event (request by an interested person), which is characteristic of an activity rule.',
#   'subtype': 'Activity obligation rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': 'The statement indicates that the Commission is obliged to order a hearing if an interested person requests it. This aligns with the activity obligation rules, which require an activity to occur following a specific event, in this case, a request by an interested person.',
#   'templates_ids': ['T49']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 6,
#   'statement_title': 'Commission orders a hearing on its own motion',
#   'statement': 'The Commission will order a hearing on the matter, upon its own motion.',
#   'sources': ['(c)(2)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a legal proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': "The term is central to the statement's context."},
#    {'term': 'Own motion',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': "The term describes the Commission's initiative to order a hearing.",
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is mentioned as a reason for a hearing.'}],
#   'verb_symbols': ['will order', 'upon'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission must order a hearing on the matter if it is upon its own motion.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement describes an activity (ordering a hearing) that the Commission can initiate on its own, which is characteristic of an activity rule.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.6,
#   'subtype_explanation': 'The statement describes a decision-making process where the Commission decides to order a hearing on its own motion. This fits the process decision rules, which determine actions to be taken by a process or device in specific situations. However, the lack of explicit conditions lowers the confidence.',
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-2',
#   'statement_id': 2,
#   'statement_title': 'Forwarding documents by the Secretary',
#   'statement': "The Secretary of the Commission (Secretary) will promptly forward a copy to each named party by registered or certified mail at that party's last address filed with the Commission.",
#   'sources': ['(a)(2)'],
#   'terms': [{'term': 'Secretary of the Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific official position.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the subject.'},
#    {'term': 'Copy',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a duplicate of the documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'},
#    {'term': 'Named party',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the recipient of the documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'},
#    {'term': 'Registered mail',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a method of sending documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'},
#    {'term': 'Certified mail',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a method of sending documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'},
#    {'term': 'Last address filed with the Commission',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the location where documents are sent.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'}],
#   'verb_symbols': ['will forward', 'by'],
#   'element_name': 'Operative Rule',
#   'transformed': "The Secretary of the Commission must forward a copy to each named party if the copy is by registered or certified mail at that party's last address filed with the Commission.",
#   'type': 'Party rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement specifies the role of the Secretary in forwarding documents to named parties, indicating a responsibility and action linked to a specific role, which is characteristic of a party rule.',
#   'subtype': 'Responsibility rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'This statement assigns a responsibility to the Secretary of the Commission to forward documents to each named party. The rule specifies the process (forwarding documents) and the responsible party (the Secretary). The template aligns with the responsibility rule as it defines who must perform a particular process.',
#   'templates_ids': ['T56']},
#  {'doc_id': '§ 275.0-2',
#   'statement_id': 3,
#   'statement_title': 'Certification of service by the Secretary',
#   'statement': 'If the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section, this certification constitutes evidence of service upon that party.',
#   'sources': ['(a)(3)'],
#   'terms': [{'term': 'Secretary',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific official position.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the subject.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a specific organization.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as a recipient.'},
#    {'term': 'Process',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the legal context.'},
#    {'term': 'Pleadings',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the legal context.'},
#    {'term': 'Papers',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to legal documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the legal context.'},
#    {'term': 'Named party',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the recipient of the documents.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'},
#    {'term': 'Certification',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the official confirmation of service.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'},
#    {'term': 'Evidence of service',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to proof of document delivery.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is part of the action described.'}],
#   'verb_symbols': ['certifies', 'was served', 'forwarded', 'constitutes'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The certification by the Secretary must constitute evidence of service upon a party if the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section.',
#   'type': 'Party rules',
#   'type_confidence': 0.8,
#   'type_explanation': "The statement involves the Secretary's role in certifying service, which is a responsibility linked to a specific role, indicating a party rule.",
#   'subtype': 'Responsibility rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': "This statement involves the Secretary's responsibility to certify service of documents. It specifies a process (certification of service) and the responsible party (the Secretary). The rule aligns with the responsibility rule template as it defines who is responsible for a particular process.",
#   'templates_ids': ['T56']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 1,
#   'statement_title': 'Notice of initiation of proceeding',
#   'statement': 'Notice of the initiation of the proceeding will be published in the Federal Register and will indicate the earliest date upon which an order disposing of the matter may be entered.',
#   'sources': ['(a)'],
#   'terms': [{'term': 'Notice',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a general concept related to communication.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as a key part of the procedure.'},
#    {'term': 'Initiation of the proceeding',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term describes a general process or event.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is a central part of the procedural description.'},
#    {'term': 'Federal Register',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term is a specific publication.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly mentioned as the publication medium.'},
#    {'term': 'Order',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': 'The term refers to a general directive or decision.',
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is a key outcome of the proceeding.'},
#    {'term': 'Matter',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general subject or issue.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is a general reference to the subject of the order.'}],
#   'verb_symbols': ['will be published', 'will indicate'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The publication of a notice for the initiation of the proceeding must occur in the Federal Register and indicate the earliest date upon which an order disposing of the matter may be entered.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'The statement describes an activity (publishing notice) that must occur as part of a process, which is characteristic of activity rules.',
#   'subtype': 'Activity time limit rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': 'The statement specifies that the notice will indicate the earliest date upon which an order may be entered, suggesting a time restriction on when the order can occur. This aligns with the template for activity time limit rules, which restricts activities to a particular time period.',
#   'templates_ids': ['T48']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 2,
#   'statement_title': 'Submission of facts by interested persons',
#   'statement': 'Any interested person may, within the period of time specified therein, submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter.',
#   'sources': ['(a)'],
#   'terms': [{'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': 'The term refers to a general category of individuals or entities.',
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is a general reference to potential participants in the process.'},
#    {'term': 'Period of time',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general duration or timeframe.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is a general reference to the timeframe for submission.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 0.95,
#     'reason': 'The term refers to a specific entity, the Commission.',
#     'extracted_confidence': 0.95,
#     'extracted_reason': 'The term is explicitly mentioned as the recipient of submissions.'},
#    {'term': 'Facts',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to general information or data.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as the content of submissions.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.85,
#     'reason': 'The term refers to a general legal proceeding.',
#     'extracted_confidence': 0.85,
#     'extracted_reason': 'The term is a key part of the procedural context.'},
#    {'term': 'Matter',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general subject or issue.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is a general reference to the subject of the hearing.'},
#    {'term': 'Reasons',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to general justifications or explanations.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is a general reference to the rationale for requesting a hearing.'},
#    {'term': 'Nature of interest',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general description of involvement or concern.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is a general reference to the type of interest in the matter.'}],
#   'verb_symbols': ['may submit', 'may request', 'stating'],
#   'element_name': 'Operative Rule',
#   'transformed': 'An interested person may submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter only if the period of time specified therein is met.',
# ...
#   'sources': ['(a)'],
#   'terms': [{'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general category of individuals involved in legal matters.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is used in a legal context to describe potential participants.'},
#    {'term': 'Period of time',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general concept of time duration.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used in a temporal context.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 1.0,
#     'reason': 'The term refers to a specific governing body.',
#     'extracted_confidence': 1.0,
#     'extracted_reason': 'The term is a well-known entity in the context of legal proceedings.'},
#    {'term': 'Facts bearing upon the desirability of a hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to general information relevant to legal decisions.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is used in a legal context to describe relevant information.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general legal procedure.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is clearly defined in the context of legal proceedings.'},
#    {'term': 'Reasons',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to general justifications or explanations.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used in a context of providing explanations.'},
#    {'term': 'Nature of his interest',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general description of involvement.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used in a context of describing involvement.'}],
#   'verb_symbols': ['may submit', 'may request', 'stating'],
#   'element_name': 'Operative Rule',
#   'transformed': 'An interested person may submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter only if the period of time specified therein is met.',
#   'type': 'Party rules',
#   'type_confidence': 0.7,
#   'type_explanation': 'The statement specifies that any interested person can submit facts and request a hearing, indicating a role-based permission, which is characteristic of party rules.',
#   'subtype': 'Party restriction rules',
#   'subtype_confidence': 0.9,
#   'subtype_explanation': "The statement specifies that 'any interested person' may submit facts and request a hearing, which restricts the activity to a subset of parties (interested persons). This aligns well with the party restriction rule template, where a qualifying clause ('interested person') is used to define who may perform the activity.",
#   'templates_ids': ['T53']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 3,
#   'statement_title': 'Issuance of order disposing of the matter',
#   'statement': 'An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter.',
#   'sources': ['(b)'],
#   'terms': [{'term': 'Order disposing of the matter',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term is a general legal concept.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is clearly defined in the context of legal orders.'},
#    {'term': 'Period of time',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general concept of time duration.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used in a temporal context.'},
#    {'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 1.0,
#     'reason': 'The term refers to a specific governing body.',
#     'extracted_confidence': 1.0,
#     'extracted_reason': 'The term is a well-known entity in the context of legal proceedings.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general legal procedure.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is clearly defined in the context of legal proceedings.'}],
#   'verb_symbols': ['will be issued', 'orders'],
#   'element_name': 'Operative Rule',
#   'transformed': 'An order disposing of the matter may be issued only following the expiration of the period of time referred to in paragraph (a) of this section unless the Commission thereafter orders a hearing on the matter.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'The statement describes a process (issuance of an order) that occurs following a specific condition (expiration of time), which is characteristic of activity rules.',
#   'subtype': 'Activity obligation rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': "The statement indicates that an order will be issued following a specific period unless a hearing is ordered, which aligns with the requirement for an activity to occur after a particular event. The use of 'unless' suggests a conditional clause, fitting the template for activity obligation rules.",
#   'templates_ids': ['T49']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 4,
#   'statement_title': 'Commission orders a hearing',
#   'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion.',
#   'sources': ['(c)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 1.0,
#     'reason': 'The term refers to a specific governing body.',
#     'extracted_confidence': 1.0,
#     'extracted_reason': 'The term is a well-known entity in the context of legal proceedings.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general legal procedure.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is clearly defined in the context of legal proceedings.'},
#    {'term': 'Public interest',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general concept of societal benefit.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used in a context of societal considerations.'},
#    {'term': 'Protection of investors',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to a general concept of safeguarding financial participants.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is used in a context of financial protection.'},
#    {'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a general category of individuals involved in legal matters.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is used in a legal context to describe potential participants.'}],
#   'verb_symbols': ['will order',
#    'appears',
#    'is necessary or appropriate',
#    'upon the request',
#    'upon its own motion'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission must order a hearing on the matter if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion.',
#   'type': 'Activity rules',
#   'type_confidence': 0.8,
#   'type_explanation': 'The statement describes the activity of ordering a hearing based on specific conditions, which aligns with activity rules that govern business processes.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': 'The statement describes a decision-making process where the Commission orders a hearing based on specific conditions, such as public interest or investor protection. This aligns with the process decision rules, which determine actions in specific situations.',
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 4,
#   'statement_title': 'Commission orders a hearing',
#   'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.',
#   'sources': ['(c)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 1.0,
#     'reason': 'The term refers to the specific regulatory body involved in the proceedings.',
#     'extracted_confidence': 1.0,
#     'extracted_reason': 'The term is explicitly mentioned as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a formal meeting for discussion or decision-making.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'},
#    {'term': 'Matter',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the subject of the proceeding.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'},
#    {'term': 'Public interest',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the welfare or well-being of the general public.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as a criterion for ordering a hearing.'},
#    {'term': 'Protection of investors',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to safeguarding the interests of investors.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as a criterion for ordering a hearing.'}],
#   'verb_symbols': ['will order', 'appears', 'is necessary', 'is appropriate'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission must order a hearing on the matter if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.',
#   'type': 'Activity rules',
#   'type_confidence': 0.9,
#   'type_explanation': 'This statement defines a condition under which the Commission must perform an activity, specifically ordering a hearing. It is an activity obligation rule as it specifies when a hearing must be ordered based on certain conditions being met.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.8,
#   'subtype_explanation': "The statement describes a decision-making process where the Commission must decide to order a hearing based on specific conditions ('if it appears that a hearing is necessary or appropriate'). This aligns with the process decision rules, which determine actions based on specific situations.",
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 5,
#   'statement_title': 'Request for hearing by interested person',
#   'statement': 'The Commission will order a hearing on the matter upon the request of any interested person.',
#   'sources': ['(c)(1)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 1.0,
#     'reason': 'The term refers to the specific regulatory body involved in the proceedings.',
#     'extracted_confidence': 1.0,
#     'extracted_reason': 'The term is explicitly mentioned as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a formal meeting for discussion or decision-making.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'},
#    {'term': 'Matter',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the subject of the proceeding.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'},
#    {'term': 'Interested person',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to any individual or entity with a stake in the proceeding.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'}],
#   'verb_symbols': ['will order', 'upon the request'],
#   'element_name': 'Operative Rule',
#   'transformed': 'Each interested person must request a hearing on the matter if the Commission will order it.',
#   'type': 'Activity rules',
#   'type_confidence': 0.8,
#   'type_explanation': 'This statement specifies an activity obligation rule where the Commission must order a hearing if an interested person requests it. It defines a trigger for the activity based on a request.',
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.9,
#   'subtype_explanation': 'This statement specifies a condition under which the Commission must take action (ordering a hearing) based on a request from an interested person. This fits the process decision rules, as it dictates an action based on a specific condition.',
#   'templates_ids': ['T52']},
#  {'doc_id': '§ 275.0-5',
#   'statement_id': 6,
#   'statement_title': 'Commission orders a hearing on its own motion',
#   'statement': 'The Commission will order a hearing on the matter upon its own motion.',
#   'sources': ['(c)(2)'],
#   'terms': [{'term': 'Commission',
#     'classification': 'Proper Noun',
#     'confidence': 1.0,
#     'reason': 'The term refers to the specific regulatory body involved in the proceedings.',
#     'extracted_confidence': 1.0,
#     'extracted_reason': 'The term is explicitly mentioned as the entity that orders a hearing.'},
#    {'term': 'Hearing',
#     'classification': 'Common Noun',
#     'confidence': 0.9,
#     'reason': 'The term refers to a formal meeting for discussion or decision-making.',
#     'extracted_confidence': 0.9,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'},
#    {'term': 'Matter',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': 'The term refers to the subject of the proceeding.',
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'},
#    {'term': 'Own motion',
#     'classification': 'Common Noun',
#     'confidence': 0.8,
#     'reason': "The term refers to the Commission's initiative to order a hearing.",
#     'extracted_confidence': 0.8,
#     'extracted_reason': 'The term is explicitly mentioned as part of the procedure.'}],
#   'verb_symbols': ['will order', 'upon its own motion'],
#   'element_name': 'Operative Rule',
#   'transformed': 'The Commission must order a hearing on the matter upon its own motion.',
#   'type': 'Activity rules',
#   'type_confidence': 0.85,
#   'type_explanation': "This statement describes an activity obligation rule where the Commission has the authority to order a hearing on its own initiative. It focuses on the Commission's ability to initiate an activity.",
#   'subtype': 'Process decision rules',
#   'subtype_confidence': 0.7,
#   'subtype_explanation': "The statement indicates that the Commission can decide to order a hearing on its own initiative. This is a decision-making process, aligning with process decision rules, as it involves taking action based on the Commission's own assessment.",
#   'templates_ids': ['T52']}]

# %%
# To get per doc_id use the pred_fitered_list
# pred_fitered_list = [pred_doc for pred_doc in pred_operative_rules_classify if pred_doc["doc_id"] == "§ 275.0-7"]
pred_fitered_list = pred_operative_rules_classify # All

# %%
key = "type"
element_name = "operative rules"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    [pred_doc for pred_doc in pred_fitered_list if "type" in pred_doc],
    true_operative_rules_p1_classify,
    key,
    element_name,
)

print(len(no_match))
print(no_match)
print(len(mismatch_docs))
print(mismatch_docs)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
# Activity rules       1.00      1.00      1.00        15
#    Party rules       1.00      1.00      1.00        17
#
#       accuracy                           1.00        32
#      macro avg       1.00      1.00      1.00        32
#   weighted avg       1.00      1.00      1.00        32
#
# 10
# [{'doc_id': '§ 275.0-5', 'statement_id': 5, 'statement_title': 'Request for hearing by interested person', 'statement': 'The Commission will order a hearing on the matter upon the request of any interested person.', 'sources': ['(c)(1)'], 'terms': [{'term': 'Commission', 'classification': 'Proper Noun', 'confidence': 0.95, 'reason': 'The term refers to a specific entity.', 'extracted_confidence': 0.95, 'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'}, {'term': 'Hearing', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a legal proceeding.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}, {'term': 'Interested person', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a general category of individuals involved in the process.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}], 'verb_symbols': ['will order', 'upon the request'], 'element_name': 'Operative Rule', 'transformed': 'Each interested person must request a hearing on the matter if the Commission will order it.', 'type': 'Activity rules', 'type_confidence': 0.8, 'type_explanation': 'The statement specifies an activity (ordering a hearing) that must occur upon a triggering event (request by an interested person), aligning with activity obligation rules.', 'subtype': 'Process decision rules', 'subtype_confidence': 0.9, 'subtype_explanation': 'The statement specifies a condition under which the Commission must order a hearing, namely, upon request by an interested person. This fits the process decision rules, as it dictates an action based on a specific condition.', 'templates_ids': ['T52']}, {'doc_id': '§ 275.0-5', 'statement_id': 6, 'statement_title': 'Commission orders a hearing on its own motion', 'statement': 'The Commission will order a hearing on the matter upon its own motion.', 'sources': ['(c)(2)'], 'terms': [{'term': 'Commission', 'classification': 'Proper Noun', 'confidence': 0.95, 'reason': 'The term refers to a specific entity.', 'extracted_confidence': 0.95, 'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'}, {'term': 'Hearing', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a legal proceeding.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}, {'term': 'Own motion', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': "The term describes the Commission's initiative.", 'extracted_confidence': 0.8, 'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'}], 'verb_symbols': ['will order', 'upon'], 'element_name': 'Operative Rule', 'transformed': 'The Commission must order a hearing on the matter upon its own motion.', 'type': 'Activity rules', 'type_confidence': 0.9, 'type_explanation': 'The statement describes an activity (ordering a hearing) that the Commission can initiate on its own, which aligns with activity obligation rules.', 'subtype': 'Process decision rules', 'subtype_confidence': 0.7, 'subtype_explanation': "The statement indicates that the Commission can decide to order a hearing on its own initiative. This is a decision-making process, aligning with process decision rules, as it involves taking action based on the Commission's discretion.", 'templates_ids': ['T52']}, {'doc_id': '§ 275.0-7', 'statement_id': 2, 'statement_title': 'Asset Threshold for Small Business', 'statement': 'An investment adviser did not have total assets of $5 million or more on the last day of the most recent fiscal year.', 'sources': ['(a)(2)'], 'terms': [{'term': 'Investment adviser', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term is a specific entity type within the financial industry.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned in the context of t ...
# 0
# []

# %% [markdown]
# List not matched rules.

# %%
for rule in no_match:
    logger.info(json.dumps({
        "doc_id": f"{rule['doc_id']}",
        "statement_id": f"{rule['statement_id']}",
        "statement": f"{rule['statement']}",
        "sources": f"{rule['sources']}",
        "subtype": f"{rule['subtype']}",
        "templates_ids": f"{rule['templates_ids']}",
    }))
# Out:
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "5", "statement": "The Commission will order a hearing on the matter upon the request of any interested person.", "sources": "['(c)(1)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "6", "statement": "The Commission will order a hearing on the matter upon its own motion.", "sources": "['(c)(2)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-7", "statement_id": "2", "statement": "An investment adviser did not have total assets of $5 million or more on the last day of the most recent fiscal year.", "sources": "['(a)(2)']", "subtype": "Range rules", "templates_ids": "['T29']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-7", "statement_id": "3", "statement": "An investment adviser does not control, is not controlled by, and is not under common control with another investment adviser that has assets under management of $25 million or more.", "sources": "['(a)(3)']", "subtype": "Role separation rules", "templates_ids": "['T54']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "5", "statement": "The Commission will order a hearing on the matter, upon the request of any interested person.", "sources": "['(c)(1)']", "subtype": "Activity obligation rules", "templates_ids": "['T49']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "6", "statement": "The Commission will order a hearing on the matter, upon its own motion.", "sources": "['(c)(2)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "5", "statement": "The Commission will order a hearing on the matter upon the request of any interested person.", "sources": "['(c)(1)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "6", "statement": "The Commission will order a hearing on the matter upon its own motion.", "sources": "['(c)(2)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "5", "statement": "The Commission will order a hearing on the matter upon the request of any interested person.", "sources": "['(c)(1)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}
# 2025-01-12 01:49:44 - INFO - {"doc_id": "\u00a7 275.0-5", "statement_id": "6", "statement": "The Commission will order a hearing on the matter upon its own motion.", "sources": "['(c)(2)']", "subtype": "Process decision rules", "templates_ids": "['T52']"}

# %%
sorted([
    f'{doc[0]["doc_id"]} - {doc[0]["sources"]} - {doc[0]["statement"]} - {doc[0]["type"]} - {doc[1]["type"]}'
    for doc in mismatch_docs
])
# Out:
# []

# %% [markdown]
# Validate taxonomy lower-levels classification. (P2)

# %%
# To get per doc_id use the pred_fitered_list
#pred_fitered_list = [pred_doc for pred_doc in pred_operative_rules_classify if pred_doc["doc_id"] == "§ 275.0-5"]
pred_fitered_list = pred_operative_rules_classify # All

# %%
key = "subtype"
element_name = "operative rules"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    [pred_doc for pred_doc in pred_fitered_list if "subtype" in pred_doc],
    true_operative_rules_p2_classify,
    key,
    element_name,
)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))

logger.info(len(no_match))
logger.info(no_match)
logger.info(len(mismatch_docs))
logger.info(mismatch_docs)
# Out:
# 2025-01-12 01:49:44 - INFO - 10
# 2025-01-12 01:49:44 - INFO - [{'doc_id': '§ 275.0-5', 'statement_id': 5, 'statement_title': 'Request for hearing by interested person', 'statement': 'The Commission will order a hearing on the matter upon the request of any interested person.', 'sources': ['(c)(1)'], 'terms': [{'term': 'Commission', 'classification': 'Proper Noun', 'confidence': 0.95, 'reason': 'The term refers to a specific entity.', 'extracted_confidence': 0.95, 'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'}, {'term': 'Hearing', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a legal proceeding.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}, {'term': 'Interested person', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a general category of individuals involved in the process.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}], 'verb_symbols': ['will order', 'upon the request'], 'element_name': 'Operative Rule', 'transformed': 'Each interested person must request a hearing on the matter if the Commission will order it.', 'type': 'Activity rules', 'type_confidence': 0.8, 'type_explanation': 'The statement specifies an activity (ordering a hearing) that must occur upon a triggering event (request by an interested person), aligning with activity obligation rules.', 'subtype': 'Process decision rules', 'subtype_confidence': 0.9, 'subtype_explanation': 'The statement specifies a condition under which the Commission must order a hearing, namely, upon request by an interested person. This fits the process decision rules, as it dictates an action based on a specific condition.', 'templates_ids': ['T52']}, {'doc_id': '§ 275.0-5', 'statement_id': 6, 'statement_title': 'Commission orders a hearing on its own motion', 'statement': 'The Commission will order a hearing on the matter upon its own motion.', 'sources': ['(c)(2)'], 'terms': [{'term': 'Commission', 'classification': 'Proper Noun', 'confidence': 0.95, 'reason': 'The term refers to a specific entity.', 'extracted_confidence': 0.95, 'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'}, {'term': 'Hearing', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a legal proceeding.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}, {'term': 'Own motion', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': "The term describes the Commission's initiative.", 'extracted_confidence': 0.8, 'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'}], 'verb_symbols': ['will order', 'upon'], 'element_name': 'Operative Rule', 'transformed': 'The Commission must order a hearing on the matter upon its own motion.', 'type': 'Activity rules', 'type_confidence': 0.9, 'type_explanation': 'The statement describes an activity (ordering a hearing) that the Commission can initiate on its own, which aligns with activity obligation rules.', 'subtype': 'Process decision rules', 'subtype_confidence': 0.7, 'subtype_explanation': "The statement indicates that the Commission can decide to order a hearing on its own initiative. This is a decision-making process, aligning with process decision rules, as it involves taking action based on the Commission's discretion.", 'templates_ids': ['T52']}, {'doc_id': '§ 275.0-7', 'statement_id': 2, 'statement_title': 'Asset Threshold for Small Business', 'statement': 'An investment adviser did not have total assets of $5 million or more on the last day of the most recent fiscal year.', 'sources': ['(a)(2)'], 'terms': [{'term': 'Investment adviser', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term is a specific entity type within the financial industry.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly  ...
# 2025-01-12 01:49:44 - INFO - 10
# 2025-01-12 01:49:44 - INFO - [({'doc_id': '§ 275.0-5', 'statement_id': '4', 'statement_title': 'Commission orders a hearing', 'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion.', 'sources': ['(c)'], 'subtype': 'Activity pre-condition rules', 'templates_ids': ['T50']}, {'doc_id': '§ 275.0-5', 'statement_id': 4, 'statement_title': 'Commission orders a hearing', 'statement': 'The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.', 'sources': ['(c)'], 'terms': [{'term': 'Commission', 'classification': 'Proper Noun', 'confidence': 0.95, 'reason': 'The term refers to a specific entity.', 'extracted_confidence': 0.95, 'extracted_reason': 'The term is explicitly named as the entity that orders a hearing.'}, {'term': 'Hearing', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term refers to a legal proceeding.', 'extracted_confidence': 0.9, 'extracted_reason': "The term is central to the statement's context."}, {'term': 'Public interest', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term describes a condition for ordering a hearing.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'}, {'term': 'Protection of investors', 'classification': 'Common Noun', 'confidence': 0.85, 'reason': 'The term describes a condition for ordering a hearing.', 'extracted_confidence': 0.85, 'extracted_reason': 'The term is mentioned as a reason for ordering a hearing.'}], 'verb_symbols': ['will order', 'appears'], 'element_name': 'Operative Rule', 'transformed': 'The Commission must order a hearing on the matter if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors.', 'type': 'Activity rules', 'type_confidence': 0.9, 'type_explanation': 'This statement describes a condition under which an activity (ordering a hearing) must occur, which is characteristic of activity restriction rules.', 'subtype': 'Process decision rules', 'subtype_confidence': 0.8, 'subtype_explanation': 'The statement describes a decision-making process where the Commission must decide to order a hearing based on specific conditions (public interest or protection of investors). This aligns with the process decision rules, which determine actions in specific situations.', 'templates_ids': ['T52']}), ({'doc_id': '§ 275.0-5', 'statement_id': '3', 'statement_title': 'Issuance of order disposing of the matter', 'statement': 'An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter.', 'sources': ['(b)'], 'subtype': 'Activity obligation rules', 'templates_ids': ['T49']}, {'doc_id': '§ 275.0-5', 'statement_id': 3, 'statement_title': 'Issuance of order disposing of the matter', 'statement': 'An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter.', 'sources': ['(b)'], 'terms': [{'term': 'Order', 'classification': 'Common Noun', 'confidence': 0.85, 'reason': 'The term refers to a general directive or decision.', 'extracted_confidence': 0.85, 'extracted_reason': 'The term is a key outcome of the proceeding.'}, {'term': 'Matter', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to a general subject or issue.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is a general reference to the subject of the order.'}, {'term': 'Period of time', 'classification': 'Common Noun', 'confidence': ...
# Classification Report:
#                               precision    recall  f1-score   support
#
#    Activity obligation rules       1.00      0.33      0.50         3
# Activity pre-condition rules       0.60      0.30      0.40        10
#    Activity time limit rules       1.00      1.00      1.00         2
#      Party restriction rules       0.75      1.00      0.86         3
#       Process decision rules       0.00      0.00      0.00         0
#         Responsibility rules       1.00      0.93      0.96        14
#
#                     accuracy                           0.69        32
#                    macro avg       0.72      0.59      0.62        32
#                 weighted avg       0.85      0.69      0.74        32

# %% [markdown]
# List not matched rules.

# %%
sorted([
    f'{doc["doc_id"]} - {doc["sources"]} - {doc["statement_id"]} - {doc["subtype"]} - {doc["templates_ids"]}'
    for doc in no_match
])
# Out:
# ["§ 275.0-5 - ['(c)(1)'] - 5 - Activity obligation rules - ['T49']",
#  "§ 275.0-5 - ['(c)(1)'] - 5 - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)(1)'] - 5 - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)(1)'] - 5 - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)(2)'] - 6 - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)(2)'] - 6 - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)(2)'] - 6 - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)(2)'] - 6 - Process decision rules - ['T52']",
#  "§ 275.0-7 - ['(a)(2)'] - 2 - Range rules - ['T29']",
#  "§ 275.0-7 - ['(a)(3)'] - 3 - Role separation rules - ['T54']"]

# %% [markdown]
# List misclassifications

# %%
sorted([
    f'{doc[0]["doc_id"]} - {doc[0]["sources"]} - {doc[0]["statement"]} - {doc[0]["subtype"]} - {doc[0]["templates_ids"]} - {doc[1]["subtype"]} - {doc[1]["templates_ids"]}'
    for doc in mismatch_docs
])
# Out:
# ["§ 275.0-2 - ['(a)(2)'] - If process, pleadings, or other papers are served on the Commission as described in this section, the Secretary of the Commission (Secretary) will promptly forward a copy to each named party by registered or certified mail at that party's last address filed with the Commission. - Responsibility rules - ['T56'] - Party restriction rules - ['T53']",
#  "§ 275.0-5 - ['(b)'] - An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter. - Activity obligation rules - ['T49'] - Activity pre-condition rules - ['T50']",
#  "§ 275.0-5 - ['(b)'] - An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter. - Activity obligation rules - ['T49'] - Activity pre-condition rules - ['T50']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']",
#  "§ 275.0-5 - ['(c)'] - The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion. - Activity pre-condition rules - ['T50'] - Process decision rules - ['T52']"]

# %% [markdown]
# ##### Facts and Fact types

# %%
# To get per doc_id use the pred_fitered_list
#pred_fitered_list = [pred_doc for pred_doc in pred_facts_classify if pred_doc["doc_id"] == "§ 275.0-7"]
pred_fitered_list = pred_facts_classify # All

# %%
key = "subtype"
element_name = "fact types"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    pred_fitered_list,
    true_facts_classify,
    key,
    element_name,
)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))

logger.info(len(no_match))
logger.info(no_match)
logger.info(len(mismatch_docs))
logger.info(mismatch_docs)
# Out:
# 2025-01-12 01:49:45 - INFO - 33
# 2025-01-12 01:49:45 - INFO - [{'doc_id': '§ 275.0-2', 'statement_id': 3, 'statement_title': 'Forwarding documents by the Secretary', 'statement': "If process, pleadings, or other papers are served on the Commission as described in this section, the Secretary of the Commission (Secretary) will promptly forward a copy to each named party by registered or certified mail at that party's last address filed with the Commission.", 'sources': ['(a)(2)'], 'terms': [{'term': 'Process', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to legal documents.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the legal context.'}, {'term': 'Pleadings', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to legal documents.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the legal context.'}, {'term': 'Papers', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to legal documents.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the legal context.'}, {'term': 'Commission', 'classification': 'Proper Noun', 'confidence': 0.9, 'reason': 'The term refers to a specific governmental body.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as the recipient of documents.'}, {'term': 'Secretary of the Commission', 'classification': 'Proper Noun', 'confidence': 0.9, 'reason': 'The term refers to a specific role within the Commission.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as the actor.'}, {'term': 'Named party', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to the entities involved in the legal process.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the service process.'}, {'term': 'Registered mail', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to a method of mailing.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the service process.'}, {'term': 'Certified mail', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to a method of mailing.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the service process.'}, {'term': 'Last address filed with the Commission', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to the address used for official correspondence.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the service process.'}], 'verb_symbols': ['are served', 'will forward', 'by'], 'element_name': 'Fact Type', 'transformed': 'A process, pleading, or other paper is forwarded by definition exactly one copy for each named party by the Secretary of the Commission.', 'type': 'Definitional', 'subtype': 'Complex concept structure rules', 'subtype_confidence': 0.5, 'subtype_explanation': 'The statement describes a process involving multiple components (process, pleadings, papers) and actions (forwarding by registered or certified mail), which suggests a complex concept structure. However, it does not fit neatly into a specific template, leading to a lower confidence score.', 'templates_ids': ['T12']}, {'doc_id': '§ 275.0-2', 'statement_id': 4, 'statement_title': 'Certification of service by the Secretary', 'statement': 'If the Secretary certifies that the Commission was served with process, pleadings, or other papers pursuant to paragraph (a)(1) of this section and forwarded these documents to a named party pursuant to paragraph (a)(2) of this section, this certification constitutes evidence of service upon that party.', 'sources': ['(a)(3)'], 'terms': [{'term': 'Secretary', 'classification': 'Proper Noun', 'confidence': 0.9, 'reason': 'The term refers to a specific role within the Commission.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as the actor.'}, {'term': 'Commission',  ...
# 2025-01-12 01:49:45 - INFO - 43
# 2025-01-12 01:49:45 - INFO - [({'doc_id': '§ 275.0-2', 'statement_id': '1', 'statement_title': 'Service of process on non-resident entities', 'statement': 'A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents.', 'sources': ['(a)'], 'subtype': 'Complex concept structure rules', 'templates_ids': ['T12']}, {'doc_id': '§ 275.0-2', 'statement_id': 1, 'statement_title': 'Service of process on non-resident entities', 'statement': 'A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents.', 'sources': ['(a)'], 'terms': [{'term': 'Person', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term is a general reference to an individual or entity.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as the subject.'}, {'term': 'Process', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to legal documents.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the legal context.'}, {'term': 'Pleadings', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to legal documents.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the legal context.'}, {'term': 'Papers', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to legal documents.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the legal context.'}, {'term': 'Non-resident investment adviser', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term is a specific type of entity described in the document.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as a recipient.'}, {'term': 'Non-resident general partner', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term is a specific type of entity described in the document.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as a recipient.'}, {'term': 'Non-resident managing agent', 'classification': 'Common Noun', 'confidence': 0.9, 'reason': 'The term is a specific type of entity described in the document.', 'extracted_confidence': 0.9, 'extracted_reason': 'The term is explicitly mentioned as a recipient.'}, {'term': 'Appointed agents', 'classification': 'Common Noun', 'confidence': 0.8, 'reason': 'The term refers to entities designated to receive service.', 'extracted_confidence': 0.8, 'extracted_reason': 'The term is part of the service process.'}], 'verb_symbols': ['may serve', 'by serving'], 'element_name': 'Fact Type', 'transformed': 'A person is by definition an entity that may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents.', 'type': 'Definitional', 'subtype': 'Formal extensional definitions', 'subtype_confidence': 0.6, 'subtype_explanation': 'The statement defines a method of serving process on non-resident entities by listing the entities involved (non-resident investment adviser, non-resident general partner, non-resident managing agent) and the method (serving appointed agents). It resembles a list of entities, aligning with the extensional definition template.', 'templates_ids': ['T8']}), ({'doc_id': '§ 275.0-2', 'statement_id': '2', 'statement_title': 'Furnishing documents to the Commission', 'statement': "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party,  ...
# Classification Report:
#                                    precision    recall  f1-score   support
#
# Complex concept cardinality rules       0.00      0.00      0.00         0
# Complex concept equivalence rules       0.00      0.00      0.00         0
#   Complex concept structure rules       0.92      0.46      0.61        24
#    Formal extensional definitions       0.54      0.73      0.62        30
#    Formal intensional definitions       0.85      0.70      0.77        74
#           Formal term definitions       0.00      0.00      0.00         0
#      Symbolic literal definitions       0.00      0.00      0.00         0
#           Valid value definitions       1.00      1.00      1.00        14
#
#                          accuracy                           0.70       142
#                         macro avg       0.41      0.36      0.38       142
#                      weighted avg       0.81      0.70      0.73       142

# %% [markdown]
# List not matched rules.

# %%
sorted([
    f'{doc["doc_id"]} - {doc["sources"]} - {doc["statement_id"]} - {doc["subtype"]} - {doc["templates_ids"]}'
    for doc in no_match
])
# Out:
# ["§ 275.0-2 - ['(a)(2)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-2 - ['(a)(2)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-2 - ['(a)(2)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-2 - ['(a)(3)'] - 4 - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(a)(3)'] - 4 - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(a)(3)'] - 4 - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-5 - ['(a)'] - 1 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 1 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 1 - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(a)'] - 1 - Formal term definitions - ['T7']",
#  "§ 275.0-5 - ['(a)'] - 1 - Standard format definitions - ['T18']",
#  "§ 275.0-5 - ['(a)'] - 1 - Standard format definitions - ['T18']",
#  "§ 275.0-5 - ['(a)'] - 1 - Standard format definitions - ['T18']",
#  "§ 275.0-5 - ['(a)'] - 1 - Standard format definitions - ['T18']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - 2 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(b)'] - 3 - Complex concept structure rules - ['T12']",
#  "§ 275.0-7 - ['(b)(1)(i)'] - 2 - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)'] - 3 - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)'] - 6 - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)'] - 6 - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(iii)(A)'] - 7 - Formal intensional definitions - ['T7']"]

# %% [markdown]
# List misclassifications

# %%
sorted([
    f'{doc[0]["doc_id"]} - {doc[0]["sources"]} - {doc[0]["statement"]} - {doc[0]["subtype"]} - {doc[0]["templates_ids"]} - {doc[1]["subtype"]} - {doc[1]["templates_ids"]}'
    for doc in mismatch_docs
])
# Out:
# ["§ 275.0-2 - ['(a)'] - A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)'] - A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)'] - A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)'] - A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)'] - A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)'] - A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)(1)'] - A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission's records. - Complex concept structure rules - ['T12'] - Complex concept cardinality rules - ['T12']",
#  "§ 275.0-2 - ['(a)(1)'] - A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission's records. - Complex concept structure rules - ['T12'] - Complex concept cardinality rules - ['T12']",
#  "§ 275.0-2 - ['(a)(1)'] - A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission's records. - Complex concept structure rules - ['T12'] - Complex concept cardinality rules - ['T12']",
#  "§ 275.0-2 - ['(a)(1)'] - A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission's records. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)(1)'] - A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission's records. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)(1)'] - A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission's records. - Complex concept structure rules - ['T12'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(3)'] - Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(d)'] - For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(d)'] - For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(d)'] - For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(d)'] - For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(d)'] - For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - The term small business or small organization for purposes of the Investment Advisers Act of 1940 shall mean an investment adviser that has assets under management of less than $25 million, or such higher amount as the Commission may by rule deem appropriate. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(a)(3)'] - An investment adviser does not control, is not controlled by, and is not under common control with another investment adviser that has assets under management of $25 million or more, or any person (other than a natural person) that had total assets of $5 million or more on the last day of the most recent fiscal year. - Complex concept structure rules - ['T12'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)(A)'] - A person is presumed to control a corporation if the person directly or indirectly has the right to vote 25 percent or more of a class of the corporation's voting securities. - Formal intensional definitions - ['T7'] - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-7 - ['(b)(1)(i)(A)'] - A person is presumed to control a corporation if the person directly or indirectly has the right to vote 25 percent or more of a class of the corporation's voting securities. - Formal intensional definitions - ['T7'] - Complex concept structure rules - ['T12']",
#  "§ 275.0-7 - ['(b)(1)(ii)'] - A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iii)'] - A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iii)'] - A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)'] - Total assets means the total assets as shown on the balance sheet of the investment adviser or other person described above under paragraph (a)(3) of this section, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)'] - Total assets means the total assets as shown on the balance sheet of the investment adviser or other person described above under paragraph (a)(3) of this section, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)'] - Total assets means the total assets as shown on the balance sheet of the investment adviser or other person described above under paragraph (a)(3) of this section, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']"]

# %% [markdown]
# ##### Terms

# %%
# To get per doc_id use the pred_fitered_list
#pred_fitered_list = [pred_doc for pred_doc in pred_terms_classify if pred_doc["doc_id"] == "§ 275.0-7"]
pred_fitered_list = pred_terms_classify # All

# %%
key = "subtype"
element_name = "terms"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    pred_fitered_list,
    true_terms_classify,
    key,
    element_name,
)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))

logger.info(len(no_match))
logger.info(no_match)
logger.info(len(mismatch_docs))
logger.info(mismatch_docs)
# Out:
# 2025-01-12 01:49:45 - INFO - 61
# 2025-01-12 01:49:45 - INFO - [{'doc_id': '§ 275.0-2', 'statement_id': 'Principal office', 'definition': 'Has the same meaning as in § 275.203A-3(c) of this chapter.', 'isLocalScope': True, 'sources': ['(b)(2)', '(b)(3)'], 'element_name': 'Term', 'transformed': 'A principal office is by definition the same as in § 275.203A-3(c) of this chapter.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.5, 'explanation': 'The statement refers to another section for its definition, indicating a formal definition exists elsewhere. This suggests an intensional definition, but without the specific content, the confidence is lower.', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Investment adviser', 'definition': 'An investment adviser is a small business or small organization under the Investment Advisers Act of 1940 if it meets certain criteria.', 'isLocalScope': True, 'sources': ['(a)(3)', '(a)', '(a)(2)', '(a)(1)', '(b)(2)'], 'element_name': 'Term', 'transformed': 'An investment adviser is by definition a small business or small organization under the Investment Advisers Act of 1940 that meets certain criteria.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'investment adviser' as a type of 'small business or small organization' with specific criteria, fitting the template of a formal intensional definition where a term is defined by a hypernym and distinguishing characteristics.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Assets under management', 'definition': 'Assets under management are defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV.', 'isLocalScope': True, 'sources': ['(a)(1)', '(a)', '(a)(3)'], 'element_name': 'Term', 'transformed': 'Assets under management is by definition of that Section 203A(a)(3) of the Act.', 'type': 'Definitional', 'subtype': 'Formal extensional definitions', 'confidence': 0.6, 'explanation': 'The statement refers to a definition provided elsewhere (Section 203A(a)(3)), suggesting an extensional definition by listing or referencing a complete set of criteria or components, but lacks explicit listing in the statement itself.', 'templates_ids': ['T8']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Total assets', 'definition': 'Total assets means the total assets as shown on the balance sheet of the investment adviser or other person, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger.', 'isLocalScope': True, 'sources': ['(b)(2)', '(a)', '(a)(3)', '(a)(2)'], 'element_name': 'Term', 'transformed': 'Total assets is by definition the total assets that are shown on the balance sheet of the investment adviser or other person, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement provides a definition of 'total assets' by specifying the conditions under which the term applies, using a hypernym ('total assets') and distinguishing characteristics (balance sheet conditions).", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Control', 'definition': 'Control means the power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise.', 'isLocalScope': True, 'sources': ['(b)(1)', '(a)', '(a)(3)'], 'element_name': 'Term', 'transformed': 'Control is by definition the power that directs the management or policies of a person, whether through ownership of securities, by contract, or otherwise.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'control' by specifying the conditions an ...
# 2025-01-12 01:49:45 - INFO - 66
# 2025-01-12 01:49:45 - INFO - [({'doc_id': '§ 275.0-2', 'statement_id': 'Non-resident', 'statement': 'An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States.', 'sources': ['(b)(2)'], 'subtype': 'Formal intensional definitions', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-2', 'statement_id': 'Non-resident', 'definition': 'An individual who resides in any place not subject to the jurisdiction of the United States; a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States; and a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States.', 'isLocalScope': True, 'sources': ['(b)(2)'], 'element_name': 'Term', 'transformed': 'A non-resident is by definition an individual who resides in any place not subject to the jurisdiction of the United States, a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States, or a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States.', 'type': 'Definitional', 'subtype': 'Formal extensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Non-resident' by listing all possible entities (individual, corporation, partnership, or unincorporated organization) that fall under this category based on their location relative to U.S. jurisdiction. This aligns with the extensional definition template by listing subsets of the term 'Non-resident'.", 'templates_ids': ['T8']}), ({'doc_id': '§ 275.0-7', 'statement_id': 'Small business', 'statement': 'An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions.', 'sources': ['(a)'], 'subtype': 'Valid value definitions', 'templates_ids': ['T15']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Small business', 'definition': 'A small business or small organization for purposes of the Investment Advisers Act of 1940 is an investment adviser that meets certain criteria.', 'isLocalScope': True, 'sources': ['(a)'], 'element_name': 'Term', 'transformed': 'A small business or small organization is by definition an investment adviser that meets certain criteria.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'Small business' by specifying it as an 'investment adviser' (hypernym) that meets certain criteria (distinguishing characteristics), fitting the intensional definition template.", 'templates_ids': ['T7']}), ({'doc_id': '§ 275.0-7', 'statement_id': 'Small organization', 'statement': 'An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions.', 'sources': ['(a)'], 'subtype': 'Valid value definitions', 'templates_ids': ['T15']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Small organization', 'definition': 'A small business or small organization for purposes of the Investment Advisers Act of 1940 is an investment adviser that meets certain criteria.', 'isLocalScope': True, 'sources': ['(a)'], 'element_name': 'Term', 'transformed': 'A small business or small organization is by definition an investment adviser that meets certain criteria.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'small business or small organization' as a type of 'investment adviser' with specific criteria, ...
# Classification Report:
#                                  precision    recall  f1-score   support
#
# Complex concept structure rules       0.00      0.00      0.00         0
#     Data calculation algorithms       0.00      0.00      0.00         5
#  Formal extensional definitions       0.00      0.00      0.00         5
#  Formal intensional definitions       0.76      0.80      0.78       137
#         Formal term definitions       0.00      0.00      0.00         0
#     Standard format definitions       0.00      0.00      0.00         0
#    Symbolic literal definitions       0.00      0.00      0.00         0
#         Valid value definitions       0.33      0.03      0.06        29
#
#                        accuracy                           0.62       176
#                       macro avg       0.14      0.10      0.11       176
#                    weighted avg       0.65      0.62      0.62       176

# %% [markdown]
# List not matched rules.

# %%
sorted([
    f'{doc["doc_id"]} - {doc["sources"]} - {doc["statement_id"]} - {doc["subtype"]} - {doc["templates_ids"]}'
    for doc in no_match
])
# Out:
# ["§ 275.0-2 - ['(a)'] - Appointed agents - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(1)', '(a)'] - Non-resident general partner - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(1)', '(a)'] - Non-resident investment adviser - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(1)', '(a)'] - Non-resident managing agent - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(1)', '(a)(3)', '(a)(2)'] - Named party - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(1)', '(a)(3)', '(a)(2)'] - Process, pleadings, or papers - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(a)(2)'] - Last address filed with the Commission - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(2)'] - Registered or certified mail - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(1)', '(a)(1)', '(a)'] - Person - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(1)', '(b)(2)'] - Unincorporated organization or association - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Place of business - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Principal office - Complex concept equivalence rules - ['T13']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Principal office - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Principal office - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Principal office - Formal term definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Principal office and place of business - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(2)', '(b)(3)'] - Principal office and place of business - Formal term definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(c)(1)'] - Interested person - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(c)(1)'] - Interested person - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'] - Hearing - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'] - Hearing - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'] - Matter - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)(2)'] - Own motion - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)(2)'] - Own motion - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)', '(a)(3)'] - Assets under management - Formal term definitions - ['T7']",
#  "§ 275.0-7 - ['(a)', '(b)(1)(iii)', '(b)(1)(ii)', '(b)(1)(iv)', '(b)(1)(i)', '(b)(2)'] - Person - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)(1)', '(a)', '(a)(3)'] - Assets under management - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(a)(1)', '(a)', '(a)(3)'] - Assets under management - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(a)(1)', '(a)', '(a)(3)'] - Assets under management - Formal term definitions - ['T7']",
#  "§ 275.0-7 - ['(a)(1)', '(a)', '(a)(3)'] - Assets under management - Symbolic literal definitions - ['T9']",
#  "§ 275.0-7 - ['(a)(1)', '(a)', '(a)(3)'] - Assets under management - Valid value definitions - ['T15']",
#  "§ 275.0-7 - ['(a)(3)', '(a)', '(a)(2)', '(a)(1)', '(b)(2)'] - Investment adviser - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)(3)', '(a)', '(a)(2)', '(a)(1)', '(b)(2)'] - Investment adviser - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)(3)', '(a)', '(a)(2)', '(a)(1)', '(b)(2)'] - Investment adviser - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)', '(a)', '(a)(3)'] - Control - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)', '(a)', '(a)(3)'] - Control - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)', '(a)'] - Control - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)', '(b)(1)(i)(A)', '(b)(1)(ii)', '(b)(1)(iv)', '(b)(1)(iii)(A)'] - Person - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)'] - Power - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)'] - Power - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)', '(b)(1)(iii)'] - Right to vote - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)'] - Corporation - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)'] - Voting securities - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)(A)'] - Voting securities - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(i)(A)'] - Voting securities - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(ii)', '(b)(1)(iii)'] - Capital - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(ii)', '(b)(1)(iii)'] - Right to receive upon dissolution - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(ii)', '(b)(1)(iii)'] - Right to receive upon dissolution - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(ii)', '(b)(1)(iii)'] - Right to receive upon dissolution - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(ii)', '(b)(1)(iii)'] - Right to receive upon dissolution - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(iii)(A)', '(b)(1)(i)(A)'] - Right to vote - Valid value definitions - ['T15']",
#  "§ 275.0-7 - ['(b)(1)(iii)(A)'] - Limited liability company - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)', '(a)(3)', '(a)(2)'] - Total assets - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)', '(a)', '(a)(3)', '(a)(2)'] - Total assets - Symbolic literal definitions - ['T9']",
#  "§ 275.0-7 - ['(b)(2)', '(a)'] - Investment adviser - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)'] - Investment adviser - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)', '(a)'] - Total assets - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)'] - Total assets - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(3)', '(a)(2)'] - Total assets - Symbolic literal definitions - ['T9']",
#  "§ 275.0-7 - ['(b)(2)'] - Balance sheet - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)'] - Subsidiaries - Formal intensional definitions - ['T7']"]

# %% [markdown]
# List misclassifications

# %%
sorted([
    f'{doc[0]["doc_id"]} - {doc[0]["sources"]} - {doc[0]["statement"]} - {doc[0]["subtype"]} - {doc[0]["templates_ids"]} - {doc[1]["subtype"]} - {doc[1]["templates_ids"]}'
    for doc in mismatch_docs
])
# Out:
# ["§ 275.0-2 - ['(a)(1)'] - Records maintained by the Commission, which include copies of process, pleadings, or other papers served. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(1)'] - Any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Standard format definitions - ['T18']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(a)'] - The process that begins when a notice is published in the Federal Register indicating the earliest date upon which an order disposing of the matter may be entered. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(a)'] - The process that begins when a notice is published in the Federal Register indicating the earliest date upon which an order disposing of the matter may be entered. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - An order issued by the Commission under the Act. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal term definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(ii)'] - A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership. - Formal intensional definitions - ['T7'] - Valid value definitions - ['T15']",
#  "§ 275.0-7 - ['(b)(1)(ii)'] - A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership. - Formal intensional definitions - ['T7'] - Valid value definitions - ['T15']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal intensional definitions - ['T7']"]

# %% [markdown]
# Misclassification with the same template

# %%
key = "templates_ids"
element_name = "terms"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    pred_terms_classify,
    true_terms_classify,
    key,
    element_name,
)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))

logger.info(len(no_match))
logger.info(no_match)
logger.info(len(mismatch_docs))
logger.info(mismatch_docs)
# Out:
# 2025-01-12 01:49:46 - INFO - 61
# 2025-01-12 01:49:46 - INFO - [{'doc_id': '§ 275.0-2', 'statement_id': 'Principal office', 'definition': 'Has the same meaning as in § 275.203A-3(c) of this chapter.', 'isLocalScope': True, 'sources': ['(b)(2)', '(b)(3)'], 'element_name': 'Term', 'transformed': 'A principal office is by definition the same as in § 275.203A-3(c) of this chapter.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.5, 'explanation': 'The statement refers to another section for its definition, indicating a formal definition exists elsewhere. This suggests an intensional definition, but without the specific content, the confidence is lower.', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Investment adviser', 'definition': 'An investment adviser is a small business or small organization under the Investment Advisers Act of 1940 if it meets certain criteria.', 'isLocalScope': True, 'sources': ['(a)(3)', '(a)', '(a)(2)', '(a)(1)', '(b)(2)'], 'element_name': 'Term', 'transformed': 'An investment adviser is by definition a small business or small organization under the Investment Advisers Act of 1940 that meets certain criteria.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'investment adviser' as a type of 'small business or small organization' with specific criteria, fitting the template of a formal intensional definition where a term is defined by a hypernym and distinguishing characteristics.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Assets under management', 'definition': 'Assets under management are defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV.', 'isLocalScope': True, 'sources': ['(a)(1)', '(a)', '(a)(3)'], 'element_name': 'Term', 'transformed': 'Assets under management is by definition of that Section 203A(a)(3) of the Act.', 'type': 'Definitional', 'subtype': 'Formal extensional definitions', 'confidence': 0.6, 'explanation': 'The statement refers to a definition provided elsewhere (Section 203A(a)(3)), suggesting an extensional definition by listing or referencing a complete set of criteria or components, but lacks explicit listing in the statement itself.', 'templates_ids': ['T8']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Total assets', 'definition': 'Total assets means the total assets as shown on the balance sheet of the investment adviser or other person, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger.', 'isLocalScope': True, 'sources': ['(b)(2)', '(a)', '(a)(3)', '(a)(2)'], 'element_name': 'Term', 'transformed': 'Total assets is by definition the total assets that are shown on the balance sheet of the investment adviser or other person, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement provides a definition of 'total assets' by specifying the conditions under which the term applies, using a hypernym ('total assets') and distinguishing characteristics (balance sheet conditions).", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Control', 'definition': 'Control means the power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise.', 'isLocalScope': True, 'sources': ['(b)(1)', '(a)', '(a)(3)'], 'element_name': 'Term', 'transformed': 'Control is by definition the power that directs the management or policies of a person, whether through ownership of securities, by contract, or otherwise.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'control' by specifying the conditions an ...
# 2025-01-12 01:49:46 - INFO - 66
# 2025-01-12 01:49:46 - INFO - [({'doc_id': '§ 275.0-2', 'statement_id': 'Non-resident', 'statement': 'An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States.', 'sources': ['(b)(2)'], 'subtype': 'Formal intensional definitions', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-2', 'statement_id': 'Non-resident', 'definition': 'An individual who resides in any place not subject to the jurisdiction of the United States; a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States; and a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States.', 'isLocalScope': True, 'sources': ['(b)(2)'], 'element_name': 'Term', 'transformed': 'A non-resident is by definition an individual who resides in any place not subject to the jurisdiction of the United States, a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States, or a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States.', 'type': 'Definitional', 'subtype': 'Formal extensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Non-resident' by listing all possible entities (individual, corporation, partnership, or unincorporated organization) that fall under this category based on their location relative to U.S. jurisdiction. This aligns with the extensional definition template by listing subsets of the term 'Non-resident'.", 'templates_ids': ['T8']}), ({'doc_id': '§ 275.0-7', 'statement_id': 'Small business', 'statement': 'An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions.', 'sources': ['(a)'], 'subtype': 'Valid value definitions', 'templates_ids': ['T15']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Small business', 'definition': 'A small business or small organization for purposes of the Investment Advisers Act of 1940 is an investment adviser that meets certain criteria.', 'isLocalScope': True, 'sources': ['(a)'], 'element_name': 'Term', 'transformed': 'A small business or small organization is by definition an investment adviser that meets certain criteria.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'Small business' by specifying it as an 'investment adviser' (hypernym) that meets certain criteria (distinguishing characteristics), fitting the intensional definition template.", 'templates_ids': ['T7']}), ({'doc_id': '§ 275.0-7', 'statement_id': 'Small organization', 'statement': 'An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions.', 'sources': ['(a)'], 'subtype': 'Valid value definitions', 'templates_ids': ['T15']}, {'doc_id': '§ 275.0-7', 'statement_id': 'Small organization', 'definition': 'A small business or small organization for purposes of the Investment Advisers Act of 1940 is an investment adviser that meets certain criteria.', 'isLocalScope': True, 'sources': ['(a)'], 'element_name': 'Term', 'transformed': 'A small business or small organization is by definition an investment adviser that meets certain criteria.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'small business or small organization' as a type of 'investment adviser' with specific criteria, ...
# Classification Report:
#               precision    recall  f1-score   support
#
#      ['T12']       0.00      0.00      0.00         0
#      ['T15']       0.33      0.03      0.06        29
#      ['T16']       0.00      0.00      0.00         5
#      ['T18']       0.00      0.00      0.00         0
#       ['T7']       0.76      0.80      0.78       137
#       ['T8']       0.00      0.00      0.00         5
#       ['T9']       0.00      0.00      0.00         0
#
#     accuracy                           0.62       176
#    macro avg       0.16      0.12      0.12       176
# weighted avg       0.64      0.62      0.61       176

# %%
sorted([
    f'{doc[0]["doc_id"]} - {doc[0]["sources"]} - {doc[0]["statement"]} - {doc[0]["subtype"]} - {doc[0]["templates_ids"]} - {doc[1]["subtype"]} - {doc[1]["templates_ids"]}'
    for doc in mismatch_docs
])
# Out:
# ["§ 275.0-2 - ['(a)(1)'] - Records maintained by the Commission, which include copies of process, pleadings, or other papers served. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party. - Formal extensional definitions - ['T8'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(b)(1)'] - Any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-2 - ['(b)(2)'] - An individual, corporation, partnership, or other unincorporated organization or association that resides or has its principal office and place of business in any place not subject to the jurisdiction of the United States. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)', '(b)'] - The timeframe specified in the notice during which interested persons can submit facts or request a hearing. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Complex concept structure rules - ['T12']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Standard format definitions - ['T18']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(a)'] - A publication in the Federal Register indicating the initiation of the proceeding and the earliest date for an order. - Formal intensional definitions - ['T7'] - Symbolic literal definitions - ['T9']",
#  "§ 275.0-5 - ['(a)'] - The process that begins when a notice is published in the Federal Register indicating the earliest date upon which an order disposing of the matter may be entered. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(a)'] - The process that begins when a notice is published in the Federal Register indicating the earliest date upon which an order disposing of the matter may be entered. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - An order issued by the Commission under the Act. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-5 - ['(d)'] - Any application for an order of the Commission under the Act, excluding applications for registration as an investment adviser. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(a)'] - An investment adviser with assets under management of less than $25 million, or such higher amount as the Commission may deem appropriate, and other specific conditions. - Valid value definitions - ['T15'] - Formal term definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(1)(ii)'] - A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership. - Formal intensional definitions - ['T7'] - Valid value definitions - ['T15']",
#  "§ 275.0-7 - ['(b)(1)(ii)'] - A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership. - Formal intensional definitions - ['T7'] - Valid value definitions - ['T15']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(1)(iv)'] - A person is presumed to control a trust if the person is a trustee or managing agent of the trust. - Formal intensional definitions - ['T7'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal extensional definitions - ['T8']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-7 - ['(b)(2)', '(a)(2)'] - The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger. - Data calculation algorithms - ['T16'] - Formal intensional definitions - ['T7']"]

# %% [markdown]
# Investigating mismatches

# %% [markdown]
# How many terms in both sides?

# %%
len(pred_terms_classify), len(true_terms_classify)
# Out:
# (237, 28)

# %% [markdown]
# Looking for duplicate terms

# %%
# Track seen items and duplicates
seen_terms = set()
duplicates = []

# Check for duplicates by specified fields
for term in true_terms_classify:
    # Create a unique key from the specified fields
    key = (
        term["doc_id"],
        term["statement_id"],
        term["statement"],
        tuple(sorted(term["sources"])),
    )
    if key in seen_terms:
        duplicates.append(term)
    else:
        seen_terms.add(key)

# Output results
if duplicates:
    print("Duplicate entries found in true_terms based on specified fields:")
    for dup in duplicates:
        print(dup)
else:
    print("No duplicate entries found in true_terms based on specified fields.")
# Out:
# No duplicate entries found in true_terms based on specified fields.

# %% [markdown]
# ##### Names

# %%
# To get per doc_id use the pred_fitered_list
#pred_fitered_list = [pred_doc for pred_doc in pred_names_classify if pred_doc["doc_id"] == "§ 275.0-5"]
pred_fitered_list = pred_names_classify # All

# %%
key = "subtype"
element_name = "names"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    pred_fitered_list, true_names_classify, key, element_name
)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))

logger.info(len(no_match))
logger.info(no_match)
logger.info(len(mismatch_docs))
logger.info(mismatch_docs)
# Out:
# 2025-01-12 01:49:46 - INFO - 6
# 2025-01-12 01:49:46 - INFO - [{'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for initiating proceedings and making orders under the Act.', 'isLocalScope': False, 'sources': ['(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for initiating proceedings and making orders under the Act.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Commission' as 'the regulatory body', which is a hypernym. The qualifying clause 'responsible for initiating proceedings and making orders under the Act' specifies its role, fitting the formal intensional definition template.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The Commission refers to the entity responsible for ordering hearings and disposing of matters under the Act.', 'isLocalScope': False, 'sources': ['(c)', '(a)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition the entity that is responsible for ordering hearings and disposing of matters under the Act.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'The Commission' as an 'entity', which serves as the hypernym. The clause 'responsible for ordering hearings and disposing of matters under the Act' provides the distinguishing characteristics, fitting the formal intensional definition template well.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for issuing orders and conducting hearings under the Act.', 'isLocalScope': False, 'sources': ['(c)', '(a)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for issuing orders and conducting hearings under the Act.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Commission' as a 'regulatory body', which is a hypernym, and specifies its responsibilities, providing distinguishing characteristics. This aligns well with a formal intensional definition.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for initiating proceedings and making orders under the Act.', 'isLocalScope': True, 'sources': ['(c)', '(a)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for initiating proceedings and making orders under the Act.', 'type': 'Definitional', 'subtype': 'Formal term definitions', 'confidence': 0.8, 'explanation': "The statement defines 'Commission' as a regulatory body with specific responsibilities. It fits the formal term definition template by identifying the role and responsibilities of the 'Commission'. The hypernym 'regulatory body' is present, but the distinguishing characteristics are implied rather than explicitly stated.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-2', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for overseeing the service of process, pleadings, or papers on non-resident entities.', 'isLocalScope': True, 'sources': ['(a)(1)', '(a)(3)', '(a)(2)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for overseeing the service of process, pleadings, or papers on non-resident entities.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'The regulatory body' as a specific entity responsible for certain actions, fitting the template of a formal intensional definition by specifying the role and responsibilities of the 'Commission' as a hypernym.", 'templates_ids ...
# 2025-01-12 01:49:46 - INFO - 4
# 2025-01-12 01:49:46 - INFO - [({'doc_id': '§ 275.0-5', 'statement_id': 'Federal Register', 'statement': 'The official journal where the notice of initiation of the proceeding is published.', 'sources': ['(a)'], 'subtype': 'Formal intensional definitions', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Federal Register', 'definition': 'The publication where the notice of the initiation of the proceeding will be published.', 'isLocalScope': True, 'sources': ['(a)'], 'element_name': 'Name', 'transformed': 'A Federal Register is by definition a publication that is where the notice of the initiation of the proceeding will be published.', 'type': 'Definitional', 'subtype': 'Formal term definitions', 'confidence': 0.7, 'explanation': "The statement defines 'Federal Register' as a publication where notices are published. It aligns with a formal term definition as it specifies the role of the 'Federal Register' in the context of proceedings. However, it lacks a clear hypernym and distinguishing characteristics, which reduces confidence.", 'templates_ids': ['T7']}), ({'doc_id': '§ 275.0-5', 'statement_id': 'Act', 'statement': 'The legislation under which the Commission operates and applications are filed.', 'sources': ['(d)'], 'subtype': 'Formal intensional definitions', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Act', 'definition': 'The legislation under which the Commission operates and makes orders.', 'isLocalScope': True, 'sources': ['(d)'], 'element_name': 'Name', 'transformed': 'An Act is by definition the legislation under which the Commission operates and makes orders.', 'type': 'Definitional', 'subtype': 'Formal term definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Act' as the legislation governing the Commission's operations. It aligns well with the formal term definition template, with 'legislation' as the hypernym and the context of governing the Commission as the distinguishing characteristic.", 'templates_ids': ['T7']}), ({'doc_id': '§ 275.0-2', 'statement_id': 'Secretary of the Commission', 'statement': 'The Secretary of the Commission is responsible for forwarding copies of process, pleadings, or other papers to each named party by registered or certified mail.', 'sources': ['(a)(2)'], 'subtype': 'Formal term definitions', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-2', 'statement_id': 'Secretary of the Commission', 'definition': 'The Secretary responsible for forwarding copies of served documents to named parties.', 'isLocalScope': True, 'sources': ['(a)(2)'], 'element_name': 'Name', 'transformed': 'A Secretary of the Commission is by definition a Secretary that is responsible for forwarding copies of served documents to named parties.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.7, 'explanation': "The statement defines 'The Secretary' by their responsibility, aligning with a formal intensional definition by specifying the role and duties, which serves as a hypernym.", 'templates_ids': ['T7']}), ({'doc_id': '§ 275.0-2', 'statement_id': 'Secretary', 'statement': 'The Secretary of the Commission is responsible for forwarding copies of process, pleadings, or other papers to each named party by registered or certified mail.', 'sources': ['(a)(3)'], 'subtype': 'Formal term definitions', 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-2', 'statement_id': 'Secretary', 'definition': 'The Secretary of the Commission who is responsible for forwarding copies of served documents to named parties.', 'isLocalScope': True, 'sources': ['(a)(3)'], 'element_name': 'Name', 'transformed': 'A Secretary of the Commission is by definition the Secretary who is responsible for forwarding copies of served documents to named parties.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "This statement clearly defines 'The Secretary of the Commission' by their specific responsibility, fitt ...
# Classification Report:
#                                 precision    recall  f1-score   support
#
# Formal intensional definitions       0.85      0.85      0.85        13
#        Formal term definitions       0.50      0.50      0.50         4
#
#                       accuracy                           0.76        17
#                      macro avg       0.67      0.67      0.67        17
#                   weighted avg       0.76      0.76      0.76        17

# %% [markdown]
# List not matched rules.

# %%
sorted([
    f'{doc["doc_id"]} - {doc["sources"]} - {doc["statement_id"]} - {doc["subtype"]} - {doc["templates_ids"]}'
    for doc in no_match
])
# Out:
# ["§ 275.0-2 - ['(a)(1)', '(a)(3)', '(a)(2)'] - Commission - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(b)'] - Commission - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(b)'] - Commission - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(b)'] - Commission - Formal term definitions - ['T7']",
#  "§ 275.0-5 - ['(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'] - Commission - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(d)', '(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'] - Commission - Formal intensional definitions - ['T7']"]

# %% [markdown]
# List misclassifications

# %%
sorted([
    f'{doc[0]["doc_id"]} - {doc[0]["sources"]} - {doc[0]["statement_id"]} - {doc[0]["subtype"]} - {doc[0]["templates_ids"]} - {doc[1]["subtype"]} - {doc[1]["templates_ids"]}'
    for doc in mismatch_docs
])
# Out:
# ["§ 275.0-2 - ['(a)(2)'] - Secretary of the Commission - Formal term definitions - ['T7'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-2 - ['(a)(3)'] - Secretary - Formal term definitions - ['T7'] - Formal intensional definitions - ['T7']",
#  "§ 275.0-5 - ['(a)'] - Federal Register - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']",
#  "§ 275.0-5 - ['(d)'] - Act - Formal intensional definitions - ['T7'] - Formal term definitions - ['T7']"]

# %% [markdown]
# Misclassification with the same template

# %%
key = "templates_ids"
element_name = "names"

cm_df, report_df, no_match, mismatch_docs = generate_metrics_with_report(
    pred_names_classify, true_names_classify, key, element_name
)

dataframes_list.append((f"{element_name} - CM {key}", cm_df))
dataframes_list.append((f"{element_name} - CR {key}", report_df))

logger.info(len(no_match))
logger.info(no_match)
logger.info(len(mismatch_docs))
logger.info(mismatch_docs)
# Out:
# /home/adsantos/miniconda3/envs/ipt-cfr2sbvr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# 2025-01-12 01:49:46 - INFO - 6
# 2025-01-12 01:49:46 - INFO - [{'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for initiating proceedings and making orders under the Act.', 'isLocalScope': False, 'sources': ['(c)', '(a)', '(c)(1)', '(c)(2)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for initiating proceedings and making orders under the Act.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Commission' as 'the regulatory body', which is a hypernym. The qualifying clause 'responsible for initiating proceedings and making orders under the Act' specifies its role, fitting the formal intensional definition template.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The Commission refers to the entity responsible for ordering hearings and disposing of matters under the Act.', 'isLocalScope': False, 'sources': ['(c)', '(a)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition the entity that is responsible for ordering hearings and disposing of matters under the Act.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'The Commission' as an 'entity', which serves as the hypernym. The clause 'responsible for ordering hearings and disposing of matters under the Act' provides the distinguishing characteristics, fitting the formal intensional definition template well.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for issuing orders and conducting hearings under the Act.', 'isLocalScope': False, 'sources': ['(c)', '(a)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for issuing orders and conducting hearings under the Act.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.9, 'explanation': "The statement defines 'Commission' as a 'regulatory body', which is a hypernym, and specifies its responsibilities, providing distinguishing characteristics. This aligns well with a formal intensional definition.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-5', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for initiating proceedings and making orders under the Act.', 'isLocalScope': True, 'sources': ['(c)', '(a)', '(b)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for initiating proceedings and making orders under the Act.', 'type': 'Definitional', 'subtype': 'Formal term definitions', 'confidence': 0.8, 'explanation': "The statement defines 'Commission' as a regulatory body with specific responsibilities. It fits the formal term definition template by identifying the role and responsibilities of the 'Commission'. The hypernym 'regulatory body' is present, but the distinguishing characteristics are implied rather than explicitly stated.", 'templates_ids': ['T7']}, {'doc_id': '§ 275.0-2', 'statement_id': 'Commission', 'definition': 'The regulatory body responsible for overseeing the service of process, pleadings, or papers on non-resident entities.', 'isLocalScope': True, 'sources': ['(a)(1)', '(a)(3)', '(a)(2)'], 'element_name': 'Name', 'transformed': 'A Commission is by definition a regulatory body that is responsible for overseeing the service of process, pleadings, or papers on non-resident entities.', 'type': 'Definitional', 'subtype': 'Formal intensional definitions', 'confidence': 0.8, 'explanation': "The statement defines 'The regulatory body' as a specific entity responsible for certain actions, fitting the template of a formal intensional definition by specifying the role and responsibilities of the 'Commission' as a hypernym.", 'templates_ids ...
# 2025-01-12 01:49:46 - INFO - 0
# 2025-01-12 01:49:46 - INFO - []
# Classification Report:
#               precision    recall  f1-score   support
#
#       ['T7']       1.00      1.00      1.00        17
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17

# %% [markdown]
# ##### Save all accumulated DataFrames at the end

# %%
save_metrics_to_excel(dataframes_list, output_excel_path=f"{config['DEFAULT_OUTPUT_DIR']}/comparison_results.xlsx")

# %% [markdown]
# ## Discussion
#
# TODO
