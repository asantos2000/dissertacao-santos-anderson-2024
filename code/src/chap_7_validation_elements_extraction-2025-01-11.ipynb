# %% [markdown]
# <a href="https://colab.research.google.com/github/asantos2000/master-degree-santos-anderson/blob/main/code/src/chap_7_validation_elements_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Validation
#
# Validation of algorithms and transformation results.
#
# Chap 7. Validação
# - Section 7.3 Resultados
#     - Section 7.3.2 Semantic Annotation
#         - Extração de regras operativas, fatos, termos e nomes
#
# > To run again, restore checkpoint directory with files from `checkpoints_extract` directory.

# %% [markdown]
# ## Google colab

# %%
# %load_ext autoreload
# %autoreload 2

import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  # !rm -rf cfr2sbvr configuration checkpoint
  # !git clone https://github.com/asantos2000/master-degree-santos-anderson.git cfr2sbvr
  # %pip install -r cfr2sbvr/code/requirements.txt
  # !cp -r cfr2sbvr/code/src/configuration .
  # !cp -r cfr2sbvr/code/src/checkpoint .
  # !cp -r cfr2sbvr/code/config.colab.yaml config.yaml
  DEFAULT_CONFIG_FILE="config.yaml"
else:
  DEFAULT_CONFIG_FILE="../config.yaml"

# %% [markdown]
# ## Imports

# %%
# Standard library imports
from collections import defaultdict
from datetime import datetime
import json
import time
from typing import List
import os
import re
from collections import Counter

# Third-party imports
import jellyfish
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import statsmodels.api as sm
from openai import OpenAI
from scipy.spatial.distance import cosine
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)
import seaborn as sns
import xlsxwriter
from openpyxl import load_workbook
import openpyxl
from pydantic import BaseModel, Field
from deepdiff import DeepSearch


# Local application/library-specific imports
import checkpoint.main as checkpoint
from checkpoint.main import (
    normalize_str,
    restore_checkpoint,
    get_all_checkpoints,
    Document,
)
import configuration.main as configuration
import logging_setup.main as logging_setup
import token_estimator.main as token_estimator
from token_estimator.main import estimate_tokens
import llm_query.main as llm_query
from llm_query.main import query_instruct_llm

DEV_MODE = True

if DEV_MODE:
    # Development mode
    import importlib

    importlib.reload(configuration)
    importlib.reload(logging_setup)
    importlib.reload(checkpoint)
    importlib.reload(token_estimator)
    importlib.reload(llm_query)

# # Ensure plots are displayed inline if using a Jupyter notebook
# %matplotlib inline

# from IPython.display import display

# %% [markdown]
# ## Settings

# %% [markdown]
# ### Configuration

# %%
# Load configuration
config = configuration.load_config(DEFAULT_CONFIG_FILE)

# %% [markdown]
# ### Logging

# %%
logger = logging_setup.setting_logging(config["DEFAULT_LOG_DIR"], config["LOG_LEVEL"])
# Out:
# 2025-01-11 17:39:08 - INFO - Logging is set up with daily rotation.

# %% [markdown]
# ## Checkpoints

# %% [markdown]
# ### Restore the checkpoint

# %%
# Restore the checkpoint

# To run after extraction
last_checkpoint = configuration.get_last_filename(
    config["DEFAULT_CHECKPOINT_DIR"], "documents", "json"
)

logger.info(f"{last_checkpoint=}")

config["DEFAULT_CHECKPOINT_FILE"] = last_checkpoint

manager = restore_checkpoint(filename=config["DEFAULT_CHECKPOINT_FILE"])
# Out:
# 2025-01-11 17:39:39 - INFO - last_checkpoint='../data/checkpoints/documents-2025-01-11-10.json'
# 2025-01-11 17:39:39 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-10.json
# 2025-01-11 17:39:39 - INFO - Checkpoint restored from ../data/checkpoints/documents-2025-01-11-10.json.

# %% [markdown]
# ## General functions

# %%
def group_and_count_not_in_true(pred_terms_list, true_terms_list):
    # Dictionary to store counts of terms not in true_terms_list
    not_in_true_counts = defaultdict(int)

    # Iterate through pred_terms_list
    for term in pred_terms_list:
        if term not in true_terms_list:
            not_in_true_counts[term] += 1

    # Sort the dictionary by key (term) in ascending order and return it
    sorted_counts = dict(sorted(not_in_true_counts.items(), key=lambda x: x[0]))
    return sorted_counts

# %%
def extract_index_and_key(s):
    # Define a regular expression pattern to match the index and key
    pattern = r"root\[(\d+)\]\['(\w+)'\]"

    # Use re.match to find the pattern in the string
    match = re.match(pattern, s)

    if match:
        # Extract the index and key from the match groups
        index = int(match.group(1))
        key = match.group(2)
        return index, key
    else:
        raise ValueError("String format is incorrect")

# %%
def save_metrics_to_excel(dataframes_list, output_excel_path):
    """
    Saves multiple DataFrames to an Excel file, each as a separate sheet.

    Args:
        dataframes_list (list): List of tuples, where each tuple contains:
            - sheet_name (str): The name of the sheet.
            - dataframe (DataFrame): The DataFrame to save.
        output_excel_path (str): Path to save the Excel file.

    Returns:
        None
    """
    # Clean up sheet names to contain only letters, spaces, and numbers
    sanitized_dataframes = [
        (re.sub(r"[^A-Za-z0-9 ]+", "", sheet_name).strip(), df)
        for sheet_name, df in dataframes_list
    ]

    # Determine the mode to use based on whether the file exists
    mode = "a" if os.path.exists(output_excel_path) else "w"

    if mode == "a":
        # Load existing workbook
        book = load_workbook(output_excel_path)
        with pd.ExcelWriter(output_excel_path, mode=mode, engine="openpyxl") as writer:
            # Use the existing workbook
            writer.book = book
            writer.sheets = {ws.title: ws for ws in book.worksheets}

            # Remove sheets if they already exist
            for sheet_name, _ in sanitized_dataframes:
                if sheet_name in writer.sheets:
                    del book[sheet_name]

            # Write the new dataframes
            for sheet_name, df in sanitized_dataframes:
                df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        # Create a new workbook
        with pd.ExcelWriter(output_excel_path, mode=mode, engine="openpyxl") as writer:
            for sheet_name, df in sanitized_dataframes:
                df.to_excel(writer, sheet_name=sheet_name, index=False)

# %%
def check_for_definitions_similarity(
    true_terms_classify, pred_terms_classify, threshold=0.8
):
    """
    Compare terms from true_terms_classify and pred_terms_classify, ensuring alignment by doc_id and statement_id.
    Calculate similarity scores for matching definitions without duplicates in the results.
    """
    results = []
    unique_results = set()  # Track unique entries
    matched_terms = 0

    # Convert true_terms_classify into a dictionary for easier matching
    true_terms = {
        f"{term['doc_id']}|{term['sources']}|{term['statement_id'].strip().lower()}": term.get(
            "statement", ""
        )
        for term in true_terms_classify
    }

    # Iterate through pred_terms_classify to compare with true_terms
    for pred_term in pred_terms_classify:
        pred_doc_id = pred_term["doc_id"]
        pred_statement_id = pred_term["statement_id"].strip().lower()
        pred_definition = pred_term.get("definition", "")
        pred_sources = pred_term["sources"]

        # Construct the key for matching
        pred_key = f"{pred_doc_id}|{pred_sources}|{pred_statement_id}"

        # Check if the term exists in true_terms
        if pred_key in true_terms:
            true_statement = true_terms[pred_key]

            logger.debug(pred_definition, true_statement)

            if not pred_definition and not true_statement:
                similarity_score = 1
            elif not pred_definition and true_statement:
                similarity_score = 0
            elif pred_definition and not true_statement:
                similarity_score = -1
            else:
                # Compute similarity between definitions
                score = jellyfish.levenshtein_distance(pred_definition, true_statement)
                max_length = max(len(pred_definition), len(true_statement), 1)
                similarity_score = 1 - (score / max_length)

            logger.debug(pred_definition, "|", true_statement, "|", similarity_score)

            # Construct a unique identifier for the result to avoid duplicates
            result_key = (
                f"{pred_doc_id}|{pred_sources}|{pred_statement_id}|{similarity_score}"
            )

            if result_key not in unique_results:
                # Add the unique key to the set
                unique_results.add(result_key)

                # Check if similarity exceeds the threshold
                if similarity_score >= threshold:
                    matched_terms += 1
                    results.append(
                        {
                            "doc_id": pred_doc_id,
                            "sources": pred_sources,
                            "term": pred_statement_id,
                            "definition_pred": pred_definition,
                            "definition_true": true_statement,
                            "similarity_score": similarity_score,
                        }
                    )
                else:
                    results.append(
                        {
                            "doc_id": pred_doc_id,
                            "sources": pred_sources,
                            "term": pred_statement_id,
                            "definition_pred": pred_definition,
                            "definition_true": true_statement,
                            "similarity_score": similarity_score,
                        }
                    )
        else:
            # Log unmatched terms for debugging
            logger.debug(f"Unmatched pred_term: {pred_key}")

    logger.info(f"Total terms in true_terms: {len(true_terms_classify)}")
    logger.info(f"Total matched terms in pred_terms: {matched_terms}")

    return results

# %%
def create_terms_results_heatmap(df_terms_results):
    # Handle duplicate entries by aggregating similarity scores
    df_terms_results = df_terms_results.groupby(["term", "doc_id"], as_index=False).agg(
        {"similarity_score": "mean"}
    )

    # Pivot the DataFrame to create a matrix of terms vs. documents
    df_pivot = df_terms_results.pivot(
        index="term", columns="doc_id", values="similarity_score"
    )

    # Limit the number of terms for readability (e.g., top 50 terms)
    if df_pivot.shape[0] > 50:
        df_pivot = df_pivot.head(50)

    # Generate the heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(df_pivot, cmap="coolwarm", linewidths=0.5, annot=True)
    plt.title("Heatmap of Similarity Scores")
    plt.xlabel("Document ID")
    plt.ylabel("Term")
    plt.tight_layout()
    plt.show()

# %%
def get_terms_with_definitions(manager, doc_type="true_table"):
    """
    Read the true terms from the true tables and merge definitions from P2 documents.

    Args:
        manager (DocumentManager): The DocumentManager instance.

    Returns:
        list: A list of true terms with definitions, without duplicates.
    """
    docs_ids = manager.list_document_ids()

    terms_sources_p1 = {}
    definitions_p2 = {}

    # Iterate over P1 documents to collect terms
    for doc_id in docs_ids:
        normalized_doc_id = normalize_str(doc_id)
        if normalized_doc_id.startswith("§") and normalized_doc_id.endswith("_P1"):
            doc = manager.retrieve_document(doc_id, doc_type)
            logger.debug(f"{doc=}")
            for element in doc.content.get("elements"):
                logger.debug(f"{element=}")
                for term in element.get("terms"):
                    logger.debug(f"{term=}")
                    statement_id = term.get("term", "")
                    sources = tuple(element.get("sources", []))  # Use tuple for immutability in keys
                    composite_key = (doc_id.replace("_P1", ""), sources, statement_id)

                    if composite_key not in terms_sources_p1:  # Avoid duplicates
                        terms_sources_p1[composite_key] = {
                            "statement_id": statement_id,
                            "classification": term.get("classification", ""),
                            "sources": sources,
                            "doc_id": normalized_doc_id.replace("_P1", ""),
                            "definition": None,  # Placeholder for definition from P2
                        }

    logger.info(f"Total count: {len(terms_sources_p1)} terms P1")

    # Iterate over P2 documents to collect definitions
    for doc_id in docs_ids:
        normalized_doc_id = normalize_str(doc_id)
        if normalized_doc_id.startswith("§") and normalized_doc_id.endswith("_P2"):
            doc = manager.retrieve_document(doc_id, doc_type)
            logger.debug(f"{doc_id=}, {doc=}")
            for term in doc.content.get("terms"):
                logger.debug(f"{term=}")
                statement_id = term.get("term", "")
                definition = term.get("definition", None)
                sources = tuple(term.get("sources", []))  # Ensure sources match the structure in P1
                composite_key = (doc_id.replace("_P2", ""), sources, statement_id)

                if composite_key not in definitions_p2:  # Avoid duplicates
                    definitions_p2[composite_key] = definition

    logger.info(f"Total count: {len(definitions_p2)} terms with definitions P2")

    # Merge definitions from P2 into the terms collected from P1
    for composite_key, term in terms_sources_p1.items():
        if composite_key in definitions_p2:
            term["definition"] = definitions_p2[composite_key]

    result = list(terms_sources_p1.values())  # Convert dictionary back to list
    logger.info(f"Count: {len(result)} terms with merged definitions")
    logger.debug(f"{result=}")

    return result

# %%
def get_pred_elements(checkpoint_dir):
    """
    Get predicted elements from checkpoints.

    Args:
        checkpoint_dir: Directory containing checkpoints.

    Returns:
        List of predicted elements.
    """
    managers, file_info_list = get_all_checkpoints(checkpoint_dir)

    logger.info(f"Loaded {len(managers)} checkpoints")

    pred_elements = []

    for manager, file_info in zip(managers, file_info_list):
        docs_ids = manager.list_document_ids(doc_type="llm_response")

        logger.info(
            f"Processing {len(docs_ids)}, {docs_ids=} documents from {file_info=}"
        )

        for doc_id in docs_ids:
            if doc_id.startswith("§") and doc_id.endswith("_P1"):
                logger.info(f"Processing {doc_id}")
                doc = manager.retrieve_document(doc_id, "llm_response")
                logger.debug(f"{doc_id=}")

                for element in doc.content.get("elements"):
                    logger.debug(f'{element.get("id")=}')
                    pred_elements.append(
                        {
                            "doc_id": doc.id.replace("_P1", ""),
                            "id": element.get("id"),
                            "title": element.get("title"),
                            "statement": element.get("statement"),
                            "classification": element["classification"],
                            "sources": f'{doc.content.get("section")}{element.get("sources")}',
                            "filename": file_info.get("filename"),
                        }
                    )
            else:
                logger.info(f"Skipping {doc_id}")

        logger.info(f"{doc_id}: total of elements: {len(pred_elements)}")

    logger.info(f"Processed all documents - total {len(pred_elements)} elements")

    return pred_elements

# %%
def get_true_elements(manager):
    """
    Read the true elements from the true tables.

    Args:
        manager (DocumentManager): The DocumentManager instance.

    Returns:
        list: A list of true elements.
    """
    docs_ids = manager.list_document_ids(doc_type="true_table")

    true_elements = []

    for doc_id in docs_ids:
        if doc_id.startswith("§") and doc_id.endswith("_P1"):
            doc = manager.retrieve_document(doc_id, "true_table")
            logger.debug(f"{doc_id=}, {doc=}")

            for element in doc.content.get("elements"):
                true_elements.append(
                    {
                        "doc_id": doc.id.replace("_P1", ""),
                        "id": element.get("id"),
                        "statement": element.get("statement"),
                        "classification": element["classification"],
                        "sources": f'{doc.content.get("section")}{element.get("sources")}',
                    }
                )

    logger.info(f"Count: {len(true_elements)} elements")

    return true_elements

# %%
jellyfish.levenshtein_distance("Anderson", "Luiz")
# Out:
# 8

# %%
# Function to group statements by doc_id
def group_statements_by_doc_id(statements_list, is_pred=False):
    doc_id_map = defaultdict(list)
    for item in statements_list:
        doc_id = item["doc_id"]
        if is_pred:
            # Include filename, id, and classification for pred_list items
            statement_info = {
                "id": item["id"],
                "statement": item["statement"],
                "classification_pred": item.get("classification", None),
                "sources_pred": item["sources"],
                "filename_pred": item["filename"],
            }
        else:
            # Include id and classification for true_list items
            statement_info = {
                "id": item["id"],
                "statement": item["statement"],
                "classification_true": item.get("classification", None),
                "source_true": item["sources"],
            }
        doc_id_map[doc_id].append(statement_info)

    logger.debug(f"doc_id_map: {doc_id_map}")

    return doc_id_map


# Function to check the similarity between true and pred statements grouped by doc_id
def check_for_statements_similarity(true_list, pred_list, threshold=0.7):
    # Build mappings from doc_id to list of statements
    true_statements_by_doc_id = group_statements_by_doc_id(true_list)
    pred_statements_by_doc_id = group_statements_by_doc_id(pred_list, is_pred=True)

    results = []
    all_doc_ids = set(true_statements_by_doc_id.keys()).union(
        pred_statements_by_doc_id.keys()
    )

    for doc_id in all_doc_ids:
        true_statements = true_statements_by_doc_id.get(doc_id, [])
        pred_statements = pred_statements_by_doc_id.get(doc_id, [])

        for pred_item in pred_statements:
            pred_expr = pred_item["statement"]
            pred_id = pred_item["id"]
            classification_pred = pred_item.get("classification_pred", None)
            source_pred = pred_item["sources_pred"]
            filename_pred = pred_item["filename_pred"]

            best_match = None
            best_score = 0
            best_true_id = None
            classification_true = None

            for true_item in true_statements:
                true_expr = true_item["statement"]
                true_id = true_item["id"]
                source_true = true_item["source_true"]
                # Calculate the similarity score using the Levenshtein distance
                score = jellyfish.levenshtein_distance(pred_expr, true_expr)
                similarity_score = 1 - (
                    score / max(len(pred_expr), len(true_expr))
                )  # Normalize to a similarity score

                if similarity_score > best_score:
                    best_score = similarity_score
                    best_match = true_expr
                    best_true_id = true_id
                    best_source = source_true
                    classification_true = true_item.get("classification_true", None)
            results.append(
                {
                    "doc_id": doc_id,
                    "id_pred": pred_id,
                    "id_true": best_true_id,
                    "classification_pred": classification_pred,
                    "classification_true": classification_true,
                    "source_pred": source_pred,
                    "source_true": best_source,
                    "filename_pred": filename_pred,
                    "statement_pred": pred_expr,
                    "statement_true": best_match,
                    "similarity_score": best_score,
                }
            )
    return results

#
# Fix the number of comparisons true vs pred
#
# def group_true_by_doc_id(true_items):
#     grouped = {}
#     for t in true_items:
#         doc_id = t["doc_id"]
#         if doc_id not in grouped:
#             grouped[doc_id] = []
#         grouped[doc_id].append(t)
#     return grouped

# def group_pred_by_doc_id_and_filename(pred_items):
#     grouped = {}
#     for p in pred_items:
#         doc_id = p["doc_id"]
#         filename = p.get("filename") or p.get("filename_pred", "no_filename")
#         key = (doc_id, filename)
#         if key not in grouped:
#             grouped[key] = []
#         grouped[key].append(p)
#     return grouped

# def check_for_statements_similarity(true_list, pred_list):
#     # Group the true items by doc_id
#     true_by_doc = group_true_by_doc_id(true_list)
    
#     # Group the predicted items by (doc_id, filename)
#     pred_by_doc_filename = group_pred_by_doc_id_and_filename(pred_list)
    
#     # Collect all doc_ids that appear in either set
#     all_doc_ids = set(true_by_doc.keys())
#     for (doc_id, _) in pred_by_doc_filename.keys():
#         all_doc_ids.add(doc_id)
    
#     results = []

#     for doc_id in all_doc_ids:
#         # Get the full list of true items for this doc_id
#         true_items = true_by_doc.get(doc_id, [])
        
#         # Collect all filenames that appear in the predictions for this doc_id
#         # (We look for all keys whose first element matches this doc_id)
#         filenames_for_doc = []
#         for (d_id, fname) in pred_by_doc_filename.keys():
#             if d_id == doc_id:
#                 filenames_for_doc.append(fname)
        
#         # If there are no predicted filenames at all for this doc_id,
#         # produce rows with empty predicted info for each true item
#         if not filenames_for_doc:
#             for t_item in true_items:
#                 results.append({
#                     "doc_id": doc_id,
#                     "id_true": t_item["id"],
#                     "statement_true": t_item["statement"],
#                     "classification_true": t_item.get("classification"),
#                     "source_true": t_item.get("sources"),
#                     "filename_pred": None,
#                     "id_pred": None,
#                     "statement_pred": None,
#                     "classification_pred": None,
#                     "source_pred": None,
#                     "similarity_score": 0.0
#                 })
#             # Move on to next doc_id
#             continue
        
#         # For each filename, produce exactly one row per true item
#         # picking the best matching prediction (if any)
#         for filename in filenames_for_doc:
#             # The predicted items for this (doc_id, filename)
#             pred_items = pred_by_doc_filename.get((doc_id, filename), [])
            
#             for t_item in true_items:
#                 true_expr = t_item["statement"]
#                 best_score = 0.0
#                 best_pred = None  # best matching predicted item

#                 # If no predicted items, we will store empty values below
#                 for p_item in pred_items:
#                     pred_expr = p_item["statement"]
#                     distance = jellyfish.levenshtein_distance(pred_expr, true_expr)
#                     max_len = max(len(pred_expr), len(true_expr))
#                     similarity = 1 - (distance / max_len) if max_len else 0
                    
#                     if similarity > best_score:
#                         best_score = similarity
#                         best_pred = p_item

#                 if best_pred:
#                     # We found a best matching predicted statement
#                     results.append({
#                         "doc_id": doc_id,
#                         "id_true": t_item["id"],
#                         "statement_true": t_item["statement"],
#                         "classification_true": t_item.get("classification"),
#                         "source_true": t_item.get("sources"),
#                         "filename_pred": filename,
#                         "id_pred": best_pred["id"],
#                         "statement_pred": best_pred["statement"],
#                         "classification_pred": best_pred.get("classification_pred", 
#                                                               best_pred.get("classification")),
#                         "source_pred": best_pred.get("sources_pred", best_pred.get("sources")),
#                         "similarity_score": best_score
#                     })
#                 else:
#                     # No predicted items or no matches for this filename
#                     results.append({
#                         "doc_id": doc_id,
#                         "id_true": t_item["id"],
#                         "statement_true": t_item["statement"],
#                         "classification_true": t_item.get("classification"),
#                         "source_true": t_item.get("sources"),
#                         "filename_pred": filename,
#                         "id_pred": None,
#                         "statement_pred": None,
#                         "classification_pred": None,
#                         "source_pred": None,
#                         "similarity_score": 0.0
#                     })

#     return results

# Add similarity_classification based on similarity_score
def classify_similarity(score):
    if score == 1.0:
        return "identical"
    elif score >= 0.9:
        return "close-match"
    else:
        return "not-sure"


# Modify the highlight_similarity function to use three colors
def highlight_similarity(val):
    if val == "identical":
        color = "green"
    elif val == "close-match":
        color = "yellow"
    else:
        color = "red"
    return f"background-color: {color}"

# %%
def create_df_elements_results(similarity_elements_results):
    # Build the dataframe
    df_results = pd.DataFrame(similarity_elements_results)

    df_results["similarity_classification"] = df_results["similarity_score"].apply(
        classify_similarity
    )

    df_results["classification_match"] = (
        df_results["classification_pred"] == df_results["classification_true"]
    )
    df_results["classification_match_label"] = df_results["classification_match"].map(
        {True: "match", False: "mismatch"}
    )

    df_results["source_match"] = df_results["source_pred"] == df_results["source_true"]
    df_results["source_match_label"] = df_results["source_match"].map(
        {True: "match", False: "mismatch"}
    )

    df_results["id_match"] = df_results["id_pred"] == df_results["id_true"]
    df_results["id_match_label"] = df_results["id_match"].map(
        {True: "match", False: "mismatch"}
    )

    return df_results

# %%
def create_df_elements_results_confusion_matrix_classification(df_elements_results):
    # Prepare the data
    df_elements_evaluation = df_elements_results.dropna(
        subset=["classification_true", "classification_pred"]
    )

    y_true = df_elements_evaluation["classification_true"]
    y_pred = df_elements_evaluation["classification_pred"]

    # Get the unique labels from both y_true and y_pred
    labels = np.unique(np.concatenate((y_true.unique(), y_pred.unique())))

    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    # Create a ConfusionMatrixDisplay
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(8, 6))
    disp.plot(ax=ax, cmap=plt.cm.Blues, values_format="d")
    plt.title("Matrix de confusão para classificação")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Generate the classification report
    report = classification_report(y_true, y_pred, labels=labels, digits=4)
    print("Classification Report:\n")
    print(report)

# %%
def create_elements_results_distribution_similarity(df_elements_results):
    # Assuming you already have similarity_counts
    similarity_elements_counts = df_elements_results[
        "similarity_classification"
    ].value_counts()

    # Calculating the total number of classifications
    total_counts = similarity_elements_counts.sum()

    # Plotting the distribution
    fig, ax = plt.subplots(
        figsize=(10, 6)
    )  # Increase the figure size for better visibility
    ax = similarity_elements_counts.plot(
        kind="bar", color=["green", "yellow", "blue"], edgecolor="black"
    )

    # Adding chart title and axis labels
    plt.title("Distribuição de Classificações de Similaridade", fontsize=16)
    plt.xlabel("Classificações de Similaridade", fontsize=14)
    plt.ylabel("Contagem", fontsize=14)

    # Adding count and percentage on each bar in the same line
    for p in ax.patches:
        count = p.get_height()
        percentage = count / total_counts * 100
        ax.annotate(
            f"{count} ({percentage:.1f}%)",
            (
                p.get_x() + p.get_width() / 2.0,
                count,
            ),  # Position slightly above the bar for clarity
            ha="center",
            va="bottom",
            fontsize=12,
            color="black",
        )

    # Optimizing axes labels and tick sizes
    plt.xticks(rotation=45, fontsize=12)  # Rotate x labels for better readability
    plt.yticks(fontsize=12)

    # Adding grid lines for better visual reference
    plt.grid(axis="y", linestyle="--", linewidth=0.3)

    plt.tight_layout()  # Adjust the padding for cleaner look
    plt.show()

# %%
def create_df_elements_results_confusion_matrix_source(df_elements_results):
    # Prepare the data
    df_elements_evaluation = df_elements_results.dropna(
        subset=["source_true", "source_pred"]
    )

    y_true = df_elements_evaluation["source_true"]
    y_pred = df_elements_evaluation["source_pred"]

    # Get the unique labels from both y_true and y_pred
    labels = np.unique(np.concatenate((y_true.unique(), y_pred.unique())))

    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    # Create a ConfusionMatrixDisplay
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(8, 6))
    disp.plot(ax=ax, cmap=plt.cm.Blues, values_format="d")
    plt.title("Matrix de confusão para origem")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Generate the classification report
    report = classification_report(y_true, y_pred, labels=labels, digits=4)
    print("Classification Report:\n")
    print(report)

# %%
def create_elements_results_distribution_source(df_elements_results):
    # Assuming you already have similarity_counts
    similarity_elements_counts = df_elements_results["source_match"].value_counts()

    # Calculating the total number of classifications
    total_counts = similarity_elements_counts.sum()

    # Plotting the distribution
    fig, ax = plt.subplots(
        figsize=(10, 6)
    )  # Increase the figure size for better visibility
    ax = similarity_elements_counts.plot(
        kind="bar", color=["green", "red"], edgecolor="black"
    )

    # Adding chart title and axis labels
    plt.title("Distribuição de Classificações de origem", fontsize=16)
    plt.xlabel("Classificações de origem", fontsize=14)
    plt.ylabel("Contagem", fontsize=14)

    # Adding count and percentage on each bar in the same line
    for p in ax.patches:
        count = p.get_height()
        percentage = count / total_counts * 100
        ax.annotate(
            f"{count} ({percentage:.1f}%)",
            (
                p.get_x() + p.get_width() / 2.0,
                count,
            ),  # Position slightly above the bar for clarity
            ha="center",
            va="bottom",
            fontsize=12,
            color="black",
        )

    # Optimizing axes labels and tick sizes
    plt.xticks(rotation=45, fontsize=12)  # Rotate x labels for better readability
    plt.yticks(fontsize=12)

    # Adding grid lines for better visual reference
    plt.grid(axis="y", linestyle="--", linewidth=0.3)

    plt.tight_layout()  # Adjust the padding for cleaner look
    plt.show()

# %%
def create_df_terms_results(similarity_terms_results):
    # Step 1: Load similarity_results into a DataFrame
    df_terms_results = pd.DataFrame(similarity_terms_results)

    return df_terms_results

# %%
def create_terms_results_distribution_similarity(df_terms_results):
    # Plot a Histogram of Similarity Scores
    plt.figure(figsize=(10, 6))
    plt.hist(
        df_terms_results["similarity_score"],
        bins=20,
        edgecolor="black",
        color="skyblue",
    )
    plt.xlabel("Similarity Score")
    plt.ylabel("Number of Terms")
    plt.title("Distribution of Similarity Scores")
    plt.grid(axis="y")
    plt.show()

# %%
def create_terms_results_histogram_low_similarity(df_terms_results, number_of_terms=10):
    df_low_similarity = df_terms_results.sort_values(by="similarity_score").head(
        number_of_terms
    )

    plt.figure(figsize=(12, 6))
    plt.barh(
        df_low_similarity["term"], df_low_similarity["similarity_score"], color="salmon"
    )
    plt.xlabel("Similarity Score")
    plt.ylabel("Term")
    plt.title("Terms with Lowest Similarity Scores")
    plt.gca().invert_yaxis()  # Invert y-axis to have the lowest score at the top
    plt.show()

# %%
def create_terms_results_average_similarity_per_document(df_terms_results):
    doc_similarity = (
        df_terms_results.groupby("doc_id")["similarity_score"].mean().reset_index()
    )

    print("Average Similarity Score per Document:")
    display(doc_similarity)

    # Plot average similarity score per document
    plt.figure(figsize=(12, 6))
    plt.bar(
        doc_similarity["doc_id"], doc_similarity["similarity_score"], color="skyblue"
    )
    plt.xlabel("Document ID")
    plt.ylabel("Average Similarity Score")
    plt.title("Average Similarity Score per Document")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Datasets
#
# From section 7.2.4 Datasets
#
# The datasets used in this chapter are mentioned in the respective algorithm as true and predicted lists.

# %% [markdown]
# ### Sample size
#
# Margin of error for estimating the mean.

# %%
import math

# Level for 95% confidence
Z = 1.96

# The algorithm ran 10 times
n = 10

# Standard deviation
sigma = 0.1

# Error margin calculation
E = (Z * sigma) / math.sqrt(n)

f"Error margin: {round(E * 100, 2)}%"
# Out:
# 'Error margin: 6.2%'

# %% [markdown]
# ### True tables

# %% [markdown]
# Get true values from all runs

# %%
true_tables_manager = restore_checkpoint(
    filename=f'{config["DEFAULT_DATA_DIR"]}/documents_true_table.json'
)

logger.info(f"Loaded {len(true_tables_manager.list_document_ids())} documents")
# Out:
# 2025-01-11 17:39:52 - INFO - DocumentManager restored from file: ../data/documents_true_table.json
# 2025-01-11 17:39:52 - INFO - Checkpoint restored from ../data/documents_true_table.json.
# 2025-01-11 17:39:52 - INFO - Loaded 14 documents

# %% [markdown]
# Documents in true table's file.

# %%
true_tables_manager.list_document_ids(doc_type="true_table")
# Out:
# ['§ 275.0-2_P1',
#  '§ 275.0-2_P2',
#  '§ 275.0-5_P1',
#  '§ 275.0-5_P2',
#  '§ 275.0-7_P1',
#  '§ 275.0-7_P2',
#  'classify_P1',
#  'classify_P2_Operative_rules',
#  'classify_P2_Definitional_terms',
#  'classify_P2_Definitional_names',
#  'classify_P2_Definitional_facts']

# %% [markdown]
# Elements true table for validate P1 extraction prompt

# %%
true_elements_extraction = get_true_elements(true_tables_manager)
# Out:
# 2025-01-11 17:40:01 - INFO - Count: 22 elements

# %%
Counter([item['classification'] for item in true_elements_extraction])
# Out:
# Counter({'Fact Type': 16, 'Operative Rule': 6})

# %% [markdown]
# Terms true table for validate P2 extraction prompt

# %%
true_all_terms = get_terms_with_definitions(true_tables_manager, "true_table")

true_terms_extraction = [
    term for term in true_all_terms if term["classification"] == "Common Noun"
]

true_names_extraction = [
    term for term in true_all_terms if term["classification"] == "Proper Noun"
]
# Out:
# 2025-01-11 17:40:04 - INFO - Total count: 136 terms P1
# 2025-01-11 17:40:04 - INFO - Total count: 84 terms with definitions P2
# 2025-01-11 17:40:04 - INFO - Count: 136 terms with merged definitions

# %%
logger.info(f"Operative rules and facts: {len(true_elements_extraction)}")
logger.info(f"Terms: {len(true_terms_extraction)}")
logger.info(f"Names: {len(true_names_extraction)}")
# Out:
# 2025-01-11 17:40:07 - INFO - Operative rules and facts: 22
# 2025-01-11 17:40:07 - INFO - Terms: 122
# 2025-01-11 17:40:07 - INFO - Names: 14

# %%
Counter([item['classification'] for item in true_all_terms])
# Out:
# Counter({'Common Noun': 122, 'Proper Noun': 14})

# %% [markdown]
# ### Predicted values
#
# Get predicted elements from all runs

# %% [markdown]
# Predict elements from P1 extraction prompt.

# %%
pred_elements_extraction = get_pred_elements(config["DEFAULT_CHECKPOINT_DIR"])
# Out:
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-1.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-10.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-2.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-3.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-4.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-5.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-6.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-7.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-8.json
# 2025-01-11 17:40:18 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-9.json
# 2025-01-11 17:40:18 - INFO - Loaded 10 checkpoints
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-1.json', 'date': '2025-01-11', 'number': 1}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 22
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-10.json', 'date': '2025-01-11', 'number': 10}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 45
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-2.json', 'date': '2025-01-11', 'number': 2}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 69
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-3.json', 'date': '2025-01-11', 'number': 3}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 86
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-4.json', 'date': '2025-01-11', 'number': 4}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 108
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-5.json', 'date': '2025-01-11', 'number': 5}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 130
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-6.json', 'date': '2025-01-11', 'number': 6}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 154
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-7.json', 'date': '2025-01-11', 'number': 7}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 175
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-8.json', 'date': '2025-01-11', 'number': 8}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 196
# 2025-01-11 17:40:18 - INFO - Processing 6, docs_ids=['§ 275.0-2_P1', '§ 275.0-2_P2', '§ 275.0-5_P1', '§ 275.0-5_P2', '§ 275.0-7_P1', '§ 275.0-7_P2'] documents from file_info={'filename': 'documents-2025-01-11-9.json', 'date': '2025-01-11', 'number': 9}
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-2_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-2_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-5_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-5_P2
# 2025-01-11 17:40:18 - INFO - Processing § 275.0-7_P1
# 2025-01-11 17:40:18 - INFO - Skipping § 275.0-7_P2
# 2025-01-11 17:40:18 - INFO - § 275.0-7_P2: total of elements: 217
# 2025-01-11 17:40:18 - INFO - Processed all documents - total 217 elements

# %%
print(Counter([item['classification'] for item in true_elements_extraction]))
print(Counter([item['classification'] for item in pred_elements_extraction]))
# Out:
# Counter({'Fact Type': 16, 'Operative Rule': 6})
# Counter({'Fact Type': 175, 'Operative Rule': 42})

# %%
logger.info(
    f"True elements: {len(true_elements_extraction)}, Pred elements: {len(pred_elements_extraction)}"
)
# Out:
# 2025-01-11 17:41:59 - INFO - True elements: 22, Pred elements: 217

# %% [markdown]
# Predict terms from P2 extraction prompt.

# %%
managers, file_info_list = get_all_checkpoints(config["DEFAULT_CHECKPOINT_DIR"])

logger.info(f"Loaded {len(managers)} checkpoints")

#pred_terms = {}
pred_all_terms = []

for pred_tables_manager, file_info in zip(managers, file_info_list):
    # pred_tables_manager = restore_checkpoint(
    #     filename=f'{config["DEFAULT_DATA_DIR"]}/checkpoints/documents-2024-12-07-1.json'
    # )

    logger.info(f"Loaded {len(pred_tables_manager.list_document_ids())} documents")

    pred_all_terms.extend(get_terms_with_definitions(pred_tables_manager, "llm_response"))
# Out:
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-1.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-10.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-2.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-3.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-4.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-5.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-6.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-7.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-8.json
# 2025-01-11 17:42:04 - INFO - DocumentManager restored from file: ../data/checkpoints/documents-2025-01-11-9.json
# 2025-01-11 17:42:04 - INFO - Loaded 10 checkpoints
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 134 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 77 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 134 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 117 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 75 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 117 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 124 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 78 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 124 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 97 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 68 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 97 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 127 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 77 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 127 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 125 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 78 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 125 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 126 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 74 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 126 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 107 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 72 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 107 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 107 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 74 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 107 terms with merged definitions
# 2025-01-11 17:42:04 - INFO - Loaded 17 documents
# 2025-01-11 17:42:04 - INFO - Total count: 113 terms P1
# 2025-01-11 17:42:04 - INFO - Total count: 70 terms with definitions P2
# 2025-01-11 17:42:04 - INFO - Count: 113 terms with merged definitions

# %%
pred_terms_extraction = [
    term for term in pred_all_terms if term["classification"] == "Common Noun"
]

pred_names_extraction = [
    term for term in pred_all_terms if term["classification"] == "Proper Noun"
]
logger.info(f"Terms: {len(pred_terms_extraction)}")
logger.info(f"Names: {len(pred_names_extraction)}")
# Out:
# 2025-01-11 17:42:09 - INFO - Terms: 1049
# 2025-01-11 17:42:09 - INFO - Names: 128

# %% [markdown]
# ## Algorithms
#
# Validation of algorithm from section 6.2 Implementation of main components
#
# Source for section 7.3 Results

# %% [markdown]
# ### semantic annotation

# %% [markdown]
# #### Extract elements
#
# Validating results from chap_6_semantic_annotation_elements_extraction.ipynb
#
# - Extract elements by type: Terms, facts, fact type, or operative rules
# - Extract term's definition
# - Identify elements source

# %% [markdown]
# ##### Extract elements: Operative Rules and Fact Types (P1)

# %% [markdown]
# Compare true and pred elements by its statement using levenshtein distance (Levenshtein distance (LIND-COMBS et al., 2023; FAROUK, 2019))

# %%
similarity_elements_results = check_for_statements_similarity(
    true_elements_extraction, pred_elements_extraction
)

# %% [markdown]
# Create a dataframe of true and pred elements

# %%
df_elements_results = create_df_elements_results(similarity_elements_results)
# Save the dataframe to an Excel file
df_elements_results.to_excel(
    f'{config["DEFAULT_OUTPUT_DIR"]}/p1_true_pred_results.xlsx'
)

# %% [markdown]
# Display the First 10 Rows

# %%
# Select the first 10 rows from df_results
df_top10 = df_elements_results.head(10)

# Apply the styling to the sliced DataFrame using .map
styled_elements_df_top10 = df_top10.style.map(
    highlight_similarity, subset=["similarity_classification"]
)
styled_elements_df_top10.set_table_attributes(
    'style="width: 100%; border: 1px solid black;"'
)
styled_elements_df_top10.set_properties(**{"border": "1px solid black"})

# Display the styled DataFrame (if in Jupyter Notebook)
display(styled_elements_df_top10)
# Out:
# <style type="text/css">
# #T_2431f_row0_col0, #T_2431f_row0_col1, #T_2431f_row0_col2, #T_2431f_row0_col3, #T_2431f_row0_col4, #T_2431f_row0_col5, #T_2431f_row0_col6, #T_2431f_row0_col7, #T_2431f_row0_col8, #T_2431f_row0_col9, #T_2431f_row0_col10, #T_2431f_row0_col12, #T_2431f_row0_col13, #T_2431f_row0_col14, #T_2431f_row0_col15, #T_2431f_row0_col16, #T_2431f_row0_col17, #T_2431f_row1_col0, #T_2431f_row1_col1, #T_2431f_row1_col2, #T_2431f_row1_col3, #T_2431f_row1_col4, #T_2431f_row1_col5, #T_2431f_row1_col6, #T_2431f_row1_col7, #T_2431f_row1_col8, #T_2431f_row1_col9, #T_2431f_row1_col10, #T_2431f_row1_col12, #T_2431f_row1_col13, #T_2431f_row1_col14, #T_2431f_row1_col15, #T_2431f_row1_col16, #T_2431f_row1_col17, #T_2431f_row2_col0, #T_2431f_row2_col1, #T_2431f_row2_col2, #T_2431f_row2_col3, #T_2431f_row2_col4, #T_2431f_row2_col5, #T_2431f_row2_col6, #T_2431f_row2_col7, #T_2431f_row2_col8, #T_2431f_row2_col9, #T_2431f_row2_col10, #T_2431f_row2_col12, #T_2431f_row2_col13, #T_2431f_row2_col14, #T_2431f_row2_col15, #T_2431f_row2_col16, #T_2431f_row2_col17, #T_2431f_row3_col0, #T_2431f_row3_col1, #T_2431f_row3_col2, #T_2431f_row3_col3, #T_2431f_row3_col4, #T_2431f_row3_col5, #T_2431f_row3_col6, #T_2431f_row3_col7, #T_2431f_row3_col8, #T_2431f_row3_col9, #T_2431f_row3_col10, #T_2431f_row3_col12, #T_2431f_row3_col13, #T_2431f_row3_col14, #T_2431f_row3_col15, #T_2431f_row3_col16, #T_2431f_row3_col17, #T_2431f_row4_col0, #T_2431f_row4_col1, #T_2431f_row4_col2, #T_2431f_row4_col3, #T_2431f_row4_col4, #T_2431f_row4_col5, #T_2431f_row4_col6, #T_2431f_row4_col7, #T_2431f_row4_col8, #T_2431f_row4_col9, #T_2431f_row4_col10, #T_2431f_row4_col12, #T_2431f_row4_col13, #T_2431f_row4_col14, #T_2431f_row4_col15, #T_2431f_row4_col16, #T_2431f_row4_col17, #T_2431f_row5_col0, #T_2431f_row5_col1, #T_2431f_row5_col2, #T_2431f_row5_col3, #T_2431f_row5_col4, #T_2431f_row5_col5, #T_2431f_row5_col6, #T_2431f_row5_col7, #T_2431f_row5_col8, #T_2431f_row5_col9, #T_2431f_row5_col10, #T_2431f_row5_col12, #T_2431f_row5_col13, #T_2431f_row5_col14, #T_2431f_row5_col15, #T_2431f_row5_col16, #T_2431f_row5_col17, #T_2431f_row6_col0, #T_2431f_row6_col1, #T_2431f_row6_col2, #T_2431f_row6_col3, #T_2431f_row6_col4, #T_2431f_row6_col5, #T_2431f_row6_col6, #T_2431f_row6_col7, #T_2431f_row6_col8, #T_2431f_row6_col9, #T_2431f_row6_col10, #T_2431f_row6_col12, #T_2431f_row6_col13, #T_2431f_row6_col14, #T_2431f_row6_col15, #T_2431f_row6_col16, #T_2431f_row6_col17, #T_2431f_row7_col0, #T_2431f_row7_col1, #T_2431f_row7_col2, #T_2431f_row7_col3, #T_2431f_row7_col4, #T_2431f_row7_col5, #T_2431f_row7_col6, #T_2431f_row7_col7, #T_2431f_row7_col8, #T_2431f_row7_col9, #T_2431f_row7_col10, #T_2431f_row7_col12, #T_2431f_row7_col13, #T_2431f_row7_col14, #T_2431f_row7_col15, #T_2431f_row7_col16, #T_2431f_row7_col17, #T_2431f_row8_col0, #T_2431f_row8_col1, #T_2431f_row8_col2, #T_2431f_row8_col3, #T_2431f_row8_col4, #T_2431f_row8_col5, #T_2431f_row8_col6, #T_2431f_row8_col7, #T_2431f_row8_col8, #T_2431f_row8_col9, #T_2431f_row8_col10, #T_2431f_row8_col12, #T_2431f_row8_col13, #T_2431f_row8_col14, #T_2431f_row8_col15, #T_2431f_row8_col16, #T_2431f_row8_col17, #T_2431f_row9_col0, #T_2431f_row9_col1, #T_2431f_row9_col2, #T_2431f_row9_col3, #T_2431f_row9_col4, #T_2431f_row9_col5, #T_2431f_row9_col6, #T_2431f_row9_col7, #T_2431f_row9_col8, #T_2431f_row9_col9, #T_2431f_row9_col10, #T_2431f_row9_col12, #T_2431f_row9_col13, #T_2431f_row9_col14, #T_2431f_row9_col15, #T_2431f_row9_col16, #T_2431f_row9_col17 {
#   border: 1px solid black;
# }
# #T_2431f_row0_col11, #T_2431f_row1_col11, #T_2431f_row2_col11, #T_2431f_row3_col11, #T_2431f_row4_col11, #T_2431f_row5_col11, #T_2431f_row6_col11, #T_2431f_row7_col11, #T_2431f_row8_col11, #T_2431f_row9_col11 {
#   background-color: green;
#   border: 1px solid black;
# }
# </style>
# <table id="T_2431f" style="width: 100%; border: 1px solid black;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2431f_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_2431f_level0_col1" class="col_heading level0 col1" >id_pred</th>
#       <th id="T_2431f_level0_col2" class="col_heading level0 col2" >id_true</th>
#       <th id="T_2431f_level0_col3" class="col_heading level0 col3" >classification_pred</th>
#       <th id="T_2431f_level0_col4" class="col_heading level0 col4" >classification_true</th>
#       <th id="T_2431f_level0_col5" class="col_heading level0 col5" >source_pred</th>
#       <th id="T_2431f_level0_col6" class="col_heading level0 col6" >source_true</th>
#       <th id="T_2431f_level0_col7" class="col_heading level0 col7" >filename_pred</th>
#       <th id="T_2431f_level0_col8" class="col_heading level0 col8" >statement_pred</th>
#       <th id="T_2431f_level0_col9" class="col_heading level0 col9" >statement_true</th>
#       <th id="T_2431f_level0_col10" class="col_heading level0 col10" >similarity_score</th>
#       <th id="T_2431f_level0_col11" class="col_heading level0 col11" >similarity_classification</th>
#       <th id="T_2431f_level0_col12" class="col_heading level0 col12" >classification_match</th>
#       <th id="T_2431f_level0_col13" class="col_heading level0 col13" >classification_match_label</th>
#       <th id="T_2431f_level0_col14" class="col_heading level0 col14" >source_match</th>
#       <th id="T_2431f_level0_col15" class="col_heading level0 col15" >source_match_label</th>
#       <th id="T_2431f_level0_col16" class="col_heading level0 col16" >id_match</th>
#       <th id="T_2431f_level0_col17" class="col_heading level0 col17" >id_match_label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2431f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2431f_row0_col0" class="data row0 col0" >§ 275.0-2</td>
#       <td id="T_2431f_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_2431f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_2431f_row0_col3" class="data row0 col3" >Fact Type</td>
#       <td id="T_2431f_row0_col4" class="data row0 col4" >Fact Type</td>
#       <td id="T_2431f_row0_col5" class="data row0 col5" >§ 275.0-2['(a)']</td>
#       <td id="T_2431f_row0_col6" class="data row0 col6" >§ 275.0-2['(a)']</td>
#       <td id="T_2431f_row0_col7" class="data row0 col7" >documents-2025-01-11-1.json</td>
#       <td id="T_2431f_row0_col8" class="data row0 col8" >A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents.</td>
#       <td id="T_2431f_row0_col9" class="data row0 col9" >A person may serve process, pleadings, or other papers on a non-resident investment adviser, or on a non-resident general partner or non-resident managing agent of an investment adviser by serving any or all of its appointed agents.</td>
#       <td id="T_2431f_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_2431f_row0_col11" class="data row0 col11" >identical</td>
#       <td id="T_2431f_row0_col12" class="data row0 col12" >True</td>
#       <td id="T_2431f_row0_col13" class="data row0 col13" >match</td>
#       <td id="T_2431f_row0_col14" class="data row0 col14" >True</td>
#       <td id="T_2431f_row0_col15" class="data row0 col15" >match</td>
#       <td id="T_2431f_row0_col16" class="data row0 col16" >True</td>
#       <td id="T_2431f_row0_col17" class="data row0 col17" >match</td>
#     </tr>
#     <tr>
#       <th id="T_2431f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2431f_row1_col0" class="data row1 col0" >§ 275.0-2</td>
#       <td id="T_2431f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_2431f_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_2431f_row1_col3" class="data row1 col3" >Fact Type</td>
#       <td id="T_2431f_row1_col4" class="data row1 col4" >Fact Type</td>
#       <td id="T_2431f_row1_col5" class="data row1 col5" >§ 275.0-2['(a)(1)']</td>
#       <td id="T_2431f_row1_col6" class="data row1 col6" >§ 275.0-2['(a)(1)']</td>

# %% [markdown]
# **Type classification**

# %% [markdown]
# Computing the confusion matrix and classification report of the evaluation results of predicted classifications against true classifications.

# %%
# To get per doc_id use the filtered_df
#filtered_df = df_elements_results[df_elements_results['doc_id']=='§ 275.0-7']
filtered_df = df_elements_results # not filtered
create_df_elements_results_confusion_matrix_classification(filtered_df)
# Out:
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#      Fact Type     0.8400    0.9866    0.9074       149
# Operative Rule     0.9524    0.5882    0.7273        68
#
#       accuracy                         0.8618       217
#      macro avg     0.8962    0.7874    0.8173       217
#   weighted avg     0.8752    0.8618    0.8510       217

# %% [markdown]
# Analyzing the Distribution of Similarity Classifications

# %%
create_elements_results_distribution_similarity(df_elements_results)

# %%
df_elements_results.query("0.75 <= similarity_score <= 1").shape[0]
# Out:
# 183

# %%
df_elements_results[df_elements_results["similarity_classification"] == "not-sure"].describe()
# Out:
#          id_pred    id_true  similarity_score
# count  34.000000  34.000000         34.000000
# mean    3.558824   3.823529          0.504344
# std     1.812268   1.217812          0.132309
# min     1.000000   2.000000          0.301724
# 25%     2.000000   3.250000          0.420635
# 50%     4.000000   4.000000          0.464029
# 75%     5.000000   4.000000          0.599485
# max     7.000000   6.000000          0.715517

# %%
df_misaligned_similarity=df_elements_results[df_elements_results["similarity_classification"] == "not-sure"].sort_values(by="similarity_score", ascending=True)

# Export the filtered and sorted DataFrame to an Excel file
output_file_path = f'{config["DEFAULT_OUTPUT_DIR"]}/misaligned_similarity.xlsx'
df_misaligned_similarity.to_excel(output_file_path, index=False)

df_misaligned_similarity
# Out:
#         doc_id  id_pred  id_true classification_pred classification_true  \
# 77   § 275.0-5        6        4      Operative Rule      Operative Rule
# 123  § 275.0-5        6        4      Operative Rule      Operative Rule
# 106  § 275.0-5        6        4      Operative Rule      Operative Rule
# 84   § 275.0-5        6        4      Operative Rule      Operative Rule
# 122  § 275.0-5        5        4      Operative Rule      Operative Rule
# 76   § 275.0-5        5        4      Operative Rule      Operative Rule
# 105  § 275.0-5        5        4      Operative Rule      Operative Rule
# 83   § 275.0-5        5        4      Operative Rule      Operative Rule
# 145  § 275.0-7        2        2           Fact Type           Fact Type
# 181  § 275.0-7        2        2           Fact Type           Fact Type
# 126  § 275.0-7        2        2           Fact Type           Fact Type
# 161  § 275.0-7        2        2           Fact Type           Fact Type
# 171  § 275.0-7        2        2           Fact Type           Fact Type
# 191  § 275.0-7        2        2           Fact Type           Fact Type
# 201  § 275.0-7        2        2           Fact Type           Fact Type
# 125  § 275.0-7        1        4           Fact Type           Fact Type
# 210  § 275.0-7        1        4           Fact Type           Fact Type
# 154  § 275.0-7        1        4           Fact Type           Fact Type
# 180  § 275.0-7        1        4           Fact Type           Fact Type
# 193  § 275.0-7        4        4           Fact Type           Fact Type
# 137  § 275.0-7        3        4      Operative Rule           Fact Type
# 203  § 275.0-7        4        4           Fact Type           Fact Type
# 147  § 275.0-7        4        4           Fact Type           Fact Type
# 185  § 275.0-7        6        6           Fact Type           Fact Type
# 130  § 275.0-7        6        6           Fact Type           Fact Type
# 212  § 275.0-7        3        6           Fact Type           Fact Type
# 155  § 275.0-7        2        6           Fact Type           Fact Type
# 55   § 275.0-2        2        3      Operative Rule      Operative Rule
# 22   § 275.0-2        2        3      Operative Rule      Operative Rule
# 141  § 275.0-7        7        6           Fact Type           Fact Type
# 121  § 275.0-5        4        4      Operative Rule      Operative Rule
# 104  § 275.0-5        4        4      Operative Rule      Operative Rule
# 82   § 275.0-5        4        4      Operative Rule      Operative Rule
# 75   § 275.0-5        4        4      Operative Rule      Operative Rule
#
#                      source_pred                source_true  \
# 77           § 275.0-5['(c)(2)']           § 275.0-5['(c)']
# 123          § 275.0-5['(c)(2)']           § 275.0-5['(c)']
# 106          § 275.0-5['(c)(2)']           § 275.0-5['(c)']
# 84           § 275.0-5['(c)(2)']           § 275.0-5['(c)']
# 122          § 275.0-5['(c)(1)']           § 275.0-5['(c)']
# 76           § 275.0-5['(c)(1)']           § 275.0-5['(c)']
# 105          § 275.0-5['(c)(1)']           § 275.0-5['(c)']
# 83           § 275.0-5['(c)(1)']           § 275.0-5['(c)']
# 145          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 181          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 126          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 161          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 171          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 191          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 201          § 275.0-7['(a)(1)']        § 275.0-7['(a)(1)']
# 125             § 275.0-7['(a)']        § 275.0-7['(a)(3)']
# 210             § 275.0-7['(a)']        § 275.0-7['(a)(3)']
# 154             § 275.0-7['(a)']        § 275.0-7['(a)(3)']
# 180             § 275.0-7['(a)']        § 275.0-7['(a)(3)']
# 193          § 275.0-7['(a)(3)']        § 275.0-7['(a)(3)']
# 137          § 275.0-7['(a)(3)']        § 275.0-7['(a)(3)']
# 203          § 275.0-7['(a)(3)']        § 275.0-7['(a)(3)']
# 147          § 275.0-7['(a)(3)']        § 275.0-7['(a)(3)']
# 185       § 275.0-7['(b)(1)(i)']  § 275.0-7['(b)(1)(i)(A)']
# 130       § 275.0-7['(b)(1)(i)']  § 275.0-7['(b)(1)(i)(A)']
# 212       § 275.0-7['(b)(1)(i)']  § 275.0-7['(b)(1)(i)(A)']
# 155       § 275.0-7['(b)(1)(i)']  § 275.0-7['(b)(1)(i)(A)']
# 55           § 275.0-2['(a)(2)']        § 275.0-2['(a)(2)']
# 22           § 275.0-2['(a)(2)']        § 275.0-2['(a)(2)']
# 141  § 275.0-7['(b)(1)(iii)(A)']  § 275.0-7['(b)(1)(i)(A)']
# 121             § 275.0-5['(c)']           § 275.0-5['(c)']
# 104             § 275.0-5['(c)']           § 275.0-5['(c)']
# 82              § 275.0-5['(c)']           § 275.0-5['(c)']
# 75              § 275.0-5['(c)']           § 275.0-5['(c)']
#
#                     filename_pred  \
# 77   documents-2025-01-11-10.json
# 123   documents-2025-01-11-9.json
# 106   documents-2025-01-11-6.json
# 84    documents-2025-01-11-2.json
# 122   documents-2025-01-11-9.json
# 76   documents-2025-01-11-10.json
# 105   documents-2025-01-11-6.json
# 83    documents-2025-01-11-2.json
# 145   documents-2025-01-11-2.json
# 181   documents-2025-01-11-6.json
# 126   documents-2025-01-11-1.json
# 161   documents-2025-01-11-4.json
# 171   documents-2025-01-11-5.json
# 191   documents-2025-01-11-7.json
# 201   documents-2025-01-11-8.json
# 125   documents-2025-01-11-1.json
# 210   documents-2025-01-11-9.json
# 154   documents-2025-01-11-3.json
# 180   documents-2025-01-11-6.json
# 193   documents-2025-01-11-7.json
# 137  documents-2025-01-11-10.json
# 203   documents-2025-01-11-8.json
# 147   documents-2025-01-11-2.json
# 185   documents-2025-01-11-6.json
# 130   documents-2025-01-11-1.json
# 212   documents-2025-01-11-9.json
# 155   documents-2025-01-11-3.json
# 55    documents-2025-01-11-8.json
# 22    documents-2025-01-11-3.json
# 141  documents-2025-01-11-10.json
# 121   documents-2025-01-11-9.json
# 104   documents-2025-01-11-6.json
# 82    documents-2025-01-11-2.json
# 75   documents-2025-01-11-10.json
#
#                                         statement_pred  \
# 77   The Commission will order a hearing on the mat...
# 123  The Commission will order a hearing on the mat...
# 106  The Commission will order a hearing on the mat...
# 84   The Commission will order a hearing on the mat...
# 122  The Commission will order a hearing on the mat...
# 76   The Commission will order a hearing on the mat...
# 105  The Commission will order a hearing on the mat...
# 83   The Commission will order a hearing on the mat...
# 145  An investment adviser has assets under managem...
# 181  An investment adviser has assets under managem...
# 126  An investment adviser has assets under managem...
# 161  An investment adviser has assets under managem...
# 171  An investment adviser has assets under managem...
# 191  An investment adviser has assets under managem...
# 201  An investment adviser has assets under managem...
# 125  The term small business or small organization ...
# 210  The term small business or small organization ...
# 154  The term small business or small organization ...
# 180  The term small business or small organization ...
# 193  An investment adviser does not control, is not...
# 137  An investment adviser does not control, is not...
# 203  An investment adviser does not control, is not...
# 147  An investment adviser does not control, is not...
# 185  A person is presumed to control a corporation ...
# 130  A person is presumed to control a corporation ...
# 212  A person is presumed to control a corporation ...
# 155  A person is presumed to control a corporation ...
# 55   The Secretary of the Commission (Secretary) wi...
# 22   The Secretary of the Commission (Secretary) wi...
# 141  A person is presumed to control a limited liab...
# 121  The Commission will order a hearing on the mat...
# 104  The Commission will order a hearing on the mat...
# 82   The Commission will order a hearing on the mat...
# 75   The Commission will order a hearing on the mat...
#
#                                         statement_true  similarity_score  \
# 77   The Commission will order a hearing on the mat...          0.301724
# 123  The Commission will order a hearing on the mat...          0.301724
# 106  The Commission will order a hearing on the mat...          0.301724
# 84   The Commission will order a hearing on the mat...          0.306034
# 122  The Commission will order a hearing on the mat...          0.396552
# 76   The Commission will order a hearing on the mat...          0.396552
# 105  The Commission will order a hearing on the mat...          0.396552
# 83   The Commission will order a hearing on the mat...          0.400862
# 145  An investment adviser has assets under managem...          0.420635
# 181  An investment adviser has assets under managem...          0.420635
# 126  An investment adviser has assets under managem...          0.420635
# 161  An investment adviser has assets under managem...          0.420635
# 171  An investment adviser has assets under managem...          0.420635
# 191  An investment adviser has assets under managem...          0.420635
# 201  An investment adviser has assets under managem...          0.420635
# 125  An investment adviser does not control, is not...          0.464029
# 210  An investment adviser does not control, is not...          0.464029
# 154  An investment adviser does not control, is not...          0.464029
# 180  An investment adviser does not control, is not...          0.464029
# 193  An investment adviser does not control, is not...          0.572327
# 137  An investment adviser does not control, is not...          0.572327
# 203  An investment adviser does not control, is not...          0.572327
# 147  An investment adviser does not control, is not...          0.572327
# 185  A person is presumed to control a corporation ...          0.597938
# 130  A person is presumed to control a corporation ...          0.597938
# 212  A person is presumed to control a corporation ...          0.600000
# 155  A person is presumed to control a corporation ...          0.600000
# 55   If process, pleadings, or other papers are ser...          0.643885
# 22   If process, pleadings, or other papers are ser...          0.643885
# 141  A person is presumed to control a corporation ...          0.710383
# 121  The Commission will order a hearing on the mat...          0.715517
# 104  The Commission will order a hearing on the mat...          0.715517
# 82   The Commission will order a hearing on the mat...          0.715517
# 75   The Commission will order a hearing on the mat...          0.715517
#
#     similarity_classification  classification_match  \
# 77                   not-sure                  True
# 123                  not-sure                  True
# 106                  not-sure                  True
# 84                   not-sure                  True
# 122                  not-sure                  True
# 76                   not-sure                  True
# 105                  not-sure                  True
# 83                   not-sure                  True
# 145                  not-sure                  True
# 181                  not-sure                  True
# 126                  not-sure                  True
# 161                  not-sure                  True
# 171                  not-sure                  True
# 191                  not-sure                  True
# 201                  not-sure                  True
# 125                  not-sure                  True
# 210                  not-sure                  True
# 154                  not-sure                  True
# 180                  not-sure                  True
# 193                  not-sure                  True
# 137                  not-sure                 False
# 203                  not-sure                  True
# 147                  not-sure                  True
# 185                  not-sure                  True
# 130                  not-sure                  True
# 212                  not-sure                  True
# 155                  not-sure                  True
# 55                   not-sure                  True
# 22                   not-sure                  True
# 141                  not-sure                  True
# 121                  not-sure                  True
# 104                  not-sure                  True
# 82                   not-sure                  True
# 75                   not-sure                  True
#
#     classification_match_label  source_match source_match_label  id_match  \
# 77                       match         False           mismatch     False
# 123                      match         False           mismatch     False
# 106                      match         False           mismatch     False
# 84                       match         False           mismatch     False
# 122                      match         False           mismatch     False
# 76                       match         False           mismatch     False
# 105                      match         False           mismatch     False
# 83                       match         False           mismatch     False
# 145                      match          True              match      True
# 181                      match          True              match      True
# 126                      match          True              match      True
# 161                      match          True              match      True
# 171                      match          True              match      True
# 191                      match          True              match      True
# 201                      match          True              match      True
# 125                      match         False           mismatch     False
# 210                      match         False           mismatch     False
# 154                      match         False           mismatch     False
# 180                      match         False           mismatch     False
# 193                      match          True              match      True
# 137                   mismatch          True              match     False
# 203                      match          True              match      True
# 147                      match          True              match      True
# 185                      match         False           mismatch      True
# 130                      match         False           mismatch      True
# 212                      match         False           mismatch     False
# 155                      match         False           mismatch     False
# 55                       match          True              match     False
# 22                       match          True              match     False
# 141                      match         False           mismatch     False
# 121                      match          True              match      True
# 104                      match          True              match      True
# 82                       match          True              match      True
# 75                       match          True              match      True
#
#     id_match_label
# 77        mismatch
# 123       mismatch
# 106       mismatch
# 84        mismatch
# 122       mismatch
# 76        mismatch
# 105       mismatch
# 83        mismatch
# 145          match
# 181          match
# 126          match
# 161          match
# 171          match
# 191          match
# 201          match
# 125       mismatch
# 210       mismatch
# 154       mismatch
# 180       mismatch
# 193          match
# 137       mismatch
# 203          match
# 147          match
# 185          match
# 130          match
# 212       mismatch
# 155       mismatch
# 55        mismatch
# 22        mismatch
# 141       mismatch
# 121          match
# 104          match
# 82           match
# 75           match

# %%
df_elements_results[df_elements_results["similarity_classification"] == "close-match"].head(10)
# Out:
#         doc_id  id_pred  id_true classification_pred classification_true  \
# 12   § 275.0-2        6        6           Fact Type           Fact Type
# 32   § 275.0-2        6        6           Fact Type           Fact Type
# 39   § 275.0-2        6        6           Fact Type           Fact Type
# 52   § 275.0-2        5        6           Fact Type           Fact Type
# 71   § 275.0-5        5        5           Fact Type           Fact Type
# 78   § 275.0-5        7        5           Fact Type           Fact Type
# 85   § 275.0-5        7        5           Fact Type           Fact Type
# 90   § 275.0-5        5        5           Fact Type           Fact Type
# 95   § 275.0-5        5        5           Fact Type           Fact Type
# 100  § 275.0-5        5        5           Fact Type           Fact Type
#
#              source_pred          source_true                 filename_pred  \
# 12   § 275.0-2['(b)(2)']  § 275.0-2['(b)(2)']  documents-2025-01-11-10.json
# 32   § 275.0-2['(b)(2)']  § 275.0-2['(b)(2)']   documents-2025-01-11-4.json
# 39   § 275.0-2['(b)(2)']  § 275.0-2['(b)(2)']   documents-2025-01-11-5.json
# 52   § 275.0-2['(b)(2)']  § 275.0-2['(b)(2)']   documents-2025-01-11-7.json
# 71      § 275.0-5['(d)']     § 275.0-5['(d)']   documents-2025-01-11-1.json
# 78      § 275.0-5['(d)']     § 275.0-5['(d)']  documents-2025-01-11-10.json
# 85      § 275.0-5['(d)']     § 275.0-5['(d)']   documents-2025-01-11-2.json
# 90      § 275.0-5['(d)']     § 275.0-5['(d)']   documents-2025-01-11-3.json
# 95      § 275.0-5['(d)']     § 275.0-5['(d)']   documents-2025-01-11-4.json
# 100     § 275.0-5['(d)']     § 275.0-5['(d)']   documents-2025-01-11-5.json
#
#                                         statement_pred  \
# 12   Non-resident means: (i) An individual who resi...
# 32   Non-resident means: (i) An individual who resi...
# 39   Non-resident means: (i) An individual who resi...
# 52   Non-resident means: (i) An individual who resi...
# 71   For purposes of this rule, an “application” me...
# 78   For purposes of this rule, an “application” me...
# 85   For purposes of this rule, an “application” me...
# 90   For purposes of this rule, an “application” me...
# 95   For purposes of this rule, an “application” me...
# 100  For purposes of this rule, an “application” me...
#
#                                         statement_true  similarity_score  \
# 12   Non-resident means an individual who resides i...          0.960084
# 32   Non-resident means an individual who resides i...          0.960084
# 39   Non-resident means an individual who resides i...          0.960084
# 52   Non-resident means an individual who resides i...          0.960084
# 71   For purposes of this rule, an application mean...          0.988827
# 78   For purposes of this rule, an application mean...          0.988827
# 85   For purposes of this rule, an application mean...          0.988827
# 90   For purposes of this rule, an application mean...          0.988827
# 95   For purposes of this rule, an application mean...          0.988827
# 100  For purposes of this rule, an application mean...          0.988827
#
#     similarity_classification  classification_match  \
# 12                close-match                  True
# 32                close-match                  True
# 39                close-match                  True
# 52                close-match                  True
# 71                close-match                  True
# 78                close-match                  True
# 85                close-match                  True
# 90                close-match                  True
# 95                close-match                  True
# 100               close-match                  True
#
#     classification_match_label  source_match source_match_label  id_match  \
# 12                       match          True              match      True
# 32                       match          True              match      True
# 39                       match          True              match      True
# 52                       match          True              match     False
# 71                       match          True              match      True
# 78                       match          True              match     False
# 85                       match          True              match     False
# 90                       match          True              match      True
# 95                       match          True              match      True
# 100                      match          True              match      True
#
#     id_match_label
# 12           match
# 32           match
# 39           match
# 52        mismatch
# 71           match
# 78        mismatch
# 85        mismatch
# 90           match
# 95           match
# 100          match

# %% [markdown]
# ##### Source identification (P1)

# %%
create_df_elements_results_confusion_matrix_source(df_elements_results)
# Out:
# Classification Report:
#
#                              precision    recall  f1-score   support
#
#            § 275.0-2['(a)']     1.0000    1.0000    1.0000        10
#         § 275.0-2['(a)(1)']     1.0000    1.0000    1.0000         7
#         § 275.0-2['(a)(2)']     1.0000    1.0000    1.0000        10
#         § 275.0-2['(a)(3)']     1.0000    1.0000    1.0000        10
#         § 275.0-2['(b)(1)']     1.0000    1.0000    1.0000        10
#         § 275.0-2['(b)(2)']     1.0000    1.0000    1.0000        10
#         § 275.0-2['(b)(3)']     1.0000    1.0000    1.0000        10
#            § 275.0-5['(a)']     1.0000    1.0000    1.0000        20
#            § 275.0-5['(b)']     1.0000    1.0000    1.0000        10
#            § 275.0-5['(c)']     1.0000    0.5556    0.7143        18
#         § 275.0-5['(c)(1)']     0.0000    0.0000    0.0000         0
#         § 275.0-5['(c)(2)']     0.0000    0.0000    0.0000         0
#            § 275.0-5['(d)']     1.0000    1.0000    1.0000        10
#            § 275.0-7['(a)']     0.6000    1.0000    0.7500         6
#         § 275.0-7['(a)(1)']     1.0000    1.0000    1.0000         7
#         § 275.0-7['(a)(2)']     1.0000    1.0000    1.0000         8
#         § 275.0-7['(a)(3)']     1.0000    0.6667    0.8000        12
#         § 275.0-7['(b)(1)']     1.0000    1.0000    1.0000         9
#      § 275.0-7['(b)(1)(i)']     0.0000    0.0000    0.0000         0
#   § 275.0-7['(b)(1)(i)(A)']     1.0000    0.5455    0.7059        11
#     § 275.0-7['(b)(1)(ii)']     1.0000    1.0000    1.0000        10
#    § 275.0-7['(b)(1)(iii)']     1.0000    1.0000    1.0000         9
# § 275.0-7['(b)(1)(iii)(A)']     0.0000    0.0000    0.0000         0
#     § 275.0-7['(b)(1)(iv)']     1.0000    1.0000    1.0000        10
#         § 275.0-7['(b)(2)']     1.0000    1.0000    1.0000        10
#
#                    accuracy                         0.9217       217
#                   macro avg     0.8240    0.7907    0.7988       217
#                weighted avg     0.9889    0.9217    0.9434       217
# /home/adsantos/miniconda3/envs/ipt-cfr2sbvr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adsantos/miniconda3/envs/ipt-cfr2sbvr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adsantos/miniconda3/envs/ipt-cfr2sbvr/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Analyzing the Distribution of Similarity Classifications

# %%
create_elements_results_distribution_source(df_elements_results)

# %% [markdown]
# ##### Extract elements: term, and verb symbols (P1)

# %% [markdown]
# **Matching and missing terms**

# %%
terms_matches = []
terms_not_matches = []

for pred_term in pred_terms_extraction:#pred_terms_classify:

    statement_id = pred_term.get("statement_id")
    doc_id = pred_term.get("doc_id")
    sources = pred_term.get("sources")

    results = DeepSearch(
        true_terms_extraction,
        statement_id,
        verbose_level=2,
        case_sensitive=False,
        match_string=True,
    )
    logger.debug(results)
    if results:
        for item in list(results["matched_values"].keys()):
            idx, key = extract_index_and_key(item)
            # print(idx, key)
        terms_matches.append(true_terms_extraction[idx])
    else:
        terms_not_matches.append(pred_term)
        logger.debug(doc_id, sources, statement_id)
        logger.debug(results)

# %% [markdown]
# Total of matching and missing terms

# %%
len(terms_matches), len(terms_not_matches)
# Out:
# (997, 52)

# %% [markdown]
# Unique terms combining statement_id and sources

# %%
terms_not_matches
# Out:
# [{'statement_id': 'Power to sell',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(i)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Right to receive',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(ii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Limited liability company',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Right to receive',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Desirability of a hearing',
#   'classification': 'Common Noun',
#   'sources': ('(a)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Own motion',
#   'classification': 'Common Noun',
#   'sources': ('(c)(2)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Right to receive',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(ii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Limited liability company',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)(A)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Interests',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)(A)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Last address filed',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Desirability of a hearing',
#   'classification': 'Common Noun',
#   'sources': ('(a)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Own motion',
#   'classification': 'Common Noun',
#   'sources': ('(c)(2)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Limited liability company',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Copy',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Affairs',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Place',
#   'classification': 'Common Noun',
#   'sources': ('(b)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Limited liability company',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Interests',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Desirability of a hearing',
#   'classification': 'Common Noun',
#   'sources': ('(a)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Process, pleadings, or papers',
#   'classification': 'Common Noun',
#   'sources': ('(a)(1)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Process, pleadings, or other papers',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Registered or certified mail',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': "Party's last address filed with the Commission",
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Process, pleadings, or other papers',
#   'classification': 'Common Noun',
#   'sources': ('(a)(3)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Unincorporated organization or association',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Principal office and place of business',
#   'classification': 'Common Noun',
#   'sources': ('(b)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Unincorporated organization or association',
#   'classification': 'Common Noun',
#   'sources': ('(b)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Principal office and place of business',
#   'classification': 'Common Noun',
#   'sources': ('(b)(3)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Request',
#   'classification': 'Common Noun',
#   'sources': ('(c)(1)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Power to sell',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(i)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Limited liability company',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Registered or certified mail',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Last day of the most recent fiscal year',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Copy',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Affairs',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Notice of the initiation of the proceeding',
#   'classification': 'Common Noun',
#   'sources': ('(a)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Facts bearing upon the desirability of a hearing',
#   'classification': 'Common Noun',
#   'sources': ('(a)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Nature of his interest',
#   'classification': 'Common Noun',
#   'sources': ('(a)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Application for registration as an investment adviser',
#   'classification': 'Common Noun',
#   'sources': ('(d)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Process, pleadings, or papers',
#   'classification': 'Common Noun',
#   'sources': ('(a)(1)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Process, pleadings, or papers',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Registered or certified mail',
#   'classification': 'Common Noun',
#   'sources': ('(a)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Process, pleadings, or papers',
#   'classification': 'Common Noun',
#   'sources': ('(a)(3)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Unincorporated organization or association',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Place not subject to the jurisdiction of the United States',
#   'classification': 'Common Noun',
#   'sources': ('(b)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Principal office and place of business',
#   'classification': 'Common Noun',
#   'sources': ('(b)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Unincorporated organization or association',
#   'classification': 'Common Noun',
#   'sources': ('(b)(2)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Principal office and place of business',
#   'classification': 'Common Noun',
#   'sources': ('(b)(3)',),
#   'doc_id': '§ 275.0-2',
#   'definition': None},
#  {'statement_id': 'Own motion',
#   'classification': 'Common Noun',
#   'sources': ('(c)(2)',),
#   'doc_id': '§ 275.0-5',
#   'definition': None},
#  {'statement_id': 'Power to sell',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(i)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Contributed capital',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(ii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None},
#  {'statement_id': 'Contributed capital',
#   'classification': 'Common Noun',
#   'sources': ('(b)(1)(iii)',),
#   'doc_id': '§ 275.0-7',
#   'definition': None}]

# %%
unique_terms_not_matches = Counter(
    [
        f'{term["doc_id"]}|{term["sources"]}|{term["statement_id"]}'
        for term in terms_not_matches
    ]
)

len(unique_terms_not_matches)
# Out:
# 33

# %% [markdown]
# Distribution (without sources)

# %%
# Extract categories and frequencies
categories = [key.split("|")[2] for key in unique_terms_not_matches.keys()]
frequencies = list(unique_terms_not_matches.values())

# Create a distribution graph
plt.figure(figsize=(12, 6))
plt.bar(categories, frequencies, color="skyblue")
plt.xlabel("Categories", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.title("Distribution of Categories", fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Missing terms

# %%
unique_terms_not_matches
# Out:
# Counter({"§ 275.0-7|('(b)(1)(iii)',)|Limited liability company": 4,
#          "§ 275.0-7|('(b)(1)(i)',)|Power to sell": 3,
#          "§ 275.0-5|('(a)',)|Desirability of a hearing": 3,
#          "§ 275.0-5|('(c)(2)',)|Own motion": 3,
#          "§ 275.0-2|('(a)(2)',)|Registered or certified mail": 3,
#          "§ 275.0-7|('(b)(1)(ii)',)|Right to receive": 2,
#          "§ 275.0-2|('(a)(2)',)|Copy": 2,
#          "§ 275.0-2|('(b)(1)',)|Affairs": 2,
#          "§ 275.0-2|('(a)(1)',)|Process, pleadings, or papers": 2,
#          "§ 275.0-2|('(b)(1)',)|Unincorporated organization or association": 2,
#          "§ 275.0-2|('(b)(2)',)|Principal office and place of business": 2,
#          "§ 275.0-2|('(b)(2)',)|Unincorporated organization or association": 2,
#          "§ 275.0-2|('(b)(3)',)|Principal office and place of business": 2,
#          "§ 275.0-7|('(b)(1)(iii)',)|Right to receive": 1,
#          "§ 275.0-7|('(b)(1)(iii)(A)',)|Limited liability company": 1,
#          "§ 275.0-7|('(b)(1)(iii)(A)',)|Interests": 1,
#          "§ 275.0-2|('(a)(2)',)|Last address filed": 1,
#          "§ 275.0-2|('(b)(2)',)|Place": 1,
#          "§ 275.0-7|('(b)(1)(iii)',)|Interests": 1,
#          "§ 275.0-2|('(a)(2)',)|Process, pleadings, or other papers": 1,
#          "§ 275.0-2|('(a)(2)',)|Party's last address filed with the Commission": 1,
#          "§ 275.0-2|('(a)(3)',)|Process, pleadings, or other papers": 1,
#          "§ 275.0-5|('(c)(1)',)|Request": 1,
#          "§ 275.0-7|('(a)(2)',)|Last day of the most recent fiscal year": 1,
#          "§ 275.0-5|('(a)',)|Notice of the initiation of the proceeding": 1,
#          "§ 275.0-5|('(a)',)|Facts bearing upon the desirability of a hearing": 1,
#          "§ 275.0-5|('(a)',)|Nature of his interest": 1,
#          "§ 275.0-5|('(d)',)|Application for registration as an investment adviser": 1,
#          "§ 275.0-2|('(a)(2)',)|Process, pleadings, or papers": 1,
#          "§ 275.0-2|('(a)(3)',)|Process, pleadings, or papers": 1,
#          "§ 275.0-2|('(b)(2)',)|Place not subject to the jurisdiction of the United States": 1,
#          "§ 275.0-7|('(b)(1)(ii)',)|Contributed capital": 1,
#          "§ 275.0-7|('(b)(1)(iii)',)|Contributed capital": 1})

# %% [markdown]
# Matching terms

# %%
unique_terms_matches = Counter(
    [
        f'{term["doc_id"]}|{term["sources"]}|{term["statement_id"]}'
        for term in terms_matches
    ]
)

len(unique_terms_matches)
# Out:
# 68

# %%
len(true_terms_extraction)
# Out:
# 122

# %%
unique_terms_matches
# Out:
# Counter({"§ 275.0-7|('(b)(2)',)|Person": 90,
#          "§ 275.0-7|('(b)(2)',)|Investment adviser": 52,
#          "§ 275.0-5|('(c)',)|Hearing": 38,
#          "§ 275.0-7|('(b)(1)(ii)',)|Partnership": 30,
#          "§ 275.0-2|('(a)(3)',)|Named party": 27,
#          "§ 275.0-7|('(a)(3)',)|Assets under management": 25,
#          "§ 275.0-7|('(b)(2)',)|Total assets": 25,
#          "§ 275.0-2|('(a)(3)',)|Process": 22,
#          "§ 275.0-2|('(a)(3)',)|Pleadings": 22,
#          "§ 275.0-2|('(a)(3)',)|Papers": 22,
#          "§ 275.0-7|('(b)(1)',)|Control": 21,
#          "§ 275.0-7|('(b)(1)(iv)',)|Managing agent": 20,
#          "§ 275.0-7|('(b)(1)(iv)',)|Trustee": 20,
#          "§ 275.0-7|('(b)(1)(i)(A)',)|Corporation": 20,
#          "§ 275.0-5|('(c)',)|Interested person": 20,
#          "§ 275.0-5|('(b)',)|Period of time": 20,
#          "§ 275.0-5|('(c)',)|Matter": 19,
#          "§ 275.0-7|('(b)(1)(iii)',)|Right to vote": 18,
#          "§ 275.0-2|('(a)(1)',)|Non-resident investment adviser": 17,
#          "§ 275.0-2|('(a)(1)',)|Non-resident general partner": 17,
#          "§ 275.0-2|('(a)(1)',)|Non-resident managing agent": 17,
#          "§ 275.0-7|('(b)(1)(iii)',)|Capital": 17,
#          "§ 275.0-2|('(b)(2)',)|Unincorporated organization": 16,
#          "§ 275.0-2|('(b)(2)',)|Association": 16,
#          "§ 275.0-2|('(b)(3)',)|Principal office": 16,
#          "§ 275.0-2|('(b)(3)',)|Place of business": 16,
#          "§ 275.0-5|('(d)',)|Order": 15,
#          "§ 275.0-7|('(b)(1)(iii)',)|Right to receive upon dissolution": 14,
#          "§ 275.0-7|('(a)(3)',)|Fiscal year": 11,
#          "§ 275.0-2|('(a)',)|Appointed agents": 10,
#          "§ 275.0-2|('(a)(3)',)|Certification": 10,
#          "§ 275.0-2|('(a)(3)',)|Evidence of service": 10,
#          "§ 275.0-2|('(b)(2)',)|Non-resident": 10,
#          "§ 275.0-2|('(b)(2)',)|Individual": 10,
#          "§ 275.0-5|('(a)',)|Reasons": 10,
#          "§ 275.0-5|('(c)',)|Public interest": 10,
#          "§ 275.0-5|('(c)',)|Protection of investors": 10,
#          "§ 275.0-5|('(d)',)|Application": 10,
#          "§ 275.0-7|('(a)',)|Small business": 10,
#          "§ 275.0-7|('(a)',)|Small organization": 10,
#          "§ 275.0-7|('(b)(1)(i)(A)',)|Voting securities": 10,
#          "§ 275.0-7|('(b)(1)(iv)',)|Trust": 10,
#          "§ 275.0-7|('(b)(2)',)|Balance sheet": 10,
#          "§ 275.0-7|('(b)(2)',)|Subsidiaries": 10,
#          "§ 275.0-5|('(b)',)|Order disposing of the matter": 10,
#          "§ 275.0-5|('(a)',)|Notice": 9,
#          "§ 275.0-5|('(a)',)|Initiation of the proceeding": 9,
#          "§ 275.0-5|('(a)',)|Facts": 9,
#          "§ 275.0-5|('(a)',)|Nature of interest": 9,
#          "§ 275.0-7|('(b)(1)',)|Power": 9,
#          "§ 275.0-7|('(b)(1)',)|Management": 9,
#          "§ 275.0-7|('(b)(1)',)|Policies": 9,
#          "§ 275.0-7|('(b)(1)(iii)',)|Elected manager": 9,
#          "§ 275.0-2|('(a)(2)',)|Last address filed with the Commission": 8,
#          "§ 275.0-2|('(a)(1)',)|Commission's records": 7,
#          "§ 275.0-2|('(a)(2)',)|Registered mail": 7,
#          "§ 275.0-2|('(a)(2)',)|Certified mail": 7,
#          "§ 275.0-7|('(b)(1)',)|Ownership of securities": 7,
#          "§ 275.0-7|('(b)(1)',)|Contract": 7,
#          "§ 275.0-5|('(d)',)|Application for registration": 6,
#          "§ 275.0-7|('(b)(1)(iii)',)|Interests of the LLC": 6,
#          "§ 275.0-2|('(b)(2)',)|Jurisdiction of the United States": 5,
#          "§ 275.0-5|('(d)',)|Order of the Commission": 5,
#          "§ 275.0-7|('(b)(1)(iii)',)|Limited liability company (LLC)": 5,
#          "§ 275.0-5|('(a)',)|Earliest date": 4,
#          "§ 275.0-5|('(d)',)|Registration": 3,
#          "§ 275.0-5|('(c)',)|Motion": 3,
#          "§ 275.0-7|('(b)(1)(ii)',)|Dissolution": 2})

# %% [markdown]
# Distribution (without sources)

# %%
# Extract categories and frequencies
categories = [key.split("|")[2] for key in unique_terms_matches.keys()]
frequencies = list(unique_terms_matches.values())

# Create a distribution graph
plt.figure(figsize=(12, 6))
plt.bar(categories, frequencies, color="skyblue")
plt.xlabel("Categories", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.title("Distribution of Categories", fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Comparing pred vs true

# %%
# true_terms_list = set([f'{term["statement_id"]}|{term["doc_id"]}|{term["sources"]}' for term in true_terms_extraction])
true_terms_list = [
    f'{term["statement_id"]}|{term["doc_id"]}|{term["sources"]}'
    for term in true_terms_extraction
]

len(true_terms_list)
# Out:
# 122

# %%
# pred_terms_list = set([f'{term["statement_id"]}|{term["doc_id"]}|{term["sources"]}' for term in pred_terms_classify])
pred_terms_list = [
    f'{term["statement_id"]}|{term["doc_id"]}|{term["sources"]}'
    for term in pred_terms_extraction
]

len(pred_terms_list)
# Out:
# 1049

# %% [markdown]
# Metrics

# %%
def calculate_terms_metrics(true_list, pred_list):
    # Convert inputs to sets for efficient operations
    true_set = set(true_list)
    pred_set = set(pred_list)

    # Calculate components
    tp = len(true_set & pred_set)  # True Positives
    fp = len(pred_set - true_set)  # False Positives
    fn = len(true_set - pred_set)  # False Negatives
    tn = len(true_set) - tp - fp - fn  # True Negatives (using total terms)

    # Calculate metrics
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_score = (
        2 * (precision * recall) / (precision + recall)
        if (precision + recall) > 0
        else 0
    )
    accuracy = (tp + tn) / len(true_set) if len(true_set) > 0 else 0

    return {
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1_score,
        "Accuracy": accuracy,
        "TP": tp,
        "FP": fp,
        "FN": fn,
        "TN": tn,
    }

# %%
metrics = calculate_terms_metrics(true_terms_list, pred_terms_list)
for metric, value in metrics.items():
    print(f"{metric}: {value}")
# Out:
# Precision: 0.6918604651162791
# Recall: 0.9754098360655737
# F1-Score: 0.8095238095238095
# Accuracy: 0.5409836065573771
# TP: 119
# FP: 53
# FN: 3
# TN: -53

# %%
len(set(true_terms_list) - set(pred_terms_list)), len(
    set(pred_terms_list) - set(true_terms_list)
)
# Out:
# (3, 53)

# %% [markdown]
# FP - False Positive

# %%
sorted(set(pred_terms_list) - set(true_terms_list))
# Out:
# ["Affairs|§ 275.0-2|('(b)(1)',)",
#  "Application for registration as an investment adviser|§ 275.0-5|('(d)',)",
#  "Contributed capital|§ 275.0-7|('(b)(1)(ii)',)",
#  "Contributed capital|§ 275.0-7|('(b)(1)(iii)',)",
#  "Control|§ 275.0-7|('(a)',)",
#  "Copy|§ 275.0-2|('(a)(2)',)",
#  "Corporation|§ 275.0-7|('(b)(1)(i)',)",
#  "Desirability of a hearing|§ 275.0-5|('(a)',)",
#  "Dissolution|§ 275.0-7|('(b)(1)(iii)',)",
#  "Facts bearing upon the desirability of a hearing|§ 275.0-5|('(a)',)",
#  "Hearing|§ 275.0-5|('(c)(1)',)",
#  "Hearing|§ 275.0-5|('(c)(2)',)",
#  "Interested person|§ 275.0-5|('(c)(1)',)",
#  "Interests|§ 275.0-7|('(b)(1)(iii)',)",
#  "Interests|§ 275.0-7|('(b)(1)(iii)(A)',)",
#  "Last address filed|§ 275.0-2|('(a)(2)',)",
#  "Last day of the most recent fiscal year|§ 275.0-7|('(a)(2)',)",
#  "Limited liability company|§ 275.0-7|('(b)(1)(iii)',)",
#  "Limited liability company|§ 275.0-7|('(b)(1)(iii)(A)',)",
#  "Matter|§ 275.0-5|('(c)(1)',)",
#  "Matter|§ 275.0-5|('(c)(2)',)",
#  "Motion|§ 275.0-5|('(c)(2)',)",
#  "Nature of his interest|§ 275.0-5|('(a)',)",
#  "Notice of the initiation of the proceeding|§ 275.0-5|('(a)',)",
#  "Own motion|§ 275.0-5|('(c)(2)',)",
#  "Papers|§ 275.0-2|('(a)',)",
#  "Party's last address filed with the Commission|§ 275.0-2|('(a)(2)',)",
#  "Person|§ 275.0-7|('(a)',)",
#  "Person|§ 275.0-7|('(b)(1)(i)',)",
#  "Person|§ 275.0-7|('(b)(1)(iii)(A)',)",
#  "Place not subject to the jurisdiction of the United States|§ 275.0-2|('(b)(2)',)",
#  "Place|§ 275.0-2|('(b)(2)',)",
#  "Pleadings|§ 275.0-2|('(a)',)",
#  "Power to sell|§ 275.0-7|('(b)(1)(i)',)",
#  "Principal office and place of business|§ 275.0-2|('(b)(2)',)",
#  "Principal office and place of business|§ 275.0-2|('(b)(3)',)",
#  "Process, pleadings, or other papers|§ 275.0-2|('(a)(2)',)",
#  "Process, pleadings, or other papers|§ 275.0-2|('(a)(3)',)",
#  "Process, pleadings, or papers|§ 275.0-2|('(a)(1)',)",
#  "Process, pleadings, or papers|§ 275.0-2|('(a)(2)',)",
#  "Process, pleadings, or papers|§ 275.0-2|('(a)(3)',)",
#  "Process|§ 275.0-2|('(a)',)",
#  "Registered or certified mail|§ 275.0-2|('(a)(2)',)",
#  "Request|§ 275.0-5|('(c)(1)',)",
#  "Right to receive|§ 275.0-7|('(b)(1)(ii)',)",
#  "Right to receive|§ 275.0-7|('(b)(1)(iii)',)",
#  "Right to vote|§ 275.0-7|('(b)(1)(i)',)",
#  "Right to vote|§ 275.0-7|('(b)(1)(iii)(A)',)",
#  "Total assets|§ 275.0-7|('(a)',)",
#  "Total assets|§ 275.0-7|('(a)(3)',)",
#  "Unincorporated organization or association|§ 275.0-2|('(b)(1)',)",
#  "Unincorporated organization or association|§ 275.0-2|('(b)(2)',)",
#  "Voting securities|§ 275.0-7|('(b)(1)(i)',)"]

# %% [markdown]
# Grouped

# %%
len(group_and_count_not_in_true(pred_terms_list, true_terms_list).keys())
# Out:
# 53

# %%
group_and_count_not_in_true(pred_terms_list, true_terms_list)
# Out:
# {"Affairs|§ 275.0-2|('(b)(1)',)": 2,
#  "Application for registration as an investment adviser|§ 275.0-5|('(d)',)": 1,
#  "Contributed capital|§ 275.0-7|('(b)(1)(ii)',)": 1,
#  "Contributed capital|§ 275.0-7|('(b)(1)(iii)',)": 1,
#  "Control|§ 275.0-7|('(a)',)": 4,
#  "Copy|§ 275.0-2|('(a)(2)',)": 2,
#  "Corporation|§ 275.0-7|('(b)(1)(i)',)": 4,
#  "Desirability of a hearing|§ 275.0-5|('(a)',)": 3,
#  "Dissolution|§ 275.0-7|('(b)(1)(iii)',)": 1,
#  "Facts bearing upon the desirability of a hearing|§ 275.0-5|('(a)',)": 1,
#  "Hearing|§ 275.0-5|('(c)(1)',)": 4,
#  "Hearing|§ 275.0-5|('(c)(2)',)": 4,
#  "Interested person|§ 275.0-5|('(c)(1)',)": 4,
#  "Interests|§ 275.0-7|('(b)(1)(iii)',)": 1,
#  "Interests|§ 275.0-7|('(b)(1)(iii)(A)',)": 1,
#  "Last address filed|§ 275.0-2|('(a)(2)',)": 1,
#  "Last day of the most recent fiscal year|§ 275.0-7|('(a)(2)',)": 1,
#  "Limited liability company|§ 275.0-7|('(b)(1)(iii)',)": 4,
#  "Limited liability company|§ 275.0-7|('(b)(1)(iii)(A)',)": 1,
#  "Matter|§ 275.0-5|('(c)(1)',)": 2,
#  "Matter|§ 275.0-5|('(c)(2)',)": 2,
#  "Motion|§ 275.0-5|('(c)(2)',)": 1,
#  "Nature of his interest|§ 275.0-5|('(a)',)": 1,
#  "Notice of the initiation of the proceeding|§ 275.0-5|('(a)',)": 1,
#  "Own motion|§ 275.0-5|('(c)(2)',)": 3,
#  "Papers|§ 275.0-2|('(a)',)": 3,
#  "Party's last address filed with the Commission|§ 275.0-2|('(a)(2)',)": 1,
#  "Person|§ 275.0-7|('(a)',)": 4,
#  "Person|§ 275.0-7|('(b)(1)(i)',)": 4,
#  "Person|§ 275.0-7|('(b)(1)(iii)(A)',)": 1,
#  "Place not subject to the jurisdiction of the United States|§ 275.0-2|('(b)(2)',)": 1,
#  "Place|§ 275.0-2|('(b)(2)',)": 1,
#  "Pleadings|§ 275.0-2|('(a)',)": 3,
#  "Power to sell|§ 275.0-7|('(b)(1)(i)',)": 3,
#  "Principal office and place of business|§ 275.0-2|('(b)(2)',)": 2,
#  "Principal office and place of business|§ 275.0-2|('(b)(3)',)": 2,
#  "Process, pleadings, or other papers|§ 275.0-2|('(a)(2)',)": 1,
#  "Process, pleadings, or other papers|§ 275.0-2|('(a)(3)',)": 1,
#  "Process, pleadings, or papers|§ 275.0-2|('(a)(1)',)": 2,
#  "Process, pleadings, or papers|§ 275.0-2|('(a)(2)',)": 1,
#  "Process, pleadings, or papers|§ 275.0-2|('(a)(3)',)": 1,
#  "Process|§ 275.0-2|('(a)',)": 3,
#  "Registered or certified mail|§ 275.0-2|('(a)(2)',)": 3,
#  "Request|§ 275.0-5|('(c)(1)',)": 1,
#  "Right to receive|§ 275.0-7|('(b)(1)(ii)',)": 2,
#  "Right to receive|§ 275.0-7|('(b)(1)(iii)',)": 1,
#  "Right to vote|§ 275.0-7|('(b)(1)(i)',)": 3,
#  "Right to vote|§ 275.0-7|('(b)(1)(iii)(A)',)": 1,
#  "Total assets|§ 275.0-7|('(a)',)": 4,
#  "Total assets|§ 275.0-7|('(a)(3)',)": 3,
#  "Unincorporated organization or association|§ 275.0-2|('(b)(1)',)": 2,
#  "Unincorporated organization or association|§ 275.0-2|('(b)(2)',)": 2,
#  "Voting securities|§ 275.0-7|('(b)(1)(i)',)": 4}

# %% [markdown]
# FN - False Negative

# %%
set(true_terms_list) - set(pred_terms_list)
# Out:
# {"Last address|§ 275.0-2|('(a)(2)',)",
#  "Natural person|§ 275.0-7|('(a)(3)',)",
#  "Securities|§ 275.0-7|('(b)(1)',)"}

# %% [markdown]
# **Matching and missing names**

# %%
names_matches = []
names_not_matches = []

for pred_names in pred_names_extraction:

    statement_id = pred_names.get("statement_id")

    results = DeepSearch(
        true_names_extraction,
        statement_id,
        verbose_level=2,
        case_sensitive=False,
        match_string=True,
    )
    if results:
        for item in list(results["matched_values"].keys()):
            idx, key = extract_index_and_key(item)
            # print(idx, key)
        names_matches.append(true_names_extraction[idx])
    else:
        names_not_matches.append(pred_names)

# %% [markdown]
# Total of matching and missing names

# %%
len(names_matches), len(names_not_matches)
# Out:
# (121, 7)

# %% [markdown]
# Unique names combining statement_id and sources

# %%
unique_names_not_matches = Counter(
    [
        f'{name["doc_id"]}|{name["sources"]}|{name["statement_id"]}'
        for name in names_not_matches
    ]
)

len(unique_names_not_matches)
# Out:
# 1

# %%
unique_names_not_matches
# Out:
# Counter({"§ 275.0-7|('(a)(1)',)|Section 203A(a)(1)(A) of the Act": 7})

# %% [markdown]
# Distribution (without sources) - Not match

# %%
# Extract categories and frequencies
categories = [key.split("|")[2] for key in unique_names_not_matches.keys()]
frequencies = list(unique_names_not_matches.values())

# Create a distribution graph
plt.figure(figsize=(12, 6))
plt.bar(categories, frequencies, color="skyblue")
plt.xlabel("Categories", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.title("Distribution of Categories", fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Matching names

# %%
names_unique_matches = Counter(
    [
        f'{name["doc_id"]}|{name["sources"]}|{name["statement_id"]}'
        for name in names_matches
    ]
)

len(names_unique_matches)
# Out:
# 5

# %%
names_unique_matches
# Out:
# Counter({"§ 275.0-7|('(a)(1)',)|Commission": 81,
#          "§ 275.0-2|('(a)(2)',)|Secretary of the Commission": 10,
#          "§ 275.0-2|('(a)(3)',)|Secretary": 10,
#          "§ 275.0-5|('(a)',)|Federal Register": 10,
#          "§ 275.0-5|('(d)',)|Act": 10})

# %% [markdown]
# Distribution (without sources) - Match

# %%
# Extract categories and frequencies
categories = [key.split("|")[2] for key in names_unique_matches.keys()]
frequencies = list(names_unique_matches.values())

# Create a distribution graph
plt.figure(figsize=(12, 6))
plt.bar(categories, frequencies, color="skyblue")
plt.xlabel("Categories", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.title("Distribution of Categories", fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Metrics

# %%
# true_terms_list = set([f'{term["statement_id"]}|{term["doc_id"]}|{term["sources"]}' for term in true_terms_extraction])
true_names_list = [
    f'{name["statement_id"]}|{name["doc_id"]}|{name["sources"]}'
    for name in true_names_extraction
]

len(true_names_list)
# Out:
# 14

# %%
# pred_terms_list = set([f'{term["statement_id"]}|{term["doc_id"]}|{term["sources"]}' for term in pred_terms_classify])
pred_names_list = [
    f'{name["statement_id"]}|{name["doc_id"]}|{name["sources"]}'
    for name in pred_names_extraction
]

len(pred_names_list)
# Out:
# 128

# %%
true_names_list
# Out:
# ["Commission|§ 275.0-2|('(a)(1)',)",
#  "Commission|§ 275.0-2|('(a)(2)',)",
#  "Secretary of the Commission|§ 275.0-2|('(a)(2)',)",
#  "Commission|§ 275.0-2|('(a)(3)',)",
#  "Secretary|§ 275.0-2|('(a)(3)',)",
#  "Federal Register|§ 275.0-5|('(a)',)",
#  "Commission|§ 275.0-5|('(a)',)",
#  "Commission|§ 275.0-5|('(b)',)",
#  "Commission|§ 275.0-5|('(c)',)",
#  "Act|§ 275.0-5|('(d)',)",
#  "Commission|§ 275.0-5|('(d)',)",
#  "Commission|§ 275.0-7|('(a)',)",
#  "Commission|§ 275.0-7|('(a)(1)',)",
#  "Form ADV|§ 275.0-7|('(a)(1)',)"]

# %%
set(pred_names_list ) - set(true_names_list)
# Out:
# {"Commission|§ 275.0-5|('(c)(1)',)",
#  "Commission|§ 275.0-5|('(c)(2)',)",
#  "Section 203A(a)(1)(A) of the Act|§ 275.0-7|('(a)(1)',)"}

# %%
metrics = calculate_terms_metrics(true_names_list, pred_names_list)
for metric, value in metrics.items():
    print(f"{metric}: {value}")
# Out:
# Precision: 0.8125
# Recall: 0.9285714285714286
# F1-Score: 0.8666666666666666
# Accuracy: 0.7142857142857143
# TP: 13
# FP: 3
# FN: 1
# TN: -3

# %% [markdown]
# Semantic similarity

# %%
len(
    set(
        [
            f'{item["doc_id"]}|{item["sources"]}|{item["statement_id"]}'
            for item in true_terms_extraction
        ]
    )
)
# Out:
# 122

# %%
len(
    set(
        [
            f'{item["doc_id"]}|{item["sources"]}|{item["statement_id"]}'
            for item in pred_terms_extraction
        ]
    )
)
# Out:
# 172

# %%
# Run the similarity check
similarity_terms_results = check_for_definitions_similarity(
    true_terms_extraction, pred_terms_extraction
)
# Out:
# 2025-01-11 17:46:41 - INFO - Total terms in true_terms: 122
# 2025-01-11 17:46:41 - INFO - Total matched terms in pred_terms: 119

# %% [markdown]
# Create a dataframe of true and pred elements

# %%
df_terms_results = create_df_terms_results(similarity_terms_results)

# %% [markdown]
# Histogram of Similarity Scores

# %%
create_terms_results_distribution_similarity(df_terms_results)

# %% [markdown]
# Terms with Lowest Similarity Scores

# %%
# Count records with similarity_score equal to 0
count_zero_similarity = df_terms_results[
    df_terms_results["similarity_score"] == 0
].shape[0]

print(f"Number of records with similarity_score equal to 0 is {count_zero_similarity}")
# Out:
# Number of records with similarity_score equal to 0 is 0

# %%
# Identify Terms with Low Similarity Scores
df_sorted = df_terms_results.sort_values(by="similarity_score")

print("Top 10 Terms with Lowest Similarity Scores:")
display(df_sorted.head(10))
# Out:
# Top 10 Terms with Lowest Similarity Scores:
#        doc_id    sources                     term definition_pred  \
# 0   § 275.0-2     ((a),)                   person            None
# 86  § 275.0-7  ((b)(1),)                 contract            None
# 85  § 275.0-7  ((b)(1),)  ownership of securities            None
# 84  § 275.0-7  ((b)(1),)                   person            None
# 83  § 275.0-7  ((b)(1),)                 policies            None
# 82  § 275.0-7  ((b)(1),)               management            None
# 81  § 275.0-7  ((b)(1),)                    power            None
# 80  § 275.0-7  ((b)(1),)                  control            None
# 79  § 275.0-7  ((a)(3),)              fiscal year            None
# 78  § 275.0-7  ((a)(3),)                   person            None
#
#    definition_true  similarity_score
# 0                                  1
# 86                                 1
# 85                                 1
# 84                                 1
# 83                                 1
# 82                                 1
# 81                                 1
# 80                                 1
# 79                                 1
# 78                                 1

# %% [markdown]
# Visualize Low Similarity Terms with a Bar Chart

# %%
create_terms_results_histogram_low_similarity(df_terms_results, number_of_terms=20)

# %% [markdown]
# Analyze Similarity Scores by Document

# %%
create_terms_results_average_similarity_per_document(df_terms_results)
# Out:
# Average Similarity Score per Document:
#       doc_id  similarity_score
# 0  § 275.0-2               1.0
# 1  § 275.0-5               1.0
# 2  § 275.0-7               1.0

# %% [markdown]
# Heatmap of Similarity Scores

# %%
create_terms_results_heatmap(df_terms_results)

# %% [markdown]
# Save Similarity Results to Excel

# %%
excel_filename = f'{config["DEFAULT_OUTPUT_DIR"]}/extract_p2_true_pred_results.xlsx'
df_terms_results.to_excel(excel_filename, index=False)

logger.info(f"Similarity results saved to '{excel_filename}'")
# Out:
# 2024-12-21 21:43:21 - INFO - Similarity results saved to '../outputs/extract_p2_true_pred_results.xlsx'
