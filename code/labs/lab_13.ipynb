# %% [markdown]
# # ChainForge

# %%
pip install chainforge bash_kernel
# Out:
# ...
#   Using cached chainforge-0.3.2.3.tar.gz (6.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached bash_kernel-0.9.3-py2.py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached urllib3-1.26.6-py2.py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached google_generativeai-0.8.3-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached dalaipy-2.0.2-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached python_socketio-5.11.4-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# ...

# %%
python -m bash_kernel.install
# Out:
# Installing IPython kernel spec

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# conda activate ipt-cfr2sbvr
chainforge serve
# Out:
# Serving Flask server on localhost on port 8000...
#  * Serving Flask app 'chainforge.flask_app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:8000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Dec/2024 19:46:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Dec/2024 19:46:47] "GET /static/js/main.7fc6b6c3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Dec/2024 19:46:48] "GET /static/css/main.ebedcb7f.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Dec/2024 19:46:48] "POST /app/loadCachedCustomProviders HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Dec/2024 19:46:48] "POST /app/fetchEnvironAPIKeys HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Dec/2024 19:46:49] "GET /manifest.json HTTP/1.1" 404 -
